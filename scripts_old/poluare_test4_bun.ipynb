# %%
import pandas as pd

# %%
import requests

# %%
from requests.auth import HTTPBasicAuth
auth = HTTPBasicAuth('elastic', 'AWbtmGda2Q7BI2bYpdjyF4qd')
url = 'https://8f9677360fc34e2eb943d737b2597c7b.us-east-1.aws.found.io:9243/brasov-dev/_search'

# %%
response = requests.get(url=url, auth=auth)

# %%
response
# Out:
# <Response [200]>

# %%
import json
data = json.loads(response.text)

# %%
data
# Out:
# {'took': 0,
#  'timed_out': False,
#  '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 10000, 'relation': 'gte'},
#   'max_score': 1.0,
#   'hits': [{'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'zWpMNXcBTeKmGB84ekLH',
#     '_score': 1.0,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm25',
#      'Value': 20,
#      'LocationLat': 45.6568,
#      'LocationLong': 25.5917,
#      'TimeStamp': 1611506922000,
#      'Measurement': 'µg/m3'}},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'z2pMNXcBTeKmGB84ekLI',
#     '_score': 1.0,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm25',
#      'Value': 20,
#      'LocationLat': 45.670103,
#      'LocationLong': 25.617966,
#      'TimeStamp': 1611506907000,
#      'Measurement': 'µg/m3'}},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': '0GpMNXcBTeKmGB84ekLJ',
#     '_score': 1.0,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm1',
#      'Value': 15,
#      'LocationLat': 45.653509,
#      'LocationLong': 25.56612,
#      'TimeStamp': 1611506908000,
#      'Measurement': 'µg/m3'}},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': '0WpMNXcBTeKmGB84ekLJ',
#     '_score': 1.0,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm10',
#      'Value': 16,
#      'LocationLat': 45.6536,
#      'LocationLong': 25.599,
#      'TimeStamp': 1611506893000,
#      'Measurement': 'µg/m3'}},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': '0mpMNXcBTeKmGB84ekLK',
#     '_score': 1.0,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm1',
#      'Value': 12,
#      'LocationLat': 45.6718,
#      'LocationLong': 25.6006,
#      'TimeStamp': 1586291052000,
#      'Measurement': 'µg/m3'}},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': '1GpMNXcBTeKmGB84ekLM',
#     '_score': 1.0,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm10',
#      'Value': 2,
#      'LocationLat': 45.589267,
#      'LocationLong': 25.46445,
#      'TimeStamp': 1611506937000,
#      'Measurement': 'µg/m3'}},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': '02pMNXcBTeKmGB84ekLM',
#     '_score': 1.0,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm25',
#      'Value': 21,
#      'LocationLat': 45.6718,
#      'LocationLong': 25.6006,
#      'TimeStamp': 1586291052000,
#      'Measurement': 'µg/m3'}},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': '1WpMNXcBTeKmGB84ekLM',
#     '_score': 1.0,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm1',
#      'Value': 12,
#      'LocationLat': 45.670103,
#      'LocationLong': 25.617966,
#      'TimeStamp': 1611506907000,
#      'Measurement': 'µg/m3'}},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': '1mpMNXcBTeKmGB84ekLM',
#     '_score': 1.0,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm25',
#      'Value': 24,
#      'LocationLat': 45.653509,
#      'LocationLong': 25.56612,
#      'TimeStamp': 1611506908000,
#      'Measurement': 'µg/m3'}},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': '12pMNXcBTeKmGB84ekLM',
#     '_score': 1.0,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm1',
#      'Value': 14,
#      'LocationLat': 45.704032,
#      'LocationLong': 25.640955,
#      'TimeStamp': 1611506918000,
#      'Measurement': 'µg/m3'}}]}}

# %%
data.keys()
# Out:
# dict_keys(['took', 'timed_out', '_shards', 'hits'])

# %%
data['hits']
# Out:
# {'total': {'value': 10000, 'relation': 'gte'},
#  'max_score': 1.0,
#  'hits': [{'_index': 'brasov-dev',
#    '_type': '_doc',
#    '_id': 'zWpMNXcBTeKmGB84ekLH',
#    '_score': 1.0,
#    '_source': {'Source': 'UradMonitor',
#     'Sensor': 'pm25',
#     'Value': 20,
#     'LocationLat': 45.6568,
#     'LocationLong': 25.5917,
#     'TimeStamp': 1611506922000,
#     'Measurement': 'µg/m3'}},
#   {'_index': 'brasov-dev',
#    '_type': '_doc',
#    '_id': 'z2pMNXcBTeKmGB84ekLI',
#    '_score': 1.0,
#    '_source': {'Source': 'UradMonitor',
#     'Sensor': 'pm25',
#     'Value': 20,
#     'LocationLat': 45.670103,
#     'LocationLong': 25.617966,
#     'TimeStamp': 1611506907000,
#     'Measurement': 'µg/m3'}},
#   {'_index': 'brasov-dev',
#    '_type': '_doc',
#    '_id': '0GpMNXcBTeKmGB84ekLJ',
#    '_score': 1.0,
#    '_source': {'Source': 'UradMonitor',
#     'Sensor': 'pm1',
#     'Value': 15,
#     'LocationLat': 45.653509,
#     'LocationLong': 25.56612,
#     'TimeStamp': 1611506908000,
#     'Measurement': 'µg/m3'}},
#   {'_index': 'brasov-dev',
#    '_type': '_doc',
#    '_id': '0WpMNXcBTeKmGB84ekLJ',
#    '_score': 1.0,
#    '_source': {'Source': 'UradMonitor',
#     'Sensor': 'pm10',
#     'Value': 16,
#     'LocationLat': 45.6536,
#     'LocationLong': 25.599,
#     'TimeStamp': 1611506893000,
#     'Measurement': 'µg/m3'}},
#   {'_index': 'brasov-dev',
#    '_type': '_doc',
#    '_id': '0mpMNXcBTeKmGB84ekLK',
#    '_score': 1.0,
#    '_source': {'Source': 'UradMonitor',
#     'Sensor': 'pm1',
#     'Value': 12,
#     'LocationLat': 45.6718,
#     'LocationLong': 25.6006,
#     'TimeStamp': 1586291052000,
#     'Measurement': 'µg/m3'}},
#   {'_index': 'brasov-dev',
#    '_type': '_doc',
#    '_id': '1GpMNXcBTeKmGB84ekLM',
#    '_score': 1.0,
#    '_source': {'Source': 'UradMonitor',
#     'Sensor': 'pm10',
#     'Value': 2,
#     'LocationLat': 45.589267,
#     'LocationLong': 25.46445,
#     'TimeStamp': 1611506937000,
#     'Measurement': 'µg/m3'}},
#   {'_index': 'brasov-dev',
#    '_type': '_doc',
#    '_id': '02pMNXcBTeKmGB84ekLM',
#    '_score': 1.0,
#    '_source': {'Source': 'UradMonitor',
#     'Sensor': 'pm25',
#     'Value': 21,
#     'LocationLat': 45.6718,
#     'LocationLong': 25.6006,
#     'TimeStamp': 1586291052000,
#     'Measurement': 'µg/m3'}},
#   {'_index': 'brasov-dev',
#    '_type': '_doc',
#    '_id': '1WpMNXcBTeKmGB84ekLM',
#    '_score': 1.0,
#    '_source': {'Source': 'UradMonitor',
#     'Sensor': 'pm1',
#     'Value': 12,
#     'LocationLat': 45.670103,
#     'LocationLong': 25.617966,
#     'TimeStamp': 1611506907000,
#     'Measurement': 'µg/m3'}},
#   {'_index': 'brasov-dev',
#    '_type': '_doc',
#    '_id': '1mpMNXcBTeKmGB84ekLM',
#    '_score': 1.0,
#    '_source': {'Source': 'UradMonitor',
#     'Sensor': 'pm25',
#     'Value': 24,
#     'LocationLat': 45.653509,
#     'LocationLong': 25.56612,
#     'TimeStamp': 1611506908000,
#     'Measurement': 'µg/m3'}},
#   {'_index': 'brasov-dev',
#    '_type': '_doc',
#    '_id': '12pMNXcBTeKmGB84ekLM',
#    '_score': 1.0,
#    '_source': {'Source': 'UradMonitor',
#     'Sensor': 'pm1',
#     'Value': 14,
#     'LocationLat': 45.704032,
#     'LocationLong': 25.640955,
#     'TimeStamp': 1611506918000,
#     'Measurement': 'µg/m3'}}]}

# %%
data = data['hits']

# %%
df = pd.DataFrame(data['hits'])

# %%
df
# Out:
#        _index _type                   _id  _score  \
# 0  brasov-dev  _doc  zWpMNXcBTeKmGB84ekLH     1.0
# 1  brasov-dev  _doc  z2pMNXcBTeKmGB84ekLI     1.0
# 2  brasov-dev  _doc  0GpMNXcBTeKmGB84ekLJ     1.0
# 3  brasov-dev  _doc  0WpMNXcBTeKmGB84ekLJ     1.0
# 4  brasov-dev  _doc  0mpMNXcBTeKmGB84ekLK     1.0
# 5  brasov-dev  _doc  1GpMNXcBTeKmGB84ekLM     1.0
# 6  brasov-dev  _doc  02pMNXcBTeKmGB84ekLM     1.0
# 7  brasov-dev  _doc  1WpMNXcBTeKmGB84ekLM     1.0
# 8  brasov-dev  _doc  1mpMNXcBTeKmGB84ekLM     1.0
# 9  brasov-dev  _doc  12pMNXcBTeKmGB84ekLM     1.0
#
#                                              _source
# 0  {'Source': 'UradMonitor', 'Sensor': 'pm25', 'V...
# 1  {'Source': 'UradMonitor', 'Sensor': 'pm25', 'V...
# 2  {'Source': 'UradMonitor', 'Sensor': 'pm1', 'Va...
# 3  {'Source': 'UradMonitor', 'Sensor': 'pm10', 'V...
# 4  {'Source': 'UradMonitor', 'Sensor': 'pm1', 'Va...
# 5  {'Source': 'UradMonitor', 'Sensor': 'pm10', 'V...
# 6  {'Source': 'UradMonitor', 'Sensor': 'pm25', 'V...
# 7  {'Source': 'UradMonitor', 'Sensor': 'pm1', 'Va...
# 8  {'Source': 'UradMonitor', 'Sensor': 'pm25', 'V...
# 9  {'Source': 'UradMonitor', 'Sensor': 'pm1', 'Va...
