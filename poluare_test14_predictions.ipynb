# %%
import pandas as pd

# %%
import requests
from requests.auth import HTTPBasicAuth
auth = HTTPBasicAuth('elastic', 'AWbtmGda2Q7BI2bYpdjyF4qd')
url = 'https://8f9677360fc34e2eb943d737b2597c7b.us-east-1.aws.found.io:9243/brasov-dev/_search?size=10000&q=*&sort=TimeStamp:desc'

# %%
response = requests.get(url=url, auth=auth)

# %%
response
# Out:
# <Response [200]>

# %%
import json
data = json.loads(response.text)

# %%
data
# Out:
# {'took': 538,
#  'timed_out': False,
#  '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 10000, 'relation': 'gte'},
#   'max_score': None,
#   'hits': [{'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'HEGc0H8Bwa_bL2zRp0Jh',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm25',
#      'Value': 18,
#      'LocationLat': 45.6536,
#      'LocationLong': 25.599,
#      'TimeStamp': 1648472400000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648472400000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'I0Gc0H8Bwa_bL2zRp0J4',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm1',
#      'Value': 10,
#      'LocationLat': 45.6536,
#      'LocationLong': 25.599,
#      'TimeStamp': 1648472400000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648472400000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'YkGc0H8Bwa_bL2zRqELL',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'o3',
#      'Value': 20,
#      'LocationLat': 45.651464,
#      'LocationLong': 25.615426,
#      'TimeStamp': 1648472400000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648472400000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'bkGc0H8Bwa_bL2zRqkLo',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm10',
#      'Value': 21,
#      'LocationLat': 45.6536,
#      'LocationLong': 25.599,
#      'TimeStamp': 1648472400000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648472400000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'c0Gc0H8Bwa_bL2zRqkLu',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'co2',
#      'Value': 405,
#      'LocationLat': 45.651464,
#      'LocationLong': 25.615426,
#      'TimeStamp': 1648472400000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648472400000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'VUGc0H8Bwa_bL2zRqEKM',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm1',
#      'Value': 12,
#      'LocationLat': 45.651464,
#      'LocationLong': 25.615426,
#      'TimeStamp': 1648472400000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648472400000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'V0Gc0H8Bwa_bL2zRqEKx',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm10',
#      'Value': 18,
#      'LocationLat': 45.651464,
#      'LocationLong': 25.615426,
#      'TimeStamp': 1648472400000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648472400000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'WUGc0H8Bwa_bL2zRqEK0',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'cho2',
#      'Value': 7,
#      'LocationLat': 45.651464,
#      'LocationLong': 25.615426,
#      'TimeStamp': 1648472400000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648472400000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'XUGc0H8Bwa_bL2zRqEK_',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm25',
#      'Value': 16,
#      'LocationLat': 45.651464,
#      'LocationLong': 25.615426,
#      'TimeStamp': 1648472400000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648472400000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'sEGc0H8Bwa_bL2zRtEL_',
#     '_score': None,
#     '_source': {'Source': 'Waqi',
#      'Sensor': 'no2',
#      'Value': 10.5,
#      'LocationLat': 45.6343302,
#      'LocationLong': 25.6338716,
#      'TimeStamp': 1648472400000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648472400000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'sUGc0H8Bwa_bL2zRtUIA',
#     '_score': None,
#     '_source': {'Source': 'Waqi',
#      'Sensor': 'no2',
#      'Value': 14.1,
#      'LocationLat': 45.6598333,
#      'LocationLong': 25.6144883,
#      'TimeStamp': 1648472400000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648472400000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'skGc0H8Bwa_bL2zRtUIB',
#     '_score': None,
#     '_source': {'Source': 'Waqi',
#      'Sensor': 'pm10',
#      'Value': 12,
#      'LocationLat': 45.6343302,
#      'LocationLong': 25.6338716,
#      'TimeStamp': 1648472400000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648472400000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 's0Gc0H8Bwa_bL2zRtUIC',
#     '_score': None,
#     '_source': {'Source': 'Waqi',
#      'Sensor': 'pm10',
#      'Value': 17,
#      'LocationLat': 45.6598333,
#      'LocationLong': 25.6144883,
#      'TimeStamp': 1648472400000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648472400000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'tEGc0H8Bwa_bL2zRtUJd',
#     '_score': None,
#     '_source': {'Source': 'Waqi',
#      'Sensor': 'o3',
#      'Value': 62.2,
#      'LocationLat': 45.7167,
#      'LocationLong': 25.6333,
#      'TimeStamp': 1648472400000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648472400000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'uEGc0H8Bwa_bL2zRtUK_',
#     '_score': None,
#     '_source': {'Source': 'Waqi',
#      'Sensor': 'pm10',
#      'Value': 18,
#      'LocationLat': 45.6542706,
#      'LocationLong': 25.6240614,
#      'TimeStamp': 1648472400000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648472400000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'tUGc0H8Bwa_bL2zRtUJd',
#     '_score': None,
#     '_source': {'Source': 'Waqi',
#      'Sensor': 'pm10',
#      'Value': 15,
#      'LocationLat': 45.7167,
#      'LocationLong': 25.6333,
#      'TimeStamp': 1648472400000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648472400000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'tkGc0H8Bwa_bL2zRtUJh',
#     '_score': None,
#     '_source': {'Source': 'Waqi',
#      'Sensor': 'no2',
#      'Value': 0.8,
#      'LocationLat': 45.7167,
#      'LocationLong': 25.6333,
#      'TimeStamp': 1648472400000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648472400000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 't0Gc0H8Bwa_bL2zRtUJh',
#     '_score': None,
#     '_source': {'Source': 'Waqi',
#      'Sensor': 'so2',
#      'Value': 1.4,
#      'LocationLat': 45.7167,
#      'LocationLong': 25.6333,
#      'TimeStamp': 1648472400000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648472400000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'uUGc0H8Bwa_bL2zRtUK_',
#     '_score': None,
#     '_source': {'Source': 'Waqi',
#      'Sensor': 'no2',
#      'Value': 9.9,
#      'LocationLat': 45.6542706,
#      'LocationLong': 25.6240614,
#      'TimeStamp': 1648472400000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648472400000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'ukGc0H8Bwa_bL2zRtULA',
#     '_score': None,
#     '_source': {'Source': 'Waqi',
#      'Sensor': 'so2',
#      'Value': 2.1,
#      'LocationLat': 45.6542706,
#      'LocationLong': 25.6240614,
#      'TimeStamp': 1648472400000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648472400000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'u0Gc0H8Bwa_bL2zRtULC',
#     '_score': None,
#     '_source': {'Source': 'Waqi',
#      'Sensor': 'o3',
#      'Value': 47.5,
#      'LocationLat': 45.6491174,
#      'LocationLong': 25.6041355,
#      'TimeStamp': 1648472400000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648472400000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'vEGc0H8Bwa_bL2zRtULC',
#     '_score': None,
#     '_source': {'Source': 'Waqi',
#      'Sensor': 'pm10',
#      'Value': 18,
#      'LocationLat': 45.6491174,
#      'LocationLong': 25.6041355,
#      'TimeStamp': 1648472400000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648472400000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'vUGc0H8Bwa_bL2zRtULF',
#     '_score': None,
#     '_source': {'Source': 'Waqi',
#      'Sensor': 'no2',
#      'Value': 8.8,
#      'LocationLat': 45.6491174,
#      'LocationLong': 25.6041355,
#      'TimeStamp': 1648472400000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648472400000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'vkGc0H8Bwa_bL2zRtULG',
#     '_score': None,
#     '_source': {'Source': 'Waqi',
#      'Sensor': 'so2',
#      'Value': 2.6,
#      'LocationLat': 45.6491174,
#      'LocationLong': 25.6041355,
#      'TimeStamp': 1648472400000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648472400000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'KEGc0H8Bwa_bL2zRp0KV',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm10',
#      'Value': 11,
#      'LocationLat': 45.645914,
#      'LocationLong': 25.602642,
#      'TimeStamp': 1648472399000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648472399000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'M0Gc0H8Bwa_bL2zRp0LP',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm10',
#      'Value': 16,
#      'LocationLat': 45.589267,
#      'LocationLong': 25.46445,
#      'TimeStamp': 1648472399000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648472399000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'O0Gc0H8Bwa_bL2zRp0Lm',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm25',
#      'Value': 11,
#      'LocationLat': 45.646976,
#      'LocationLong': 25.595224,
#      'TimeStamp': 1648472399000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648472399000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'ckGc0H8Bwa_bL2zRqkLu',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm1',
#      'Value': 7,
#      'LocationLat': 45.645914,
#      'LocationLong': 25.602642,
#      'TimeStamp': 1648472399000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648472399000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'hEGc0H8Bwa_bL2zRq0J6',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm1',
#      'Value': 8,
#      'LocationLat': 45.646976,
#      'LocationLong': 25.595224,
#      'TimeStamp': 1648472399000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648472399000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'kkGc0H8Bwa_bL2zRrEIj',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm25',
#      'Value': 14,
#      'LocationLat': 45.589267,
#      'LocationLong': 25.46445,
#      'TimeStamp': 1648472399000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648472399000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'mUGc0H8Bwa_bL2zRrkKy',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm25',
#      'Value': 9,
#      'LocationLat': 45.645914,
#      'LocationLong': 25.602642,
#      'TimeStamp': 1648472399000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648472399000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'rUGc0H8Bwa_bL2zRs0K1',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm1',
#      'Value': 10,
#      'LocationLat': 45.589267,
#      'LocationLong': 25.46445,
#      'TimeStamp': 1648472399000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648472399000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'qEGc0H8Bwa_bL2zRs0KY',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm10',
#      'Value': 12,
#      'LocationLat': 45.646976,
#      'LocationLong': 25.595224,
#      'TimeStamp': 1648472399000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648472399000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'Q0Gc0H8Bwa_bL2zRqEJK',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm25',
#      'Value': 10,
#      'LocationLat': 45.641274,
#      'LocationLong': 25.614817,
#      'TimeStamp': 1648472391000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648472391000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'aUGc0H8Bwa_bL2zRqkLV',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm10',
#      'Value': 10,
#      'LocationLat': 45.641274,
#      'LocationLong': 25.614817,
#      'TimeStamp': 1648472391000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648472391000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'qkGc0H8Bwa_bL2zRs0Kb',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm1',
#      'Value': 7,
#      'LocationLat': 45.641274,
#      'LocationLong': 25.614817,
#      'TimeStamp': 1648472391000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648472391000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'GEGc0H8Bwa_bL2zRp0JG',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm25',
#      'Value': 16,
#      'LocationLat': 45.6568,
#      'LocationLong': 25.5917,
#      'TimeStamp': 1648472373000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648472373000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'QkGc0H8Bwa_bL2zRqEJJ',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm10',
#      'Value': 14,
#      'LocationLat': 45.657148,
#      'LocationLong': 25.563752,
#      'TimeStamp': 1648472373000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648472373000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'ekGc0H8Bwa_bL2zRq0IW',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm1',
#      'Value': 9,
#      'LocationLat': 45.6568,
#      'LocationLong': 25.5917,
#      'TimeStamp': 1648472373000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648472373000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'fkGc0H8Bwa_bL2zRq0Is',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm10',
#      'Value': 19,
#      'LocationLat': 45.6568,
#      'LocationLong': 25.5917,
#      'TimeStamp': 1648472373000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648472373000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'ikGc0H8Bwa_bL2zRq0KS',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'o3',
#      'Value': 20,
#      'LocationLat': 45.657148,
#      'LocationLong': 25.563752,
#      'TimeStamp': 1648472373000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648472373000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'i0Gc0H8Bwa_bL2zRq0Kb',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'cho2',
#      'Value': 7,
#      'LocationLat': 45.657148,
#      'LocationLong': 25.563752,
#      'TimeStamp': 1648472373000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648472373000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'XEGc0H8Bwa_bL2zRqEK6',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm25',
#      'Value': 13,
#      'LocationLat': 45.657148,
#      'LocationLong': 25.563752,
#      'TimeStamp': 1648472373000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648472373000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'h0Gc0H8Bwa_bL2zRq0KI',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm1',
#      'Value': 10,
#      'LocationLat': 45.657148,
#      'LocationLong': 25.563752,
#      'TimeStamp': 1648472373000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648472373000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'iEGc0H8Bwa_bL2zRq0KJ',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'co2',
#      'Value': 408,
#      'LocationLat': 45.657148,
#      'LocationLong': 25.563752,
#      'TimeStamp': 1648472373000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648472373000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'QUGc0H8Bwa_bL2zRqEJJ',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm25',
#      'Value': 12,
#      'LocationLat': 45.614267,
#      'LocationLong': 25.63325,
#      'TimeStamp': 1648472372000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648472372000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'a0Gc0H8Bwa_bL2zRqkLb',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm1',
#      'Value': 9,
#      'LocationLat': 45.614267,
#      'LocationLong': 25.63325,
#      'TimeStamp': 1648472372000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648472372000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'r0Gc0H8Bwa_bL2zRtEIZ',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm10',
#      'Value': 13,
#      'LocationLat': 45.614267,
#      'LocationLong': 25.63325,
#      'TimeStamp': 1648472372000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648472372000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'YEGc0H8Bwa_bL2zRqELG',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'o3',
#      'Value': 20,
#      'LocationLat': 45.642198,
#      'LocationLong': 25.588532,
#      'TimeStamp': 1648472371000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648472371000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'kEGc0H8Bwa_bL2zRrEIU',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm25',
#      'Value': 11,
#      'LocationLat': 45.642198,
#      'LocationLong': 25.588532,
#      'TimeStamp': 1648472371000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648472371000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'VkGc0H8Bwa_bL2zRqEKw',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm1',
#      'Value': 8,
#      'LocationLat': 45.642198,
#      'LocationLong': 25.588532,
#      'TimeStamp': 1648472371000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648472371000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'WEGc0H8Bwa_bL2zRqEK0',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'co2',
#      'Value': 428,
#      'LocationLat': 45.642198,
#      'LocationLong': 25.588532,
#      'TimeStamp': 1648472371000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648
#      _source.Source _source.Sensor  _source.Value  _source.LocationLat  \
# 0       UradMonitor           pm25           18.0            45.653600
# 1       UradMonitor            pm1           10.0            45.653600
# 2       UradMonitor             o3           20.0            45.651464
# 3       UradMonitor           pm10           21.0            45.653600
# 4       UradMonitor            co2          405.0            45.651464
# ...             ...            ...            ...                  ...
# 9995    UradMonitor           pm10           28.0            45.653509
# 9996    UradMonitor            pm1           20.0            45.653509
# 9997    UradMonitor           pm25           26.0            45.653509
# 9998    UradMonitor           cho2            7.0            45.651464
# 9999    UradMonitor           pm25           27.0            45.651464
#
#       _source.LocationLong  _source.TimeStamp _source.Measurement
# 0                25.599000      1648472400000               µg/m3
# 1                25.599000      1648472400000               µg/m3
# 2                25.615426      1648472400000               µg/m3
# 3                25.599000      1648472400000               µg/m3
# 4                25.615426      1648472400000               µg/m3
# ...                    ...                ...                 ...
# 9995             25.566120      1648133955000               µg/m3
# 9996             25.566120      1648133955000               µg/m3
# 9997             25.566120      1648133955000               µg/m3
# 9998             25.615426      1648133954000               µg/m3
# 9999             25.615426      1648133954000               µg/m3
#
# [10000 rows x 12 columns]

# %%
import matplotlib.pyplot as plt
hist_sensor = plt.figure(figsize = (25,10))
ax = hist_sensor.gca()

dataframe.get('_source.Sensor').value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
dataframe['LocationId'] = dataframe['_source.LocationLat']*10000000 + dataframe['_source.LocationLong']*10000000
dataframe['LocationName'] = ""
dataframe.loc[dataframe['LocationId'] == 712668900.0, 'LocationName'] = 'AFI' 
dataframe.loc[dataframe['LocationId'] == 712196290.0, 'LocationName'] = 'Bartolomeu1'
dataframe.loc[dataframe['LocationId'] == 712209000.0, 'LocationName'] = 'Bartolomeu2'
dataframe.loc[dataframe['LocationId'] == 712240750.0, 'LocationName'] = 'Bartolomeu3'
dataframe.loc[dataframe['LocationId'] == 708361730.0, 'LocationName'] = 'Bucegi'
dataframe.loc[dataframe['LocationId'] == 712682018.0, 'LocationName'] = 'Carrefour'
dataframe.loc[dataframe['LocationId'] == 712307300.0, 'LocationName'] = 'Centru1'
dataframe.loc[dataframe['LocationId'] == 712422000.0, 'LocationName'] = 'Centru2'
dataframe.loc[dataframe['LocationId'] == 712485560.0, 'LocationName'] = 'Centru3'
dataframe.loc[dataframe['LocationId'] == 712532529.0, 'LocationName'] = 'Centru4'
dataframe.loc[dataframe['LocationId'] == 711435090.0, 'LocationName'] = 'Codlea1'
dataframe.loc[dataframe['LocationId'] == 711587690.0, 'LocationName'] = 'Codlea2'
dataframe.loc[dataframe['LocationId'] == 712526000.0, 'LocationName'] = 'Colina1'
dataframe.loc[dataframe['LocationId'] == 712485000.0, 'LocationName'] = 'Colina2'
dataframe.loc[dataframe['LocationId'] == 711054930.0, 'LocationName'] = 'Cristian'
dataframe.loc[dataframe['LocationId'] == 712743216.0, 'LocationName'] = 'Gara'
dataframe.loc[dataframe['LocationId'] == 713825580.0, 'LocationName'] = 'Harman1'
dataframe.loc[dataframe['LocationId'] == 714030800.0, 'LocationName'] = 'Harman2'
dataframe.loc[dataframe['LocationId'] == 712560910.0, 'LocationName'] = 'Racadau'
dataframe.loc[dataframe['LocationId'] == 710537170.0, 'LocationName'] = 'Rasnov'
dataframe.loc[dataframe['LocationId'] == 713449870.0, 'LocationName'] = 'Sanpetru1'
dataframe.loc[dataframe['LocationId'] == 713500000.0, 'LocationName'] = 'Sanpetru2'
dataframe.loc[dataframe['LocationId'] == 712475170.0, 'LocationName'] = 'Saturn'
dataframe.loc[dataframe['LocationId'] == 712500331.0, 'LocationName'] = 'Stupini1'
dataframe.loc[dataframe['LocationId'] == 712571580.0, 'LocationName'] = 'Stupini2'
dataframe.loc[dataframe['LocationId'] == 712804610.0, 'LocationName'] = 'Tractorul'
dataframe.loc[dataframe['LocationId'] == 713218270.0, 'LocationName'] = 'TriajH'
dataframe.loc[dataframe['LocationId'] == 712783320.0, 'LocationName'] = 'Vlahuta1'
dataframe.loc[dataframe['LocationId'] == 712797770.0, 'LocationName'] = 'Vlahuta2'
dataframe.head(10)
# Out:
#        _index _type                   _id _score             sort  \
# 0  brasov-dev  _doc  HEGc0H8Bwa_bL2zRp0Jh   None  [1648472400000]
# 1  brasov-dev  _doc  I0Gc0H8Bwa_bL2zRp0J4   None  [1648472400000]
# 2  brasov-dev  _doc  YkGc0H8Bwa_bL2zRqELL   None  [1648472400000]
# 3  brasov-dev  _doc  bkGc0H8Bwa_bL2zRqkLo   None  [1648472400000]
# 4  brasov-dev  _doc  c0Gc0H8Bwa_bL2zRqkLu   None  [1648472400000]
# 5  brasov-dev  _doc  VUGc0H8Bwa_bL2zRqEKM   None  [1648472400000]
# 6  brasov-dev  _doc  V0Gc0H8Bwa_bL2zRqEKx   None  [1648472400000]
# 7  brasov-dev  _doc  WUGc0H8Bwa_bL2zRqEK0   None  [1648472400000]
# 8  brasov-dev  _doc  XUGc0H8Bwa_bL2zRqEK_   None  [1648472400000]
# 9  brasov-dev  _doc  sEGc0H8Bwa_bL2zRtEL_   None  [1648472400000]
#
#   _source.Source _source.Sensor  _source.Value  _source.LocationLat  \
# 0    UradMonitor           pm25           18.0            45.653600
# 1    UradMonitor            pm1           10.0            45.653600
# 2    UradMonitor             o3           20.0            45.651464
# 3    UradMonitor           pm10           21.0            45.653600
# 4    UradMonitor            co2          405.0            45.651464
# 5    UradMonitor            pm1           12.0            45.651464
# 6    UradMonitor           pm10           18.0            45.651464
# 7    UradMonitor           cho2            7.0            45.651464
# 8    UradMonitor           pm25           16.0            45.651464
# 9           Waqi            no2           10.5            45.634330
#
#    _source.LocationLong  _source.TimeStamp _source.Measurement   LocationId  \
# 0             25.599000      1648472400000               µg/m3  712526000.0
# 1             25.599000      1648472400000               µg/m3  712526000.0
# 2             25.615426      1648472400000               µg/m3  712668900.0
# 3             25.599000      1648472400000               µg/m3  712526000.0
# 4             25.615426      1648472400000               µg/m3  712668900.0
# 5             25.615426      1648472400000               µg/m3  712668900.0
# 6             25.615426      1648472400000               µg/m3  712668900.0
# 7             25.615426      1648472400000               µg/m3  712668900.0
# 8             25.615426      1648472400000               µg/m3  712668900.0
# 9             25.633872      1648472400000               µg/m3  712682018.0
#
#   LocationName
# 0      Colina1
# 1      Colina1
# 2          AFI
# 3      Colina1
# 4          AFI
# 5          AFI
# 6          AFI
# 7          AFI
# 8          AFI
# 9    Carrefour

# %%
# dataframe.groupby(['LocationName']).size().reset_index().rename(columns={0:'count'})

# %%
# hist_location = dataframe.get('LocationName').hist()
import matplotlib.pyplot as plt
hist_location = plt.figure(figsize = (25,10))
ax = hist_location.gca()
# dataframe.get('LocationName').hist(ax = ax)

dataframe.get('LocationName').value_counts().plot(kind='bar')
# dataframe.get('LocationName').value_counts(sort=False).plot.bar(rot=0)
# Out:
# <AxesSubplot:>

# %%
dataframe_v2 = dataframe[[i for i in list(dataframe.columns) if i != '_index']]
dataframe_v2 = dataframe_v2[[i for i in list(dataframe_v2.columns) if i != '_type']]
dataframe_v2 = dataframe_v2[[i for i in list(dataframe_v2.columns) if i != '_id']]
dataframe_v2 = dataframe_v2[[i for i in list(dataframe_v2.columns) if i != '_score']]
dataframe_v2 = dataframe_v2[[i for i in list(dataframe_v2.columns) if i != 'sort']]
dataframe_v2.head(7)
# dataframe_v2
# Out:
#   _source.Source _source.Sensor  _source.Value  _source.LocationLat  \
# 0    UradMonitor           pm25           18.0            45.653600
# 1    UradMonitor            pm1           10.0            45.653600
# 2    UradMonitor             o3           20.0            45.651464
# 3    UradMonitor           pm10           21.0            45.653600
# 4    UradMonitor            co2          405.0            45.651464
# 5    UradMonitor            pm1           12.0            45.651464
# 6    UradMonitor           pm10           18.0            45.651464
#
#    _source.LocationLong  _source.TimeStamp _source.Measurement   LocationId  \
# 0             25.599000      1648472400000               µg/m3  712526000.0
# 1             25.599000      1648472400000               µg/m3  712526000.0
# 2             25.615426      1648472400000               µg/m3  712668900.0
# 3             25.599000      1648472400000               µg/m3  712526000.0
# 4             25.615426      1648472400000               µg/m3  712668900.0
# 5             25.615426      1648472400000               µg/m3  712668900.0
# 6             25.615426      1648472400000               µg/m3  712668900.0
#
#   LocationName
# 0      Colina1
# 1      Colina1
# 2          AFI
# 3      Colina1
# 4          AFI
# 5          AFI
# 6          AFI

# %%
cho2 = dataframe_v2[dataframe_v2.get('_source.Sensor') == 'cho2']
co2 = dataframe_v2[dataframe_v2.get('_source.Sensor') == 'co2']
no2 = dataframe_v2[dataframe_v2.get('_source.Sensor') == 'no2']
o3 = dataframe_v2[dataframe_v2.get('_source.Sensor') == 'o3']
pm1 = dataframe_v2[dataframe_v2.get('_source.Sensor') == 'pm1']
pm10 = dataframe_v2[dataframe_v2.get('_source.Sensor') == 'pm10']
pm25 = dataframe_v2[dataframe_v2.get('_source.Sensor') == 'pm25']
so2 = dataframe_v2[dataframe_v2.get('_source.Sensor') == 'so2']

# %%
print('Lungime dataframe: ',len(dataframe_v2))
print('Lungime dataframe cho2: ',len(cho2))
print('Lungime dataframe co2: ',len(co2))
print('Lungime dataframe no2: ',len(no2))
print('Lungime dataframe o3: ',len(o3))
print('Lungime dataframe pm1: ',len(pm1))
print('Lungime dataframe pm10: ',len(pm10))
print('Lungime dataframe pm25: ',len(pm25))
print('Lungime dataframe so2: ',len(so2))
# Out:
# Lungime dataframe:  10000
# Lungime dataframe cho2:  473
# Lungime dataframe co2:  472
# Lungime dataframe no2:  470
# Lungime dataframe o3:  660
# Lungime dataframe pm1:  2390
# Lungime dataframe pm10:  2861
# Lungime dataframe pm25:  2392
# Lungime dataframe so2:  282

# %%
import matplotlib.pyplot as plt
plt.close("all")
# fig = plt.figure(figsize=(20,10), frameon=True)
plt.figure(figsize=(20,10))
plt.plot(so2.get('_source.TimeStamp'), so2.get('_source.Value'), label="All SO2 sensors")
plt.scatter(so2.get('_source.TimeStamp'), so2.get('_source.Value'), color = "red")
plt.xlabel("TimeStamp")
plt.ylabel("Value")
plt.title("Last 10000 values for all SO2 sensors")
plt.legend()
plt.savefig('plots_updated/SO2.jpg', bbox_inches = 'tight')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.linear_model import LinearRegression

# %%
X = so2[["_source.TimeStamp"]].values
y = so2[["_source.Value"]].values

# %%
regressor = LinearRegression()
regressor.fit(X, y)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(X)

# %%
print("Slope: ", float(regressor.coef_))
print("Intercept: ", float(regressor.intercept_))
# float("{:.8f}".format(float(regressor.intercept_)))
# Out:
# Slope:  -5.0721601084415e-10
# Intercept:  838.0079131590485

# %%
plt.figure(figsize=(20,10))
# plt.scatter(X, y, color = 'blue')
plt.plot(X,y, color = 'blue', label="All SO2 values")
plt.plot(X, regressor.predict(X), color = 'red', label="SO2 linear regression")
plt.title('Linear regression on last 10000 SO2 values')
plt.xlabel('TimeStamp')
plt.ylabel('Value')
plt.legend()
plt.savefig('plots_updated/SO2_regression.jpg', bbox_inches = 'tight')
plt.show()

# %%
so2.head(6) #Vlahuta1, Centru4, Sanpetru2
# Out:
#     _source.Source _source.Sensor  _source.Value  _source.LocationLat  \
# 17            Waqi            so2            1.4            45.716700
# 19            Waqi            so2            2.1            45.654271
# 23            Waqi            so2            2.6            45.649117
# 107           Waqi            so2            3.0            45.649117
# 119           Waqi            so2            2.1            45.654271
# 122           Waqi            so2            1.4            45.716700
#
#      _source.LocationLong  _source.TimeStamp _source.Measurement   LocationId  \
# 17              25.633300      1648472400000               µg/m3  713500000.0
# 19              25.624061      1648472400000               µg/m3  712783320.0
# 23              25.604136      1648472400000               µg/m3  712532529.0
# 107             25.604136      1648468800000               µg/m3  712532529.0
# 119             25.624061      1648468800000               µg/m3  712783320.0
# 122             25.633300      1648468800000               µg/m3  713500000.0
#
#     LocationName
# 17     Sanpetru2
# 19      Vlahuta1
# 23       Centru4
# 107      Centru4
# 119     Vlahuta1
# 122    Sanpetru2

# %%
so2_vlahuta1 = so2[so2.get('LocationName') == 'Vlahuta1']
so2_centru4 = so2[so2.get('LocationName') == 'Centru4']
so2_sanpetru2 = so2[so2.get('LocationName') == 'Sanpetru2']

# %%
import matplotlib.pyplot as plt
plt.close("all")
plt.figure(figsize=(20,10))
plt.plot(so2_vlahuta1.get('_source.TimeStamp'), so2_vlahuta1.get('_source.Value'), color = "red", label="Vlahuta1 SO2 sensor")
plt.plot(so2_centru4.get('_source.TimeStamp'), so2_centru4.get('_source.Value'), color = "blue", label="Centru4 SO2 sensor")
plt.plot(so2_sanpetru2.get('_source.TimeStamp'), so2_sanpetru2.get('_source.Value'), color = "purple", label="Sanpetru2 SO2 sensor")
plt.xlabel("TimeStamp")
plt.ylabel("Value")
plt.title("Last 10000 values for SO2")
plt.legend()
plt.savefig('plots_updated/SO2_all.jpg', bbox_inches = 'tight')
plt.show()

# %%
pm10_bartolomeu1 = pm10[pm10.get('LocationName') == 'Bartolomeu1']
pm10_bartolomeu2 = pm10[pm10.get('LocationName') == 'Bartolomeu2']
pm10_bartolomeu3 = pm10[pm10.get('LocationName') == 'Bartolomeu3']

# %%
import matplotlib.pyplot as plt
plt.close("all")
plt.figure(figsize=(20,10))
plt.plot(pm10_bartolomeu1.get('_source.TimeStamp'), pm10_bartolomeu1.get('_source.Value'), color = "red", label="Bartolomeu1 PM10 sensor")
plt.plot(pm10_bartolomeu2.get('_source.TimeStamp'), pm10_bartolomeu2.get('_source.Value'), color = "blue", label="Bartolomeu2 PM10 sensor")
plt.plot(pm10_bartolomeu3.get('_source.TimeStamp'), pm10_bartolomeu3.get('_source.Value'), color = "purple", label="Bartolomeu3 PM10 sensor")
plt.xlabel("TimeStamp")
plt.ylabel("Value")
plt.title("Last 10000 values for PM10 in Bartolomeu")
plt.legend()
plt.savefig('plots_updated/PM10_Bartolomeu.jpg', bbox_inches = 'tight')
plt.show()

# %%
pm10_bartolomeu2.head(30)
# Out:
#      _source.Source _source.Sensor  _source.Value  _source.LocationLat  \
# 37      UradMonitor           pm10           14.0            45.657148
# 149     UradMonitor           pm10           11.0            45.657148
# 256     UradMonitor           pm10           13.0            45.657148
# 356     UradMonitor           pm10           12.0            45.657148
# 454     UradMonitor           pm10           22.0            45.657148
# 575     UradMonitor           pm10           27.0            45.657148
# 677     UradMonitor           pm10           29.0            45.657148
# 782     UradMonitor           pm10           29.0            45.657148
# 884     UradMonitor           pm10           27.0            45.657148
# 975     UradMonitor           pm10           27.0            45.657148
# 1082    UradMonitor           pm10           23.0            45.657148
# 1184    UradMonitor           pm10           18.0            45.657148
# 1275    UradMonitor           pm10           16.0            45.657148
# 1375    UradMonitor           pm10           15.0            45.657148
# 1474    UradMonitor           pm10           20.0            45.657148
# 1592    UradMonitor           pm10           22.0            45.657148
# 1703    UradMonitor           pm10           20.0            45.657148
# 1841    UradMonitor           pm10           15.0            45.657148
# 1938    UradMonitor           pm10           30.0            45.657148
# 2047    UradMonitor           pm10           23.0            45.657148
# 2197    UradMonitor           pm10           19.0            45.657148
# 2302    UradMonitor           pm10           14.0            45.657148
# 2409    UradMonitor           pm10           12.0            45.657148
# 2517    UradMonitor           pm10           10.0            45.657148
# 2627    UradMonitor           pm10            7.0            45.657148
# 2729    UradMonitor           pm10            6.0            45.657148
# 2828    UradMonitor           pm10           12.0            45.657148
# 2928    UradMonitor           pm10            5.0            45.657148
# 3029    UradMonitor           pm10            9.0            45.657148
# 3123    UradMonitor           pm10           14.0            45.657148
#
#       _source.LocationLong  _source.TimeStamp _source.Measur


# %%
import matplotlib.pyplot as plt
plt.close("all")
plt.figure(figsize=(20,10))
# plt.plot(pm10_centru1.get('_source.TimeStamp'), pm10_centru1.get('_source.Value'), color = "red")
plt.plot(pm10_centru2.get('_source.TimeStamp'), pm10_centru2.get('_source.Value'), color = "blue", label="Centru2 PM10 sensor")
plt.plot(pm10_centru3.get('_source.TimeStamp'), pm10_centru3.get('_source.Value'), color = "purple", label="Centru3 PM10 sensor")
plt.plot(pm10_centru4.get('_source.TimeStamp'), pm10_centru4.get('_source.Value'), color = "red", label="Centru4 PM10 sensor")
plt.xlabel("TimeStamp")
plt.ylabel("Value")
plt.title("Last 10000 values for PM10 in Centru")
plt.legend()
plt.savefig('plots_updated/PM10_Centru.jpg', bbox_inches = 'tight')
plt.show()

# %%
pm10_carrefour = pm10[pm10.get('LocationName') == 'Carrefour']
pm10_afi = pm10[pm10.get('LocationName') == 'AFI']
pm10_gara = pm10[pm10.get('LocationName') == 'Gara']

# %%
import matplotlib.pyplot as plt
plt.close("all")
plt.figure(figsize=(20,10))
plt.plot(pm10_carrefour.get('_source.TimeStamp'), pm10_carrefour.get('_source.Value'), color = "red", label="Carrefour PM10 sensor")
plt.plot(pm10_afi.get('_source.TimeStamp'), pm10_afi.get('_source.Value'), color = "blue", label="AFI PM10 sensor")
plt.plot(pm10_gara.get('_source.TimeStamp'), pm10_gara.get('_source.Value'), color = "purple", label="Gara PM10 sensor")
plt.plot(pm10_centru4.get('_source.TimeStamp'), pm10_centru4.get('_source.Value'), color = "black", label="Centru4 PM10 sensor")
plt.xlabel("TimeStamp")
plt.ylabel("Value")
plt.title("Last 10000 values for PM10 in Carrefour-AFI-Gara-Centru4")
plt.legend()
plt.savefig('plots_updated/PM10_C-A-G-C4.jpg', bbox_inches = 'tight')
plt.show()

# %%
# pm10_afi.head(30)
pm10_gara.tail(10)
# Out:
#      _source.Source _source.Sensor  _source.Value  _source.LocationLat  \
# 8921           Waqi           pm10           25.0            45.659833
# 9026           Waqi           pm10           26.0            45.659833
# 9138           Waqi           pm10           26.0            45.659833
# 9233           Waqi           pm10           26.0            45.659833
# 9327           Waqi           pm10           26.0            45.659833
# 9423           Waqi           pm10           25.0            45.659833
# 9503           Waqi           pm10           25.0            45.659833
# 9592           Waqi           pm10           24.0            45.659833
# 9730           Waqi           pm10           24.0            45.659833
# 9935           Waqi           pm10           23.0            45.659833
#
#       _source.LocationLong  _source.TimeStamp _source.Measurement  \
# 8921             25.614488      1648166400000               µg/m3
# 9026             25.614488      1648162800000               µg/m3
# 9138             25.614488      1648159200000               µg/m3
# 9233             25.614488      1648155600000               µg/m3
# 9327             25.614488      1648152000000               µg/m3
# 9423             25.614488      1648148400000               µg/m3
# 9503             25.614488      1648144800000               µg/m3
# 9592             25.614488      1648141200000               µg/m3
# 9730             25.614488      1648137600000               µg/m3
# 9935             25.614488      1648134000000               µg/m3
#
#        LocationId LocationName
# 8921  712743216.0         Gara
# 9026  712743216.0         Gara
# 9138  712743216.0         Gara
# 9233  712743216.0         Gara
# 9327  712743216.0         Gara
# 9423  712743216.0         Gara
# 9503  712743216.0         Gara
# 9592  712743216.0         Gara
# 9730  712743216.0         Gara
# 9935  712743216.0         Gara

# %%
train = pm10_afi[pm10_afi.get('_source.TimeStamp') < 1648123156000]
test = pm10_afi[pm10_afi.get('_source.TimeStamp') >= 1648123156000]

import matplotlib.pyplot as plt
plt.close("all")
plt.figure(figsize=(20,10))
plt.plot(train.get('_source.TimeStamp'), train.get('_source.Value'), color = "black", label = "Training")
plt.plot(test.get('_source.TimeStamp'), test.get('_source.Value'), color = "red", label = "Testing")
plt.xlabel("TimeStamp")
plt.ylabel("Value")
plt.title("Train/Test split for PM10 in AFI")
plt.legend()
plt.savefig('plots_updated/PM10_AFI_Split.jpg', bbox_inches = 'tight')
plt.show()

# %%
pm10_afi = pm10[pm10.get('LocationName') == 'AFI']
train = pm10_afi[pm10_afi.index < 8000]
test = pm10_afi[pm10_afi.index >= 8000]

from statsmodels.tsa.statespace.sarimax import SARIMAX
y = train['_source.Value']

ARMAmodel = SARIMAX(y, order=(1,0,1))
ARMAmodel = ARMAmodel.fit()
y_pred = ARMAmodel.get_forecast(len(test.index))
y_pred_df = y_pred.conf_int(alpha=0.05)
y_pred_df['Predictions'] = ARMAmodel.predict(start = y_pred_df.index[0], end = y_pred_df.index[-1])
y_pred_df.index = test.index
y_pred_out = y_pred_df["Predictions"]


import matplotlib.pyplot as plt
plt.close("all")
plt.figure(figsize=(20,10))
plt.plot(train.index, train.get('_source.Value'), color = "black", label = "Training")
plt.plot(test.index, test.get('_source.Value'), color = "red", label = "Testing")
plt.xlabel("Index")
plt.ylabel("Value")
plt.title("Train/Test/Predictions for PM10 in AFI")
plt.plot(y_pred_out, color='green', label = 'ARMA Predictions')
plt.legend()
plt.savefig('plots_updated/PM10_AFI_ARMA_Prediction.jpg', bbox_inches = 'tight')
plt.show()


import numpy as np
from sklearn.metrics import mean_squared_error

arma_rmse = np.sqrt(mean_squared_error(test["_source.Value"].values, y_pred_df["Predictions"]))
print("RMSE: ", arma_rmse)
# Out:
# C:\VALI\Programs\Miniconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\VALI\Programs\Miniconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\VALI\Programs\Miniconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# C:\VALI\Programs\Miniconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# RMSE:  13.937689227210766

# %%
pm10_afi = pm10[pm10.get('LocationName') == 'AFI']
train = pm10_afi[pm10_afi.index < 8000]
test = pm10_afi[pm10_afi.index >= 8000]

from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.arima.model import ARIMA
y = train['_source.Value']

ARMAmodel = ARIMA(y, order=(2,2,2))
ARMAmodel = ARMAmodel.fit()
y_pred = ARMAmodel.get_forecast(len(test.index))
y_pred_df = y_pred.conf_int(alpha=0.05)
y_pred_df['Predictions'] = ARMAmodel.predict(start = y_pred_df.index[0], end = y_pred_df.index[-1])
y_pred_df.index = test.index
y_pred_out = y_pred_df["Predictions"]


import matplotlib.pyplot as plt
plt.close("all")
plt.figure(figsize=(20,10))
plt.plot(train.index, train.get('_source.Value'), color = "black", label = "Training")
plt.plot(test.index, test.get('_source.Value'), color = "red", label = "Testing")
plt.xlabel("Index")
plt.ylabel("Value")
plt.title("Train/Test/Predictions for PM10 in AFI")
plt.plot(y_pred_out, color='purple', label = 'ARIMA Predictions')
plt.legend()
plt.savefig('plots_updated/PM10_AFI_ARIMA_Prediction.jpg', bbox_inches = 'tight')
plt.show()


import numpy as np
from sklearn.metrics import mean_squared_error

arima_rmse = np.sqrt(mean_squared_error(test["_source.Value"].values, y_pred_df["Predictions"]))
print("RMSE: ", arima_rmse)
# Out:
# C:\VALI\Programs\Miniconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\VALI\Programs\Miniconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\VALI\Programs\Miniconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\VALI\Programs\Miniconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# C:\VALI\Programs\Miniconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# C:\VALI\Programs\Miniconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# C:\VALI\Programs\Miniconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# RMSE:  7.407728621220632

# %%
pm10_afi = pm10[pm10.get('LocationName') == 'AFI']
train = pm10_afi[pm10_afi.index < 8000]
test = pm10_afi[pm10_afi.index >= 8000]

from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.arima.model import ARIMA
y = train['_source.Value']

ARMAmodel = ARIMA(y, order=(2,3,2))
ARMAmodel = ARMAmodel.fit()
y_pred = ARMAmodel.get_forecast(len(test.index))
y_pred_df = y_pred.conf_int(alpha=0.05)
y_pred_df['Predictions'] = ARMAmodel.predict(start = y_pred_df.index[0], end = y_pred_df.index[-1])
y_pred_df.index = test.index
y_pred_out = y_pred_df["Predictions"]


import matplotlib.pyplot as plt
plt.close("all")
plt.figure(figsize=(20,10))
plt.plot(train.index, train.get('_source.Value'), color = "black", label = "Training")
plt.plot(test.index, test.get('_source.Value'), color = "red", label = "Testing")
plt.xlabel("Index")
plt.ylabel("Value")
plt.title("Train/Test/Predictions for PM10 in AFI")
plt.plot(y_pred_out, color='purple', label = 'ARIMA Predictions2')
plt.legend()
plt.savefig('plots_updated/PM10_AFI_ARIMA_Prediction2.jpg', bbox_inches = 'tight')
plt.show()


import numpy as np
from sklearn.metrics import mean_squared_error

arima_rmse2 = np.sqrt(mean_squared_error(test["_source.Value"].values, y_pred_df["Predictions"]))
print("RMSE: ", arima_rmse2)
# Out:
# C:\VALI\Programs\Miniconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\VALI\Programs\Miniconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\VALI\Programs\Miniconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\VALI\Programs\Miniconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# C:\VALI\Programs\Miniconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# RMSE:  12.355223934399707

# %%
pm10_afi = pm10[pm10.get('LocationName') == 'AFI']
train = pm10_afi[pm10_afi.index < 8000]
test = pm10_afi[pm10_afi.index >= 8000]

from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.arima.model import ARIMA
y = train['_source.Value']

ARMAmodel = ARIMA(y, order=(9,3,6))
ARMAmodel = ARMAmodel.fit()
y_pred = ARMAmodel.get_forecast(len(test.index))
y_pred_df = y_pred.conf_int(alpha=0.05)
y_pred_df['Predictions'] = ARMAmodel.predict(start = y_pred_df.index[0], end = y_pred_df.index[-1])
y_pred_df.index = test.index
y_pred_out = y_pred_df["Predictions"]


import matplotlib.pyplot as plt
plt.close("all")
plt.figure(figsize=(20,10))
plt.plot(train.index, train.get('_source.Value'), color = "black", label = "Training")
plt.plot(test.index, test.get('_source.Value'), color = "red", label = "Testing")
plt.xlabel("Index")
plt.ylabel("Value")
plt.title("Train/Test/Predictions for PM10 in AFI")
plt.plot(y_pred_out, color='purple', label = 'ARIMA Predictions3')
plt.legend()
plt.savefig('plots_updated/PM10_AFI_ARIMA_Prediction3.jpg', bbox_inches = 'tight')
plt.show()


import numpy as np
from sklearn.metrics import mean_squared_error

arima_rmse3 = np.sqrt(mean_squared_error(test["_source.Value"].values, y_pred_df["Predictions"]))
print("RMSE: ", arima_rmse3)
# Out:
# C:\VALI\Programs\Miniconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\VALI\Programs\Miniconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\VALI\Programs\Miniconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\VALI\Programs\Miniconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# C:\VALI\Programs\Miniconda3\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\VALI\Programs\Miniconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# C:\VALI\Programs\Miniconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# RMSE:  14.00422546066787
