# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
dataframe = pd.read_csv("csv/82000278_Toamnei_2022_05.csv")
dataframe_size = len(dataframe.index)
train = dataframe[dataframe.index < dataframe_size*(85/100)]
test = dataframe[dataframe.index >= dataframe_size*(85/100)]


y_train = train['pm10']
y_test = test['pm10']
x_train = train['time']
x_test = test['time']
# Convert to numpy array
x_train = np.array(x_train)
x_test = np.array(x_test)
y_train = np.array(y_train)
y_test = np.array(y_test)
# Reshape
x_train = np.reshape(x_train, (-1,1))
x_test = np.reshape(x_test, (-1,1))
y_train = np.reshape(y_train, (-1,1))
y_test = np.reshape(y_test, (-1,1))


from sklearn.ensemble import RandomForestRegressor
clf = RandomForestRegressor()
clf.fit(x_train, y_train)
y_pred = clf.predict(x_test)


plt.figure(figsize=(30,15))
plt.plot(x_train, y_train, color = 'black', label= 'Training')
plt.plot(x_test, y_test, color = 'blue', label = 'Testing')
plt.plot(x_test, y_pred, color = 'red', label = 'Random Forest Regression')
plt.title('Random Forest Regression - pm10 values - May 2022 - Toamnei', fontsize=18)
plt.xlabel('TimeStamp', fontsize=16)
plt.ylabel('Value', fontsize=16)
plt.legend(fontsize=16)
plt.savefig('simulations/CSV_pm10_2022-05_RandomForest-split.jpg', bbox_inches = 'tight')
plt.show()


import numpy as np
from sklearn.metrics import mean_squared_error
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
print("RMSE: ", rmse)
# Out:
# C:\Users\Valentin.Adam\AppData\Local\Temp\ipykernel_17012\242401618.py:25: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   clf.fit(x_train, y_train)
# RMSE:  4.536094901643603

# %%
dataframe = pd.read_csv("csv/82000278_Toamnei_2022_05.csv")
dataframe_size = len(dataframe.index)
train = dataframe[dataframe.index < dataframe_size*(85/100)]
test = dataframe[dataframe.index >= dataframe_size*(85/100)]


y_train = train['pm10']
y_test = test['pm10']
x_train = train['time']
x_test = test['time']
# Convert to numpy array
x_train = np.array(x_train)
x_test = np.array(x_test)
y_train = np.array(y_train)
y_test = np.array(y_test)
# Reshape
x_train = np.reshape(x_train, (-1,1))
x_test = np.reshape(x_test, (-1,1))
y_train = np.reshape(y_train, (-1,1))
y_test = np.reshape(y_test, (-1,1))

# {'n_estimators': 300, 'min_samples_split': 6, 'min_samples_leaf': 2, 'max_features': 'auto', 'max_depth': None, 'bootstrap': True}
from sklearn.ensemble import RandomForestRegressor
clf = RandomForestRegressor(bootstrap=True, max_depth=None, max_features='auto', min_samples_leaf=2, min_samples_split=6, n_estimators=300)
clf.fit(x_train, y_train)
y_pred = clf.predict(x_test)


plt.figure(figsize=(30,15))
plt.plot(x_train, y_train, color = 'black', label= 'Training')
plt.plot(x_test, y_test, color = 'blue', label = 'Testing')
plt.plot(x_test, y_pred, color = 'red', label = 'Random Forest Regression RS')
plt.title('Random Forest Regression - pm10 values - May 2022 - Toamnei', fontsize=18)
plt.xlabel('TimeStamp', fontsize=16)
plt.ylabel('Value', fontsize=16)
plt.legend(fontsize=16)
plt.savefig('simulations/CSV_pm10_2022-05_RandomForest-RS-split.jpg', bbox_inches = 'tight')
plt.show()


import numpy as np
from sklearn.metrics import mean_squared_error
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
print("RMSE: ", rmse)
# Out:
# C:\Users\Valentin.Adam\AppData\Local\Temp\ipykernel_17012\2685056799.py:25: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   clf.fit(x_train, y_train)
# c:\VALI\Programs\Miniconda3\envs\myenv\lib\site-packages\sklearn\ensemble\_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# RMSE:  4.579151838356874

# %%
dataframe = pd.read_csv("csv/82000278_Toamnei_2022_05.csv")
dataframe_size = len(dataframe.index)
train = dataframe[dataframe.index < dataframe_size*(85/100)]
test = dataframe[dataframe.index >= dataframe_size*(85/100)]


y_train = train['pm10']
y_test = test['pm10']
x_train = train['time']
x_test = test['time']
# Convert to numpy array
x_train = np.array(x_train)
x_test = np.array(x_test)
y_train = np.array(y_train)
y_test = np.array(y_test)
# Reshape
x_train = np.reshape(x_train, (-1,1))
x_test = np.reshape(x_test, (-1,1))
y_train = np.reshape(y_train, (-1,1))
y_test = np.reshape(y_test, (-1,1))

# {'bootstrap': True, 'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 6, 'n_estimators': 400}
from sklearn.ensemble import RandomForestRegressor
clf = RandomForestRegressor(bootstrap=True, max_depth=None, max_features='auto', min_samples_leaf=1, min_samples_split=6, n_estimators=400)
clf.fit(x_train, y_train)
y_pred = clf.predict(x_test)


plt.figure(figsize=(30,15))
plt.plot(x_train, y_train, color = 'black', label= 'Training')
plt.plot(x_test, y_test, color = 'blue', label = 'Testing')
plt.plot(x_test, y_pred, color = 'red', label = 'Random Forest Regression GS')
plt.title('Random Forest Regression - pm10 values - May 2022 - Toamnei', fontsize=18)
plt.xlabel('TimeStamp', fontsize=16)
plt.ylabel('Value', fontsize=16)
plt.legend(fontsize=16)
plt.savefig('simulations/CSV_pm10_2022-05_RandomForest-GS-split.jpg', bbox_inches = 'tight')
plt.show()


import numpy as np
from sklearn.metrics import mean_squared_error
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
print("RMSE: ", rmse)
# Out:
# C:\Users\Valentin.Adam\AppData\Local\Temp\ipykernel_17012\394536679.py:25: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   clf.fit(x_train, y_train)
# c:\VALI\Programs\Miniconda3\envs\myenv\lib\site-packages\sklearn\ensemble\_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# RMSE:  4.5822074161383535

# %%
dataframe = pd.read_csv("csv/82000278_Toamnei_2022_05.csv")
dataframe_size = len(dataframe.index)
train = dataframe[dataframe.index < dataframe_size*(85/100)]
test = dataframe[dataframe.index >= dataframe_size*(85/100)]


y_train = train['pm10']
y_test = test['pm10']
x_train = train['time']
x_test = test['time']
# Convert to numpy array
x_train = np.array(x_train)
x_test = np.array(x_test)
y_train = np.array(y_train)
y_test = np.array(y_test)
# Reshape
x_train = np.reshape(x_train, (-1,1))
x_test = np.reshape(x_test, (-1,1))
y_train = np.reshape(y_train, (-1,1))
y_test = np.reshape(y_test, (-1,1))


from sklearn.linear_model import ARDRegression
clf = ARDRegression(compute_score=True)
clf.fit(x_train, y_train)
y_pred = clf.predict(x_test)


plt.figure(figsize=(30,15))
plt.plot(x_train, y_train, color = 'black', label= 'Training')
plt.plot(x_test, y_test, color = 'blue', label = 'Testing')
plt.plot(x_test, y_pred, color = 'red', label = 'ARD Regression')
plt.title('ARD Regression - pm10 values - May 2022 - Toamnei', fontsize=18)
plt.xlabel('TimeStamp', fontsize=16)
plt.ylabel('Value', fontsize=16)
plt.legend(fontsize=16)
plt.savefig('simulations/CSV_pm10_2022-05_ARD-split.jpg', bbox_inches = 'tight')
plt.show()


import numpy as np
from sklearn.metrics import mean_squared_error
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
print("RMSE: ", rmse)
# Out:
# c:\VALI\Programs\Miniconda3\envs\myenv\lib\site-packages\sklearn\utils\validation.py:1111: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# RMSE:  4.78131283598714

# %%
dataframe = pd.read_csv("csv/82000278_Toamnei_2022_05.csv")
dataframe_size = len(dataframe.index)
train = dataframe[dataframe.index < dataframe_size*(85/100)]
test = dataframe[dataframe.index >= dataframe_size*(85/100)]


y_train = train['pm10']
y_test = test['pm10']
x_train = train['time']
x_test = test['time']
# Convert to numpy array
x_train = np.array(x_train)
x_test = np.array(x_test)
y_train = np.array(y_train)
y_test = np.array(y_test)
# Reshape
x_train = np.reshape(x_train, (-1,1))
x_test = np.reshape(x_test, (-1,1))
y_train = np.reshape(y_train, (-1,1))
y_test = np.reshape(y_test, (-1,1))


from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import AdaBoostRegressor
rng = np.random.RandomState(1)
clf = AdaBoostRegressor(DecisionTreeRegressor(max_depth=4), n_estimators=300, random_state=rng)
clf.fit(x_train, y_train)
y_pred = clf.predict(x_test)


plt.figure(figsize=(30,15))
plt.plot(x_train, y_train, color = 'black', label= 'Training')
plt.plot(x_test, y_test, color = 'blue', label = 'Testing')
plt.plot(x_test, y_pred, color = 'red', label = 'Decision Tree Regression')
plt.title('Decision Tree Regression - pm10 values - May 2022 - Toamnei', fontsize=18)
plt.xlabel('TimeStamp', fontsize=16)
plt.ylabel('Value', fontsize=16)
plt.legend(fontsize=16)
plt.savefig('simulations/CSV_pm10_2022-05_DecisionTree-split.jpg', bbox_inches = 'tight')
plt.show()


import numpy as np
from sklearn.metrics import mean_squared_error
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
print("RMSE: ", rmse)
# Out:
# c:\VALI\Programs\Miniconda3\envs\myenv\lib\site-packages\sklearn\utils\validation.py:1111: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# RMSE:  4.509401638887514

# %%
dataframe = pd.read_csv("csv/82000278_Toamnei_2022_05.csv")
dataframe_size = len(dataframe.index)
train = dataframe[dataframe.index < dataframe_size*(85/100)]
test = dataframe[dataframe.index >= dataframe_size*(85/100)]


y_train = train['pm10']
y_test = test['pm10']
x_train = train['time']
x_test = test['time']
# Convert to numpy array
x_train = np.array(x_train)
x_test = np.array(x_test)
y_train = np.array(y_train)
y_test = np.array(y_test)
# Reshape
x_train = np.reshape(x_train, (-1,1))
x_test = np.reshape(x_test, (-1,1))
y_train = np.reshape(y_train, (-1,1))
y_test = np.reshape(y_test, (-1,1))


from sklearn.ensemble import GradientBoostingRegressor
clf = GradientBoostingRegressor()
clf.fit(x_train, y_train)
y_pred = clf.predict(x_test)


plt.figure(figsize=(30,15))
plt.plot(x_train, y_train, color = 'black', label= 'Training')
plt.plot(x_test, y_test, color = 'blue', label = 'Testing')
plt.plot(x_test, y_pred, color = 'red', label = 'Gradient Boosting Regression')
plt.title('Gradient Boosting Regression - pm10 values - May 2022 - Toamnei', fontsize=18)
plt.xlabel('TimeStamp', fontsize=16)
plt.ylabel('Value', fontsize=16)
plt.legend(fontsize=16)
plt.savefig('simulations/CSV_pm10_2022-05_GradientBoosting-split.jpg', bbox_inches = 'tight')
plt.show()


import numpy as np
from sklearn.metrics import mean_squared_error
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
print("RMSE: ", rmse)
# Out:
# c:\VALI\Programs\Miniconda3\envs\myenv\lib\site-packages\sklearn\ensemble\_gb.py:570: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# RMSE:  4.326727227080695

# %%
dataframe = pd.read_csv("csv/82000278_Toamnei_2022_05.csv")
dataframe_size = len(dataframe.index)
train = dataframe[dataframe.index < dataframe_size*(85/100)]
test = dataframe[dataframe.index >= dataframe_size*(85/100)]


y_train = train['pm10']
y_test = test['pm10']
x_train = train['time']
x_test = test['time']
# Convert to numpy array
x_train = np.array(x_train)
x_test = np.array(x_test)
y_train = np.array(y_train)
y_test = np.array(y_test)
# Reshape
x_train = np.reshape(x_train, (-1,1))
x_test = np.reshape(x_test, (-1,1))
y_train = np.reshape(y_train, (-1,1))
y_test = np.reshape(y_test, (-1,1))


from sklearn.linear_model import LinearRegression
clf = LinearRegression()
clf.fit(x_train, y_train)
y_pred = clf.predict(x_test)


plt.figure(figsize=(30,15))
plt.plot(x_train, y_train, color = 'black', label= 'Training')
plt.plot(x_test, y_test, color = 'blue', label = 'Testing')
plt.plot(x_test, y_pred, color = 'red', label = 'Linear Regression')
plt.title('Linear Regression - pm10 values - May 2022 - Toamnei', fontsize=18)
plt.xlabel('TimeStamp', fontsize=16)
plt.ylabel('Value', fontsize=16)
plt.legend(fontsize=16)
plt.savefig('simulations/CSV_pm10_2022-05_Linear-split.jpg', bbox_inches = 'tight')
plt.show()


import numpy as np
from sklearn.metrics import mean_squared_error
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
print("RMSE: ", rmse)
# Out:
# RMSE:  4.137035494130613

# %%
dataframe = pd.read_csv("csv/82000278_Toamnei_2022_05.csv")
dataframe_size = len(dataframe.index)
train = dataframe[dataframe.index < dataframe_size*(85/100)]
test = dataframe[dataframe.index >= dataframe_size*(85/100)]


y_train = train['pm10']
y_test = test['pm10']
x_train = train['time']
x_test = test['time']
# Convert to numpy array
x_train = np.array(x_train)
x_test = np.array(x_test)
y_train = np.array(y_train)
y_test = np.array(y_test)
# Reshape
x_train = np.reshape(x_train, (-1,1))
x_test = np.reshape(x_test, (-1,1))
y_train = np.reshape(y_train, (-1,1))
y_test = np.reshape(y_test, (-1,1))


from sklearn.isotonic import IsotonicRegression
clf = IsotonicRegression()
clf.fit(x_train, y_train)
y_pred = clf.predict(x_test)


plt.figure(figsize=(30,15))
plt.plot(x_train, y_train, color = 'black', label= 'Training')
plt.plot(x_test, y_test, color = 'blue', label = 'Testing')
plt.plot(x_test, y_pred, color = 'red', label = 'Random Forest Regression')
plt.title('Random Forest Regression - pm10 values - May 2022 - Toamnei', fontsize=18)
plt.xlabel('TimeStamp', fontsize=16)
plt.ylabel('Value', fontsize=16)
plt.legend(fontsize=16)
plt.savefig('simulations/CSV_pm10_2022-05_RandomForest-split.jpg', bbox_inches = 'tight')
plt.show()


import numpy as np
from sklearn.metrics import mean_squared_error
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
print("RMSE: ", rmse)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\VALI\Repos\Licenta_Poluare\poluare_test21_simulations-split_pm10.ipynb Cell 7' in <cell line: 25>()
#      <a href='vscode-notebook-cell:/c%3A/VALI/Repos/Licenta_Poluare/poluare_test21_simulations-split_pm10.ipynb#ch0000006?line=22'>23</a> from sklearn.isotonic import IsotonicRegression
#      <a href='vscode-notebook-cell:/c%3A/VALI/Repos/Licenta_Poluare/poluare_test21_simulations-split_pm10.ipynb#ch0000006?line=23'>24</a> clf = IsotonicRegression()
# ---> <a href='vscode-notebook-cell:/c%3A/VALI/Repos/Licenta_Poluare/poluare_test21_simulations-split_pm10.ipynb#ch0000006?line=24'>25</a> clf.fit(x_train, y_train)
#      <a href='vscode-notebook-cell:/c%3A/VALI/Repos/Licenta_Poluare/poluare_test21_simulations-split_pm10.ipynb#ch0000006?line=25'>26</a> y_pred = clf.predict(x_test)
# ...
