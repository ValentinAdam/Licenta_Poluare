# %%
import pandas as pd

# %%
import requests

# %%
from requests.auth import HTTPBasicAuth
auth = HTTPBasicAuth('elastic', 'AWbtmGda2Q7BI2bYpdjyF4qd')
url = 'https://8f9677360fc34e2eb943d737b2597c7b.us-east-1.aws.found.io:9243/brasov-dev/_search?size=10000&q=*&sort=TimeStamp:desc'

# %%
response = requests.get(url=url, auth=auth)

# %%
response
# Out:
# <Response [200]>

# %%
import json
data = json.loads(response.text)

# %%
data
# Out:
# {'took': 552,
#  'timed_out': False,
#  '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 10000, 'relation': 'gte'},
#   'max_score': None,
#   'hits': [{'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'vEGEwH8Bwa_bL2zRyg3r',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm1',
#      'Value': 13,
#      'LocationLat': 45.589267,
#      'LocationLong': 25.46445,
#      'TimeStamp': 1648202399000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648202399000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'vUGEwH8Bwa_bL2zRyg31',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm10',
#      'Value': 24,
#      'LocationLat': 45.589267,
#      'LocationLong': 25.46445,
#      'TimeStamp': 1648202399000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648202399000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
# ...

# %%
data.keys()
# Out:
# dict_keys(['took', 'timed_out', '_shards', 'hits'])

# %%
data['hits']
# Out:
# {'total': {'value': 10000, 'relation': 'gte'},
#  'max_score': None,
#  'hits': [{'_index': 'brasov-dev',
#    '_type': '_doc',
#    '_id': 'vEGEwH8Bwa_bL2zRyg3r',
#    '_score': None,
#    '_source': {'Source': 'UradMonitor',
#     'Sensor': 'pm1',
#     'Value': 13,
#     'LocationLat': 45.589267,
#     'LocationLong': 25.46445,
#     'TimeStamp': 1648202399000,
#     'Measurement': 'µg/m3'},
#    'sort': [1648202399000]},
#   {'_index': 'brasov-dev',
#    '_type': '_doc',
#    '_id': 'vUGEwH8Bwa_bL2zRyg31',
#    '_score': None,
#    '_source': {'Source': 'UradMonitor',
#     'Sensor': 'pm10',
#     'Value': 24,
#     'LocationLat': 45.589267,
#     'LocationLong': 25.46445,
#     'TimeStamp': 1648202399000,
#     'Measurement': 'µg/m3'},
#    'sort': [1648202399000]},
#   {'_index': 'brasov-dev',
#    '_type': '_doc',
#    '_id': 'y0GEwH8Bwa_bL2zRyw0r',
#    '_score': None,
#    '_source': {'Source': 'UradMonitor',
#     'Sensor': 'pm25',
#     'Value': 20,
# ...

# %%
from pandas import json_normalize
df2 = json_normalize(data['hits']['hits'])

# %%
df2
# Out:
#           _index _type                   _id _score             sort  \
# 0     brasov-dev  _doc  vEGEwH8Bwa_bL2zRyg3r   None  [1648202399000]
# 1     brasov-dev  _doc  vUGEwH8Bwa_bL2zRyg31   None  [1648202399000]
# 2     brasov-dev  _doc  y0GEwH8Bwa_bL2zRyw0r   None  [1648202399000]
# 3     brasov-dev  _doc  XUGEwH8Bwa_bL2zRxg3m   None  [1648202397000]
# 4     brasov-dev  _doc  p0GEwH8Bwa_bL2zRyg1k   None  [1648202397000]
# ...          ...   ...                   ...    ...              ...
# 9995  brasov-dev  _doc  JEChqn8Bwa_bL2zRw8ZH   None  [1647835157000]
# 9996  brasov-dev  _doc  70Chqn8Bwa_bL2zRwMWI   None  [1647835156000]
# 9997  brasov-dev  _doc  8UChqn8Bwa_bL2zRwMWJ   None  [1647835156000]
# 9998  brasov-dev  _doc  8kChqn8Bwa_bL2zRwMWK   None  [1647835156000]
# 9999  brasov-dev  _doc  A0Chqn8Bwa_bL2zRwcbd   None  [1647835156000]
#
#      _source.Source _source.Sensor  _source.Value  _source.LocationLat  \
# ...

# %%
hist = df2.get('_source.Sensor').hist()

# %%
pm25 = df2[df2.get('_source.Sensor') == 'pm25']
pm25.head(24)
# Out:
#         _index _type                   _id _score             sort  \
# 2   brasov-dev  _doc  y0GEwH8Bwa_bL2zRyw0r   None  [1648202399000]
# 5   brasov-dev  _doc  q0GEwH8Bwa_bL2zRyg17   None  [1648202397000]
# 6   brasov-dev  _doc  Y0GEwH8Bwa_bL2zRxw3z   None  [1648202396000]
# 10  brasov-dev  _doc  okGEwH8Bwa_bL2zRyg1g   None  [1648202388000]
# 12  brasov-dev  _doc  gEGEwH8Bwa_bL2zRyQ0Z   None  [1648202387000]
# 16  brasov-dev  _doc  z0GEwH8Bwa_bL2zRyw06   None  [1648202381000]
# 22  brasov-dev  _doc  iEGEwH8Bwa_bL2zRyQ1W   None  [1648202378000]
# 25  brasov-dev  _doc  XkGEwH8Bwa_bL2zRxw2G   None  [1648202377000]
# 27  brasov-dev  _doc  X0GEwH8Bwa_bL2zRxw3D   None  [1648202373000]
# 31  brasov-dev  _doc  lEGEwH8Bwa_bL2zRyQ2s   None  [1648202369000]
# 33  brasov-dev  _doc  f0GEwH8Bwa_bL2zRyA3u   None  [1648202362000]
# 38  brasov-dev  _doc  pkGEwH8Bwa_bL2zRyg1j   None  [1648202361000]
# 39  brasov-dev  _doc  AUGEwH8Bwa_bL2zR0g5K   None  [1648202357000]
# ...

# %%
print('Lungime dataframe: ',len(df2))
print('Lungime dataframe pm 1: ',len(pm25))
# Out:
# Lungime dataframe:  10000
# Lungime dataframe pm 1:  2386

# %%
print(f"Number of no data values per column:\n{pm25.isna().sum()}")
# Out:
# Number of no data values per column:
# _index                     0
# _type                      0
# _id                        0
# _score                  2386
# sort                       0
# _source.Source             0
# _source.Sensor             0
# _source.Value              0
# _source.LocationLat        0
# _source.LocationLong       0
# _source.TimeStamp          0
# _source.Measurement        0
# dtype: int64

# %%
# pm25_v2 = pm25.drop('_score', inplace=True, axis=1) #method 1
# pm25_v2 = pm25.drop('_score', axis=1) #method 2
# pm25_v2 = pm25.loc[:, pm25.columns != '_score'] #method3
pm25_v2 = pm25[[i for i in list(pm25.columns) if i != '_score']] #method4
pm25_v2.head(7)
# Out:
#         _index _type                   _id             sort _source.Source  \
# 2   brasov-dev  _doc  y0GEwH8Bwa_bL2zRyw0r  [1648202399000]    UradMonitor
# 5   brasov-dev  _doc  q0GEwH8Bwa_bL2zRyg17  [1648202397000]    UradMonitor
# 6   brasov-dev  _doc  Y0GEwH8Bwa_bL2zRxw3z  [1648202396000]    UradMonitor
# 10  brasov-dev  _doc  okGEwH8Bwa_bL2zRyg1g  [1648202388000]    UradMonitor
# 12  brasov-dev  _doc  gEGEwH8Bwa_bL2zRyQ0Z  [1648202387000]    UradMonitor
# 16  brasov-dev  _doc  z0GEwH8Bwa_bL2zRyw06  [1648202381000]    UradMonitor
# 22  brasov-dev  _doc  iEGEwH8Bwa_bL2zRyQ1W  [1648202378000]    UradMonitor
#
#    _source.Sensor  _source.Value  _source.LocationLat  _source.LocationLong  \
# 2            pm25           20.0            45.589267             25.464450
# 5            pm25           18.0            45.704032             25.640955
# 6            pm25           22.0            45.653600             25.599000
# ...

# %%
print('Lungime dataframe: ', len(df2))
print('Lungime dataframe pm 1: ', len(pm25))
print('Lungime dataframe pm 1 - fara _score: ', len(pm25_v2))
# Out:
# Lungime dataframe:  10000
# Lungime dataframe pm 1:  2386
# Lungime dataframe pm 1 - fara _score:  2386

# %%
print(f"Number of no data values per column:\n{pm25_v2.isna().sum()}")
# Out:
# Number of no data values per column:
# _index                  0
# _type                   0
# _id                     0
# sort                    0
# _source.Source          0
# _source.Sensor          0
# _source.Value           0
# _source.LocationLat     0
# _source.LocationLong    0
# _source.TimeStamp       0
# _source.Measurement     0
# dtype: int64

# %%
import matplotlib.pyplot as plt
plt.close("all")
# fig = plt.figure(figsize=(20,10), frameon=True)
plt.figure(figsize=(20,10))
plt.plot(pm25_v2.get('_source.TimeStamp'), pm25_v2.get('_source.Value'))
plt.xlabel("TimeStamp")
plt.ylabel("Value")
plt.title("Last 10000 values for PM25")
plt.savefig('plots/PM25.jpg', dpi = 100, bbox_inches = 'tight')
# fig.savefig('plots/PM25.jpg', dpi = 100, bbox_inches = 'tight')
plt.show()

# %%
pm25_v2.groupby(['_source.LocationLat','_source.LocationLong']).size().reset_index().rename(columns={0:'count'})
# Out:
#     _source.LocationLat  _source.LocationLong  count
# 0             45.393240             25.442933    102
# 1             45.589267             25.464450    103
# 2             45.614267             25.633250    103
# 3             45.623958             25.481535    103
# 4             45.641274             25.614817    103
# 5             45.642198             25.588532     27
# 6             45.645914             25.602642    101
# 7             45.646976             25.595224     99
# 8             45.651464             25.615426    103
# 9             45.653509             25.566120    103
# 10            45.653600             25.599000    103
# 11            45.656800             25.591700    103
# 12            45.657148             25.563752    103
# 13            45.657861             25.621916    103
# 14            45.665184             25.558891    102
# 15            45.673977             25.606484    103
# 16            45.676195             25.645632    103
# ...
