# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
dataframe = pd.read_csv("csv/82000278_Toamnei_CO2_2021_7_SHORT.csv")
dataframe
# Out:
#              time   latitude  longitude  altitude  co2
# 0      1625086823  45.651464  25.615426       100  553
# 1      1625086883  45.651464  25.615426       100  551
# 2      1625086943  45.651464  25.615426       100  551
# 3      1625087003  45.651464  25.615426       100  558
# 4      1625087063  45.651464  25.615426       100  559
# ...           ...        ...        ...       ...  ...
# 10494  1625716432  45.651464  25.615426       100  671
# 10495  1625716492  45.651464  25.615426       100  671
# 10496  1625716553  45.651464  25.615426       100  671
# 10497  1625716613  45.651464  25.615426       100  670
# 10498  1625716673  45.651464  25.615426       100  674
#
# [10499 rows x 5 columns]

# %%
X = dataframe[["time"]].values
Y = dataframe[["co2"]].values

# %%
i=0
x=[]
y=[]
for el in X:
    x.append(i)
    y.append(Y[i][0])
    i=i+1

# %%
#{'bootstrap': True, 'max_depth': 55, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 6, 'n_estimators': 600}
from sklearn.ensemble import RandomForestRegressor
clf = RandomForestRegressor(bootstrap=True, max_depth=55, max_features='sqrt', min_samples_leaf=5, min_samples_split=6, n_estimators=600).fit(X, y)
y_pred = clf.predict(X)

# %%
# {'n_estimators': 700, 'min_samples_split': 6, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'max_depth': 60, 'bootstrap': True}
from sklearn.ensemble import RandomForestRegressor
clf_2 = RandomForestRegressor(bootstrap=True, max_depth=60, max_features='sqrt', min_samples_leaf=4, min_samples_split=6, n_estimators=700).fit(X, y)
y_pred_2 = clf.predict(X)

# %%
plt.figure(figsize=(30,15))
plt.plot(X, y, color = 'blue', label="CO2 values")
plt.plot(X, y_pred, color = 'red', label = 'Forest Regression')
# plt.scatter(X, y, color = "green")
# plt.scatter(X, y_pred, color = "black")
plt.title('Forest Regression using Grid Search parameters on a week in July 2021 in Toamnei', fontsize=18)
plt.xlabel('TimeStamp', fontsize=16)
plt.ylabel('Value', fontsize=16)
plt.legend(fontsize=16)
plt.savefig('plots_from_csv/CO2_Toamnei_2021-07_Forest-GridSearch_1week.jpg', bbox_inches = 'tight')
plt.show()

# %%
plt.figure(figsize=(30,15))
plt.plot(X, y, color = 'yellow', label="CO2 values")
plt.plot(X, y_pred, color = 'red', label = 'Forest Regression using Grid Search')
plt.plot(X, y_pred_2, color = 'blue', label = 'Forest Regression using Random Search')
# plt.scatter(X, y, color = "green")
# plt.scatter(X, y_pred, color = "black")
plt.title('Forest Regression using Grid Search & Random Search parameters on a week in July 2021 in Toamnei', fontsize=18)
plt.xlabel('TimeStamp', fontsize=16)
plt.ylabel('Value', fontsize=16)
plt.legend(fontsize=16)
plt.savefig('plots_from_csv/CO2_Toamnei_2021-07_Forest-GS-RS_1week.jpg', bbox_inches = 'tight')
plt.show()
