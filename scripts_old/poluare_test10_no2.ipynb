# %%
import pandas as pd

# %%
import requests

# %%
from requests.auth import HTTPBasicAuth
auth = HTTPBasicAuth('elastic', 'AWbtmGda2Q7BI2bYpdjyF4qd')
url = 'https://8f9677360fc34e2eb943d737b2597c7b.us-east-1.aws.found.io:9243/brasov-dev/_search?size=10000&q=*&sort=TimeStamp:desc'

# %%
response = requests.get(url=url, auth=auth)

# %%
response
# Out:
# <Response [200]>

# %%
import json
data = json.loads(response.text)

# %%
data
# Out:
# {'took': 550,
#  'timed_out': False,
#  '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 10000, 'relation': 'gte'},
#   'max_score': None,
#   'hits': [{'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'vEGEwH8Bwa_bL2zRyg3r',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm1',
#      'Value': 13,
#      'LocationLat': 45.589267,
#      'LocationLong': 25.46445,
#      'TimeStamp': 1648202399000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648202399000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'vUGEwH8Bwa_bL2zRyg31',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm10',
#      'Value': 24,
#      'LocationLat': 45.589267,
#      'LocationLong': 25.46445,
#      'TimeStamp': 1648202399000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648202399000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
# ...

# %%
data.keys()
# Out:
# dict_keys(['took', 'timed_out', '_shards', 'hits'])

# %%
data['hits']
# Out:
# {'total': {'value': 10000, 'relation': 'gte'},
#  'max_score': None,
#  'hits': [{'_index': 'brasov-dev',
#    '_type': '_doc',
#    '_id': 'vEGEwH8Bwa_bL2zRyg3r',
#    '_score': None,
#    '_source': {'Source': 'UradMonitor',
#     'Sensor': 'pm1',
#     'Value': 13,
#     'LocationLat': 45.589267,
#     'LocationLong': 25.46445,
#     'TimeStamp': 1648202399000,
#     'Measurement': 'µg/m3'},
#    'sort': [1648202399000]},
#   {'_index': 'brasov-dev',
#    '_type': '_doc',
#    '_id': 'vUGEwH8Bwa_bL2zRyg31',
#    '_score': None,
#    '_source': {'Source': 'UradMonitor',
#     'Sensor': 'pm10',
#     'Value': 24,
#     'LocationLat': 45.589267,
#     'LocationLong': 25.46445,
#     'TimeStamp': 1648202399000,
#     'Measurement': 'µg/m3'},
#    'sort': [1648202399000]},
#   {'_index': 'brasov-dev',
#    '_type': '_doc',
#    '_id': 'y0GEwH8Bwa_bL2zRyw0r',
#    '_score': None,
#    '_source': {'Source': 'UradMonitor',
#     'Sensor': 'pm25',
#     'Value': 20,
# ...

# %%
from pandas import json_normalize
df2 = json_normalize(data['hits']['hits'])

# %%
df2
# Out:
#           _index _type                   _id _score             sort  \
# 0     brasov-dev  _doc  vEGEwH8Bwa_bL2zRyg3r   None  [1648202399000]
# 1     brasov-dev  _doc  vUGEwH8Bwa_bL2zRyg31   None  [1648202399000]
# 2     brasov-dev  _doc  y0GEwH8Bwa_bL2zRyw0r   None  [1648202399000]
# 3     brasov-dev  _doc  XUGEwH8Bwa_bL2zRxg3m   None  [1648202397000]
# 4     brasov-dev  _doc  p0GEwH8Bwa_bL2zRyg1k   None  [1648202397000]
# ...          ...   ...                   ...    ...              ...
# 9995  brasov-dev  _doc  JEChqn8Bwa_bL2zRw8ZH   None  [1647835157000]
# 9996  brasov-dev  _doc  70Chqn8Bwa_bL2zRwMWI   None  [1647835156000]
# 9997  brasov-dev  _doc  8UChqn8Bwa_bL2zRwMWJ   None  [1647835156000]
# 9998  brasov-dev  _doc  8kChqn8Bwa_bL2zRwMWK   None  [1647835156000]
# 9999  brasov-dev  _doc  A0Chqn8Bwa_bL2zRwcbd   None  [1647835156000]
#
#      _source.Source _source.Sensor  _source.Value  _source.LocationLat  \
# ...

# %%
hist = df2.get('_source.Sensor').hist()

# %%
no2 = df2[df2.get('_source.Sensor') == 'no2']
no2.head(100)
# Out:
#           _index _type                   _id _score             sort  \
# 82    brasov-dev  _doc  70GEwH8Bwa_bL2zRzw0Z   None  [1648198800000]
# 85    brasov-dev  _doc  80GEwH8Bwa_bL2zRzw0b   None  [1648198800000]
# 87    brasov-dev  _doc  9kGEwH8Bwa_bL2zRzw1H   None  [1648198800000]
# 89    brasov-dev  _doc  -EGEwH8Bwa_bL2zRzw1P   None  [1648198800000]
# 91    brasov-dev  _doc  -kGEwH8Bwa_bL2zRzw1V   None  [1648198800000]
# ...          ...   ...                   ...    ...              ...
# 2027  brasov-dev  _doc  okFxvH8Bwa_bL2zRIQD4   None  [1648130400000]
# 2029  brasov-dev  _doc  pEFxvH8Bwa_bL2zRIgCD   None  [1648130400000]
# 2031  brasov-dev  _doc  pkFxvH8Bwa_bL2zRIgCl   None  [1648130400000]
# 2036  brasov-dev  _doc  nEFxvH8Bwa_bL2zRIQAl   None  [1648130400000]
# 2038  brasov-dev  _doc  nkFxvH8Bwa_bL2zRIQDY   None  [1648130400000]
#
#      _source.Source _source.Sensor  _source.Value  _source.LocationLat  \
# ...

# %%
print('Lungime dataframe: ',len(df2))
print('Lungime dataframe pm 1: ',len(no2))
# Out:
# Lungime dataframe:  10000
# Lungime dataframe pm 1:  510

# %%
print(f"Number of no data values per column:\n{no2.isna().sum()}")
# Out:
# Number of no data values per column:
# _index                    0
# _type                     0
# _id                       0
# _score                  510
# sort                      0
# _source.Source            0
# _source.Sensor            0
# _source.Value             0
# _source.LocationLat       0
# _source.LocationLong      0
# _source.TimeStamp         0
# _source.Measurement       0
# dtype: int64

# %%
# no2_v2 = no2.drop('_score', inplace=True, axis=1) #method 1
# no2_v2 = no2.drop('_score', axis=1) #method 2
# no2_v2 = no2.loc[:, no2.columns != '_score'] #method3
no2_v2 = no2[[i for i in list(no2.columns) if i != '_score']] #method4
no2_v2.head(10)
# Out:
#          _index _type                   _id             sort _source.Source  \
# 82   brasov-dev  _doc  70GEwH8Bwa_bL2zRzw0Z  [1648198800000]           Waqi
# 85   brasov-dev  _doc  80GEwH8Bwa_bL2zRzw0b  [1648198800000]           Waqi
# 87   brasov-dev  _doc  9kGEwH8Bwa_bL2zRzw1H  [1648198800000]           Waqi
# 89   brasov-dev  _doc  -EGEwH8Bwa_bL2zRzw1P  [1648198800000]           Waqi
# 91   brasov-dev  _doc  -kGEwH8Bwa_bL2zRzw1V  [1648198800000]           Waqi
# 178  brasov-dev  _doc  QUFNwH8Bwa_bL2zR4A1T  [1648195200000]           Waqi
# 182  brasov-dev  _doc  RkFNwH8Bwa_bL2zR4A11  [1648195200000]           Waqi
# 185  brasov-dev  _doc  SEFNwH8Bwa_bL2zR4A17  [1648195200000]           Waqi
# 187  brasov-dev  _doc  SkFNwH8Bwa_bL2zR4Q3P  [1648195200000]           Waqi
# 188  brasov-dev  _doc  S0FNwH8Bwa_bL2zR4Q3Q  [1648195200000]           Waqi
#
#     _source.Sensor  _source.Value  _source.LocationLat  _source.LocationLong  \
# ...

# %%
print('Lungime dataframe: ', len(df2))
print('Lungime dataframe pm 1: ', len(no2))
print('Lungime dataframe pm 1 - fara _score: ', len(no2_v2))
# Out:
# Lungime dataframe:  10000
# Lungime dataframe pm 1:  510
# Lungime dataframe pm 1 - fara _score:  510

# %%
print(f"Number of no data values per column:\n{no2_v2.isna().sum()}")
# Out:
# Number of no data values per column:
# _index                  0
# _type                   0
# _id                     0
# sort                    0
# _source.Source          0
# _source.Sensor          0
# _source.Value           0
# _source.LocationLat     0
# _source.LocationLong    0
# _source.TimeStamp       0
# _source.Measurement     0
# dtype: int64

# %%
import matplotlib.pyplot as plt
plt.close("all")
# fig = plt.figure(figsize=(20,10), frameon=True)
plt.figure(figsize=(20,10))
plt.plot(no2_v2.get('_source.TimeStamp'), no2_v2.get('_source.Value'))
plt.xlabel("TimeStamp")
plt.ylabel("Value")
plt.title("Last 10000 values for NO2")
plt.savefig('plots/NO2.jpg', dpi = 100, bbox_inches = 'tight')
# fig.savefig('plots/NO2.jpg', dpi = 100, bbox_inches = 'tight')
plt.show()

# %%
no2_v2.groupby(['_source.LocationLat','_source.LocationLong']).size().reset_index().rename(columns={0:'count'})
# Out:
#    _source.LocationLat  _source.LocationLong  count
# 0            45.634330             25.633872    102
# 1            45.649117             25.604136    102
# 2            45.654271             25.624061    102
# 3            45.659833             25.614488    102
# 4            45.716700             25.633300    102
