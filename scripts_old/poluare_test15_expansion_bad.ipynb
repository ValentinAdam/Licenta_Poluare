# %%
import logging
import pandas as pd
import requests
import sys
import json

# %%
# import requests
# from requests.auth import HTTPBasicAuth
# auth = HTTPBasicAuth('elastic', 'AWbtmGda2Q7BI2bYpdjyF4qd')
# url = 'https://8f9677360fc34e2eb943d737b2597c7b.us-east-1.aws.found.io:9243/brasov-dev/_search?scroll=1m&size=10000&q=*&sort=TimeStamp:desc'

# %%
# import requests
# from requests.auth import HTTPBasicAuth
# auth = HTTPBasicAuth('elastic', 'AWbtmGda2Q7BI2bYpdjyF4qd')
# url = 'https://8f9677360fc34e2eb943d737b2597c7b.us-east-1.aws.found.io:9243/brasov-dev/_search?q=@version:2&scroll=2m'
# response = requests.get(url=url, auth=auth)

# data = json.loads(response.text) 

# # data
# sid = data['_scroll_id']
# scroll_size = data['hits']['total']
# print ("scroll size: " + str(scroll_size))
# print(scroll_size)
# print(sid)
# Out:
# scroll size: {'value': 0, 'relation': 'eq'}
# {'value': 0, 'relation': 'eq'}
# DXF1ZXJ5QW5kRmV0Y2gBAAAAAANhfykWbXNHVmhRVTFTME96UEV5V3BlNU9aZw==

# %%
# while (scroll_size['value'] > 0):
#     data = {"scroll" : "2m", "scroll_id" :  sid}
#     response = requests.post('https://8f9677360fc34e2eb943d737b2597c7b.us-east-1.aws.found.io:9243/scroll', data=data)
#     data = json.loads(response.text) 
#     # do something
#     sid = data['_scroll_id']
#     scroll_size = len(data['hits']['hits'])
#     print ("scroll size: " + str(scroll_size))

# %%
# def __init__(self, _username, _password, _elkUrl, _scrollUrl):
#     self._username = 'elastic'
#     self._password = 'AWbtmGda2Q7BI2bYpdjyF4qd'
#     self._elkUrl = "https://8f9677360fc34e2eb943d737b2597c7b.us-east-1.aws.found.io:9243/brasov-dev/_search?scroll=1m"
#     self._scrollUrl="https://8f9677360fc34e2eb943d737b2597c7b.us-east-1.aws.found.io:9243/brasov-dev/_search/scroll"

# # self._username = 'elastic'
# # self._password = 'AWbtmGda2Q7BI2bYpdjyF4qd'
# # self._elkUrl = "https://8f9677360fc34e2eb943d737b2597c7b.us-east-1.aws.found.io:9243/brasov-dev/_search?scroll=1m"
# # self._scrollUrl="https://8f9677360fc34e2eb943d737b2597c7b.us-east-1.aws.found.io:9243/brasov-dev/_search/scroll"

# def GetDataFromELK(self):
#     # implementing scroll and retrieving data from elk to get more than 100000 records at one search
#     # ref :https://www.elastic.co/guide/en/elasticsearch/reference/6.8/search-request-scroll.html
#     try:
#         dataFrame = pd.DataFrame()
#         if self._elkUrl is None:
#             raise ValueError("_elkUrl is missing")
#         if self._username is None:
#             raise ValueError("_userNmae for elk is missing")
#         if self._password is None:
#             raise ValueError("_password for elk is missing")
#         response = requests.post(self._elkUrl, json=self.body,
#                                  auth=(self._username, self._password))
#         response = response.json()
#         if response is None:
#             raise ValueError("response is missing")
#         sid = response['_scroll_id']
#         hits = response['hits']
#         total = hits["total"]
#         if total is None:
#             raise ValueError("total hits from ELK is none")
#         total_val = int(total['value'])
#         url = self._scrollUrl
#         if url is None:
#             raise ValueError("scroll url is missing")
#         # start scrolling 
#         while (total_val > 0):
#             # keep search context alive for 2m
#             scroll = '2m'
#             scroll_query = {"scroll": scroll, "scroll_id": sid}
#             response1 = requests.post(url, json=scroll_query,
#                                       auth=(self._username, self._password))
#             response1 = response1.json()
#             # The result from the above request includes a scroll_id, which should be passed to the scroll API in order to retrieve the next batch of results
#             sid = response1['_scroll_id']
#             hits = response1['hits']
#             data = response1['hits']['hits']
#             if len(data) > 0:
#                 cleanDataFrame = self.DataClean(data)
#                 dataFrame = dataFrame.append(cleanDataFrame)
#             total_val = len(response1['hits']['hits'])
#             num = len(dataFrame)
#         print('Total records recieved from ELK=', num)
#         return dataFrame
#     except Exception as e:
#         logging.error('Error while getting the data from elk', exc_info=e)
#         sys.exit()

# %%
# response = requests.get(url=url, auth=auth)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\VALI\Repos\Siemens_Stuff\Licenta\Pandas_Licenta\poluare_test15_expansion.ipynb Cell 4' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/VALI/Repos/Siemens_Stuff/Licenta/Pandas_Licenta/poluare_test15_expansion.ipynb#ch0000002?line=0'>1</a> # response = requests.get(url=url, auth=auth)
# ----> <a href='vscode-notebook-cell:/c%3A/VALI/Repos/Siemens_Stuff/Licenta/Pandas_Licenta/poluare_test15_expansion.ipynb#ch0000002?line=1'>2</a> dataFrame
#
# NameError: name 'dataFrame' is not defined

# %%
# response
# Out:
# <Response [200]>

# %%
# import json
# data = json.loads(response.text)

# %%
# data
# Out:
# {'_scroll_id': 'DXF1ZXJ5QW5kRmV0Y2gBAAAAAANhPKIWbXNHVmhRVTFTME96UEV5V3BlNU9aZw==',
#  'took': 865,
#  'timed_out': False,
#  '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 1823155, 'relation': 'eq'},
#   'max_score': None,
#   'hits': [{'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'IkEu0H8Bwa_bL2zRzUGI',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm1',
#      'Value': 13,
#      'LocationLat': 45.651464,
#      'LocationLong': 25.615426,
#      'TimeStamp': 1648465200000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648465200000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'I0Eu0H8Bwa_bL2zRzUGI',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'co2',
#      'Value': 420,
#      'LocationLat': 45.651464,
#      'LocationLong': 25.615426,
#      'TimeStamp': 1648465200000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648465200000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'JEEu0H8Bwa_bL2zRzUGJ',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm25',
#      'Value': 16,
#      'LocationLat': 45.651464,
#      'LocationLong': 25.615426,
#      'TimeStamp': 1648465200000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648465200000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'JkEu0H8Bwa_bL2zRzUGK',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm10',
#      'Value': 18,
#      'LocationLat': 45.651464,
#      'LocationLong': 25.615426,
#      'TimeStamp': 1648465200000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648465200000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'KEEu0H8Bwa_bL2zRzUGM',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'o3',
#      'Value': 20,
#      'LocationLat': 45.651464,
#      'LocationLong': 25.615426,
#      'TimeStamp': 1648465200000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648465200000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'LUEu0H8Bwa_bL2zRzUGS',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'cho2',
#      'Value': 7,
#      'LocationLat': 45.651464,
#      'LocationLong': 25.615426,
#      'TimeStamp': 1648465200000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648465200000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'ykEu0H8Bwa_bL2zRzEBC',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm1',
#      'Value': 11,
#      'LocationLat': 45.645914,
#      'LocationLong': 25.602642,
#      'TimeStamp': 1648465199000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648465199000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': '2UEu0H8Bwa_bL2zRzEBk',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm1',
#      'Value': 8,
#      'LocationLat': 45.646976,
#      'LocationLong': 25.595224,
#      'TimeStamp': 1648465199000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648465199000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': '3kEu0H8Bwa_bL2zRzEB3',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm1',
#      'Value': 10,
#      'LocationLat': 45.589267,
#      'LocationLong': 25.46445,
#      'TimeStamp': 1648465199000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648465199000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'zkEu0H8Bwa_bL2zRzEBN',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm25',
#      'Value': 13,
#      'LocationLat': 45.589267,
#      'LocationLong': 25.46445,
#      'TimeStamp': 1648465199000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648465199000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': '0kEu0H8Bwa_bL2zRzEBY',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm10',
#      'Value': 14,
#      'LocationLat': 45.589267,
#      'LocationLong': 25.46445,
#      'TimeStamp': 1648465199000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648465199000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': '5UEu0H8Bwa_bL2zRzECF',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm25',
#      'Value': 11,
#      'LocationLat': 45.646976,
#      'LocationLong': 25.595224,
#      'TimeStamp': 1648465199000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648465199000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': '5kEu0H8Bwa_bL2zRzECG',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm10',
#      'Value': 12,
#      'LocationLat': 45.646976,
#      'LocationLong': 25.595224,
#      'TimeStamp': 1648465199000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648465199000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'B0Eu0H8Bwa_bL2zRzUEb',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm10',
#      'Value': 15,
#      'LocationLat': 45.645914,
#      'LocationLong': 25.602642,
#      'TimeStamp': 1648465199000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648465199000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'CkEu0H8Bwa_bL2zRzUEd',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm25',
#      'Value': 14,
#      'LocationLat': 45.645914,
#      'LocationLong': 25.602642,
#      'TimeStamp': 1648465199000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648465199000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'tUEu0H8Bwa_bL2zRy0Db',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm25',
#      'Value': 18,
#      'LocationLat': 45.6536,
#      'LocationLong': 25.599,
#      'TimeStamp': 1648465197000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648465197000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'v0Eu0H8Bwa_bL2zRy0D8',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm10',
#      'Value': 20,
#      'LocationLat': 45.6536,
#      'LocationLong': 25.599,
#      'TimeStamp': 1648465197000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648465197000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'w0Eu0H8Bwa_bL2zRzEAM',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm1',
#      'Value': 8,
#      'LocationLat': 45.6536,
#      'LocationLong': 25.599,
#      'TimeStamp': 1648465197000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648465197000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': '80Eu0H8Bwa_bL2zRzEDX',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm25',
#      'Value': 12,
#      'LocationLat': 45.641274,
#      'LocationLong': 25.614817,
#      'TimeStamp': 1648465194000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648465194000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': '9EEu0H8Bwa_bL2zRzEDd',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm1',
#      'Value': 8,
#      'LocationLat': 45.641274,
#      'LocationLong': 25.614817,
#      'TimeStamp': 1648465194000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648465194000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'GUEu0H8Bwa_bL2zRzUFv',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm10',
#      'Value': 13,
#      'LocationLat': 45.641274,
#      'LocationLong': 25.614817,
#      'TimeStamp': 1648465194000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648465194000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 's0Eu0H8Bwa_bL2zRy0DX',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm25',
#      'Value': 14,
#      'LocationLat': 45.700748,
#      'LocationLong': 25.442761,
#      'TimeStamp': 1648465185000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648465185000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 't0Eu0H8Bwa_bL2zRy0Df',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm10',
#      'Value': 16,
#      'LocationLat': 45.700748,
#      'LocationLong': 25.442761,
#      'TimeStamp': 1648465185000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648465185000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': '-0Eu0H8Bwa_bL2zRzUAE',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm1',
#      'Value': 8,
#      'LocationLat': 45.700748,
#      'LocationLong': 25.442761,
#      'TimeStamp': 1648465185000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648465185000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'vkEu0H8Bwa_bL2zRy0D6',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm10',
#      'Value': 21,
#      'LocationLat': 45.6568,
#      'LocationLong': 25.5917,
#      'TimeStamp': 1648465173000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648465173000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'QkEu0H8Bwa_bL2zRzkE_',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm10',
#      'Value': 15,
#      'LocationLat': 45.614267,
#      'LocationLong': 25.63325,
#      'TimeStamp': 1648465173000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648465173000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'Q0Eu0H8Bwa_bL2zRzkFB',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm1',
#      'Value': 9,
#      'LocationLat': 45.657148,
#      'LocationLong': 25.563752,
#      'TimeStamp': 1648465173000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648465173000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'R0Eu0H8Bwa_bL2zRz0GD',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'co2',
#      'Value': 400,
#      'LocationLat': 45.657148,
#      'LocationLong': 25.563752,
#      'TimeStamp': 1648465173000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648465173000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': '7EEu0H8Bwa_bL2zRzEC9',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm25',
#      'Value': 13,
#      'LocationLat': 45.614267,
#      'LocationLong': 25.63325,
#      'TimeStamp': 1648465173000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648465173000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'AkEu0H8Bwa_bL2zRzUES',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm1',
#      'Value': 5,
#      'LocationLat': 45.6568,
#      'LocationLong': 25.5917,
#      'TimeStamp': 1648465173000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648465173000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'BEEu0H8Bwa_bL2zRzUEU',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm25',
#      'Value': 14,
#      'LocationLat': 45.6568,
#      'LocationLong': 25.5917,
#      'TimeStamp': 1648465173000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648465173000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'EkEu0H8Bwa_bL2zRzUFK',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm1',
#      'Value': 9,
#      'LocationLat': 45.614267,
#      'LocationLong': 25.63325,
#      'TimeStamp': 1648465173000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648465173000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'MEEu0H8Bwa_bL2zRzUGs',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm25',
#      'Value': 11,
#      'LocationLat': 45.642198,
#      'LocationLong': 25.588532,
#      'TimeStamp': 1648465173000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648465173000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'MUEu0H8Bwa_bL2zRzUGz',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm25',
#      'Value': 12,
#      'LocationLat': 45.657148,
#      'LocationLong': 25.563752,
#      'TimeStamp': 1648465173000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648465173000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'NEEu0H8Bwa_bL2zRzUHB',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'co2',
#      'Value':
000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648432752000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'jEFAzn8Bwa_bL2zRZjri',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm1',
#      'Value': 6,
#      'LocationLat': 45.638767,
#      'LocationLong': 25.586021,
#      'TimeStamp': 1648432752000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648432752000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'bEFAzn8Bwa_bL2zRZjp2',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm1',
#      'Value': 5,
#      'LocationLat': 45.55914,
#      'LocationLong': 25.324771,
#      'TimeStamp': 1648432752000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648432752000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'vUFAzn8Bwa_bL2zRazog',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm25',
#      'Value': 17,
#      'LocationLat': 45.623958,
#      'LocationLong': 25.481535,
#      'TimeStamp': 1648432749000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648432749000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'b0FAzn8Bwa_bL2zRZjp5',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm1',
#      'Value': 10,
#      'LocationLat': 45.623958,
#      'LocationLong': 25.481535,
#      'TimeStamp': 1648432749000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648432749000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': '7kFAzn8Bwa_bL2zRbzoT',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm10',
#      'Value': 19,
#      'LocationLat': 45.623958,
#      'LocationLong': 25.481535,
#      'TimeStamp': 1648432749000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648432749000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'e0FAzn8Bwa_bL2zRZjq2',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm1',
#      'Value': 15,
#      'LocationLat': 45.698269,
#      'LocationLong': 25.558889,
#      'TimeStamp': 1648432748000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648432748000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'h0FAzn8Bwa_bL2zRZjrQ',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm25',
#      'Value': 23,
#      'LocationLat': 45.698269,
#      'LocationLong': 25.558889,
#      'TimeStamp': 1648432748000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648432748000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'jkFAzn8Bwa_bL2zRZzoa',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm10',
#      'Value': 27,
#      'LocationLat': 45.698269,
#      'LocationLong': 25.558889,
#      'TimeStamp': 1648432748000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648432748000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'm0FAzn8Bwa_bL2zRZzoq',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm10',
#      'Value': 22,
#      'LocationLat': 45.673977,
#      'LocationLong': 25.606484,
#      'TimeStamp': 1648432747000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648432747000]},
#    ...]}}

# %%
# from pandas import json_normalize
# dataframe = json_normalize(data['hits']['hits'])

# %%
# dataframe
# Out:
#           _index _type                   _id _score             sort  \
# 0     brasov-dev  _doc  IkEu0H8Bwa_bL2zRzUGI   None  [1648465200000]
# 1     brasov-dev  _doc  I0Eu0H8Bwa_bL2zRzUGI   None  [1648465200000]
# 2     brasov-dev  _doc  JEEu0H8Bwa_bL2zRzUGJ   None  [1648465200000]
# 3     brasov-dev  _doc  JkEu0H8Bwa_bL2zRzUGK   None  [1648465200000]
# 4     brasov-dev  _doc  KEEu0H8Bwa_bL2zRzUGM   None  [1648465200000]
# ...          ...   ...                   ...    ...              ...
# 9995  brasov-dev  _doc  xEADvH8Bwa_bL2zRN_6R   None  [1648126739000]
# 9996  brasov-dev  _doc  HEADvH8Bwa_bL2zRO_9g   None  [1648126739000]
# 9997  brasov-dev  _doc  OUADvH8Bwa_bL2zRQP-i   None  [1648126739000]
# 9998  brasov-dev  _doc  -0ADvH8Bwa_bL2zROf77   None  [1648126685000]
# 9999  brasov-dev  _doc  _kADvH8Bwa_bL2zROf7-   None  [1648126685000]
#
#      _source.Source _source.Sensor  _source.Value  _source.LocationLat  \
# 0       UradMonitor            pm1           13.0            45.651464
# 1       UradMonitor            co2          420.0            45.651464
# 2       UradMonitor           pm25           16.0            45.651464
# 3       UradMonitor           pm10           18.0            45.651464
# 4       UradMonitor             o3           20.0            45.651464
# ...             ...            ...            ...                  ...
# 9995    UradMonitor            pm1            3.0            45.665184
# 9996    UradMonitor           pm25            9.0            45.665184
# 9997    UradMonitor           pm10            4.0            45.665184
# 9998    UradMonitor            pm1            3.0            45.717370
# 9999    UradMonitor           pm10            7.0            45.717370
#
#       _source.LocationLong  _source.TimeStamp _source.Measurement
# 0                25.615426      1648465200000               µg/m3
# 1                25.615426      1648465200000               µg/m3
# 2                25.615426      1648465200000               µg/m3
# 3                25.615426      1648465200000               µg/m3
# 4                25.615426      1648465200000               µg/m3
# ...                    ...                ...                 ...
# 9995             25.558891      1648126739000               µg/m3
# 9996             25.558891      1648126739000               µg/m3
# 9997             25.558891      1648126739000               µg/m3
# 9998             25.685710      1648126685000               µg/m3
# 9999             25.685710      1648126685000               µg/m3
#
# [10000 rows x 12 columns]

# %%
import matplotlib.pyplot as plt
hist_sensor = plt.figure(figsize = (25,10))
ax = hist_sensor.gca()

dataframe.get('_source.Sensor').value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
dataframe['LocationId'] = dataframe['_source.LocationLat']*10000000 + dataframe['_source.LocationLong']*10000000
dataframe['LocationName'] = ""
dataframe.loc[dataframe['LocationId'] == 712668900.0, 'LocationName'] = 'AFI' 
dataframe.loc[dataframe['LocationId'] == 712196290.0, 'LocationName'] = 'Bartolomeu1'
dataframe.loc[dataframe['LocationId'] == 712209000.0, 'LocationName'] = 'Bartolomeu2'
dataframe.loc[dataframe['LocationId'] == 712240750.0, 'LocationName'] = 'Bartolomeu3'
dataframe.loc[dataframe['LocationId'] == 708361730.0, 'LocationName'] = 'Bucegi'
dataframe.loc[dataframe['LocationId'] == 712682018.0, 'LocationName'] = 'Carrefour'
dataframe.loc[dataframe['LocationId'] == 712307300.0, 'LocationName'] = 'Centru1'
dataframe.loc[dataframe['LocationId'] == 712422000.0, 'LocationName'] = 'Centru2'
dataframe.loc[dataframe['LocationId'] == 712485560.0, 'LocationName'] = 'Centru3'
dataframe.loc[dataframe['LocationId'] == 712532529.0, 'LocationName'] = 'Centru4'
dataframe.loc[dataframe['LocationId'] == 711435090.0, 'LocationName'] = 'Codlea1'
dataframe.loc[dataframe['LocationId'] == 711587690.0, 'LocationName'] = 'Codlea2'
dataframe.loc[dataframe['LocationId'] == 712526000.0, 'LocationName'] = 'Colina1'
dataframe.loc[dataframe['LocationId'] == 712485000.0, 'LocationName'] = 'Colina2'
dataframe.loc[dataframe['LocationId'] == 711054930.0, 'LocationName'] = 'Cristian'
dataframe.loc[dataframe['LocationId'] == 712743216.0, 'LocationName'] = 'Gara'
dataframe.loc[dataframe['LocationId'] == 713825580.0, 'LocationName'] = 'Harman1'
dataframe.loc[dataframe['LocationId'] == 714030800.0, 'LocationName'] = 'Harman2'
dataframe.loc[dataframe['LocationId'] == 712560910.0, 'LocationName'] = 'Racadau'
dataframe.loc[dataframe['LocationId'] == 710537170.0, 'LocationName'] = 'Rasnov'
dataframe.loc[dataframe['LocationId'] == 713449870.0, 'LocationName'] = 'Sanpetru1'
dataframe.loc[dataframe['LocationId'] == 713500000.0, 'LocationName'] = 'Sanpetru2'
dataframe.loc[dataframe['LocationId'] == 712475170.0, 'LocationName'] = 'Saturn'
dataframe.loc[dataframe['LocationId'] == 712500331.0, 'LocationName'] = 'Stupini1'
dataframe.loc[dataframe['LocationId'] == 712571580.0, 'LocationName'] = 'Stupini2'
dataframe.loc[dataframe['LocationId'] == 712804610.0, 'LocationName'] = 'Tractorul'
dataframe.loc[dataframe['LocationId'] == 713218270.0, 'LocationName'] = 'TriajH'
dataframe.loc[dataframe['LocationId'] == 712783320.0, 'LocationName'] = 'Vlahuta1'
dataframe.loc[dataframe['LocationId'] == 712797770.0, 'LocationName'] = 'Vlahuta2'
dataframe.head(10)
# Out:
#        _index _type                   _id _score             sort  \
# 0  brasov-dev  _doc  vEGEwH8Bwa_bL2zRyg3r   None  [1648202399000]
# 1  brasov-dev  _doc  vUGEwH8Bwa_bL2zRyg31   None  [1648202399000]
# 2  brasov-dev  _doc  y0GEwH8Bwa_bL2zRyw0r   None  [1648202399000]
# 3  brasov-dev  _doc  XUGEwH8Bwa_bL2zRxg3m   None  [1648202397000]
# 4  brasov-dev  _doc  p0GEwH8Bwa_bL2zRyg1k   None  [1648202397000]
# 5  brasov-dev  _doc  q0GEwH8Bwa_bL2zRyg17   None  [1648202397000]
# 6  brasov-dev  _doc  Y0GEwH8Bwa_bL2zRxw3z   None  [1648202396000]
# 7  brasov-dev  _doc  ZkGEwH8Bwa_bL2zRyA0I   None  [1648202396000]
# 8  brasov-dev  _doc  qUGEwH8Bwa_bL2zRyg1n   None  [1648202396000]
# 9  brasov-dev  _doc  bEGEwH8Bwa_bL2zRyA06   None  [1648202388000]
#
#   _source.Source _source.Sensor  _source.Value  _source.LocationLat  \
# 0    UradMonitor            pm1           13.0            45.589267
# 1    UradMonitor           pm10           24.0            45.589267
# 2    UradMonitor           pm25           20.0            45.589267
# 3    UradMonitor           pm10           23.0            45.704032
# 4    UradMonitor            pm1            8.0            45.704032
# 5    UradMonitor           pm25           18.0            45.704032
# 6    UradMonitor           pm25           22.0            45.653600
# 7    UradMonitor            pm1            9.0            45.653600
# 8    UradMonitor           pm10           26.0            45.653600
# 9    UradMonitor           pm10           14.0            45.700748
#
#    _source.LocationLong  _source.TimeStamp _source.Measurement   LocationId  \
# 0             25.464450      1648202399000               µg/m3  710537170.0
# 1             25.464450      1648202399000               µg/m3  710537170.0
# 2             25.464450      1648202399000               µg/m3  710537170.0
# 3             25.640955      1648202397000               µg/m3  713449870.0
# 4             25.640955      1648202397000               µg/m3  713449870.0
# 5             25.640955      1648202397000               µg/m3  713449870.0
# 6             25.599000      1648202396000               µg/m3  712526000.0
# 7             25.599000      1648202396000               µg/m3  712526000.0
# 8             25.599000      1648202396000               µg/m3  712526000.0
# 9             25.442761      1648202388000               µg/m3  711435090.0
#
#   LocationName
# 0       Rasnov
# 1       Rasnov
# 2       Rasnov
# 3    Sanpetru1
# 4    Sanpetru1
# 5    Sanpetru1
# 6      Colina1
# 7      Colina1
# 8      Colina1
# 9      Codlea1

# %%
# dataframe.groupby(['LocationName']).size().reset_index().rename(columns={0:'count'})

# %%
# hist_location = dataframe.get('LocationName').hist()
import matplotlib.pyplot as plt
hist_location = plt.figure(figsize = (25,10))
ax = hist_location.gca()
# dataframe.get('LocationName').hist(ax = ax)

dataframe.get('LocationName').value_counts().plot(kind='bar')
# dataframe.get('LocationName').value_counts(sort=False).plot.bar(rot=0)
# Out:
# <AxesSubplot:>

# %%
dataframe_v2 = dataframe[[i for i in list(dataframe.columns) if i != '_index']]
dataframe_v2 = dataframe_v2[[i for i in list(dataframe_v2.columns) if i != '_type']]
dataframe_v2 = dataframe_v2[[i for i in list(dataframe_v2.columns) if i != '_id']]
dataframe_v2 = dataframe_v2[[i for i in list(dataframe_v2.columns) if i != '_score']]
dataframe_v2 = dataframe_v2[[i for i in list(dataframe_v2.columns) if i != 'sort']]
dataframe_v2.head(7)
# dataframe_v2
# Out:
#   _source.Source _source.Sensor  _source.Value  _source.LocationLat  \
# 0    UradMonitor            pm1           13.0            45.589267
# 1    UradMonitor           pm10           24.0            45.589267
# 2    UradMonitor           pm25           20.0            45.589267
# 3    UradMonitor           pm10           23.0            45.704032
# 4    UradMonitor            pm1            8.0            45.704032
# 5    UradMonitor           pm25           18.0            45.704032
# 6    UradMonitor           pm25           22.0            45.653600
#
#    _source.LocationLong  _source.TimeStamp _source.Measurement   LocationId  \
# 0             25.464450      1648202399000               µg/m3  710537170.0
# 1             25.464450      1648202399000               µg/m3  710537170.0
# 2             25.464450      1648202399000               µg/m3  710537170.0
# 3             25.640955      1648202397000               µg/m3  713449870.0
# 4             25.640955      1648202397000               µg/m3  713449870.0
# 5             25.640955      1648202397000               µg/m3  713449870.0
# 6             25.599000      1648202396000               µg/m3  712526000.0
#
#   LocationName
# 0       Rasnov
# 1       Rasnov
# 2       Rasnov
# 3    Sanpetru1
# 4    Sanpetru1
# 5    Sanpetru1
# 6      Colina1

# %%
cho2 = dataframe_v2[dataframe_v2.get('_source.Sensor') == 'cho2']
co2 = dataframe_v2[dataframe_v2.get('_source.Sensor') == 'co2']
no2 = dataframe_v2[dataframe_v2.get('_source.Sensor') == 'no2']
o3 = dataframe_v2[dataframe_v2.get('_source.Sensor') == 'o3']
pm1 = dataframe_v2[dataframe_v2.get('_source.Sensor') == 'pm1']
pm10 = dataframe_v2[dataframe_v2.get('_source.Sensor') == 'pm10']
pm25 = dataframe_v2[dataframe_v2.get('_source.Sensor') == 'pm25']
so2 = dataframe_v2[dataframe_v2.get('_source.Sensor') == 'so2']

# %%
print('Lungime dataframe: ',len(dataframe_v2))
print('Lungime dataframe cho2: ',len(cho2))
print('Lungime dataframe co2: ',len(co2))
print('Lungime dataframe no2: ',len(no2))
print('Lungime dataframe o3: ',len(o3))
print('Lungime dataframe pm1: ',len(pm1))
print('Lungime dataframe pm10: ',len(pm10))
print('Lungime dataframe pm25: ',len(pm25))
print('Lungime dataframe so2: ',len(so2))
# Out:
# Lungime dataframe:  10000
# Lungime dataframe cho2:  438
# Lungime dataframe co2:  439
# Lungime dataframe no2:  510
# Lungime dataframe o3:  642
# Lungime dataframe pm1:  2384
# Lungime dataframe pm10:  2895
# Lungime dataframe pm25:  2386
# Lungime dataframe so2:  306

# %%
import matplotlib.pyplot as plt
plt.close("all")
# fig = plt.figure(figsize=(20,10), frameon=True)
plt.figure(figsize=(20,10))
plt.plot(so2.get('_source.TimeStamp'), so2.get('_source.Value'), label="All SO2 sensors")
plt.scatter(so2.get('_source.TimeStamp'), so2.get('_source.Value'), color = "red")
plt.xlabel("TimeStamp")
plt.ylabel("Value")
plt.title("Last 10000 values for all SO2 sensors")
plt.legend()
plt.savefig('plots_updated/SO2.jpg', bbox_inches = 'tight')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.linear_model import LinearRegression

# %%
X = so2[["_source.TimeStamp"]].values
y = so2[["_source.Value"]].values

# %%
regressor = LinearRegression()
regressor.fit(X, y)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(X)

# %%
print("Slope: ", float(regressor.coef_))
print("Intercept: ", float(regressor.intercept_))
# float("{:.8f}".format(float(regressor.intercept_)))
# Out:
# Slope:  4.4109999885360486e-10
# Intercept:  -724.6144123549045

# %%
plt.figure(figsize=(20,10))
# plt.scatter(X, y, color = 'blue')
plt.plot(X,y, color = 'blue', label="All SO2 values")
plt.plot(X, regressor.predict(X), color = 'red', label="SO2 linear regression")
plt.title('Linear regression on last 10000 SO2 values')
plt.xlabel('TimeStamp')
plt.ylabel('Value')
plt.legend()
plt.savefig('plots_updated/SO2_regression.jpg', bbox_inches = 'tight')
plt.show()

# %%
so2.head(6) #Vlahuta1, Centru4, Sanpetru2
# Out:
#     _source.Source _source.Sensor  _source.Value  _source.LocationLat  \
# 81            Waqi            so2            2.3            45.654271
# 86            Waqi            so2            2.7            45.649117
# 90            Waqi            so2            1.5            45.716700
# 180           Waqi            so2            1.6            45.716700
# 183           Waqi            so2            2.4            45.654271
# 190           Waqi            so2            3.0            45.649117
#
#      _source.LocationLong  _source.TimeStamp _source.Measurement   LocationId  \
# 81              25.624061      1648198800000               µg/m3  712783320.0
# 86              25.604136      1648198800000               µg/m3  712532529.0
# 90              25.633300      1648198800000               µg/m3  713500000.0
# 180             25.633300      1648195200000               µg/m3  713500000.0
# 183             25.624061      1648195200000               µg/m3  712783320.0
# 190             25.604136      1648195200000               µg/m3  712532529.0
#
#     LocationName
# 81      Vlahuta1
# 86       Centru4
# 90     Sanpetru2
# 180    Sanpetru2
# 183     Vlahuta1
# 190      Centru4

# %%
so2_vlahuta1 = so2[so2.get('LocationName') == 'Vlahuta1']
so2_centru4 = so2[so2.get('LocationName') == 'Centru4']
so2_sanpetru2 = so2[so2.get('LocationName') == 'Sanpetru2']

# %%
import matplotlib.pyplot as plt
plt.close("all")
plt.figure(figsize=(20,10))
plt.plot(so2_vlahuta1.get('_source.TimeStamp'), so2_vlahuta1.get('_source.Value'), color = "red", label="Vlahuta1 SO2 sensor")
plt.plot(so2_centru4.get('_source.TimeStamp'), so2_centru4.get('_source.Value'), color = "blue", label="Centru4 SO2 sensor")
plt.plot(so2_sanpetru2.get('_source.TimeStamp'), so2_sanpetru2.get('_source.Value'), color = "purple", label="Sanpetru2 SO2 sensor")
plt.xlabel("TimeStamp")
plt.ylabel("Value")
plt.title("Last 10000 values for SO2")
plt.legend()
plt.savefig('plots_updated/SO2_all.jpg', bbox_inches = 'tight')
plt.show()

# %%
pm10_bartolomeu1 = pm10[pm10.get('LocationName') == 'Bartolomeu1']
pm10_bartolomeu2 = pm10[pm10.get('LocationName') == 'Bartolomeu2']
pm10_bartolomeu3 = pm10[pm10.get('LocationName') == 'Bartolomeu3']

# %%
import matplotlib.pyplot as plt
plt.close("all")
plt.figure(figsize=(20,10))
plt.plot(pm10_bartolomeu1.get('_source.TimeStamp'), pm10_bartolomeu1.get('_source.Value'), color = "red", label="Bartolomeu1 PM10 sensor")
plt.plot(pm10_bartolomeu2.get('_source.TimeStamp'), pm10_bartolomeu2.get('_source.Value'), color = "blue", label="Bartolomeu2 PM10 sensor")
plt.plot(pm10_bartolomeu3.get('_source.TimeStamp'), pm10_bartolomeu3.get('_source.Value'), color = "purple", label="Bartolomeu3 PM10 sensor")
plt.xlabel("TimeStamp")
plt.ylabel("Value")
plt.title("Last 10000 values for PM10 in Bartolomeu")
plt.legend()
plt.savefig('plots_updated/PM10_Bartolomeu.jpg', bbox_inches = 'tight')
plt.show()

# %%
pm10_bartolomeu2.head(30)
# Out:
#      _source.Source _source.Sensor  _source.Value  _source.LocationLat  \
# 15      UradMonitor           pm10           22.0            45.657148
# 112     UradMonitor           pm10           21.0            45.657148
# 208     UradMonitor           pm10           23.0            45.657148
# 309     UradMonitor           pm10           26.0            45.657148
# 396     UradMonitor           pm10           29.0            45.657148
# 500     UradMonitor           pm10           28.0            45.657148
# 585     UradMonitor           pm10           22.0            45.657148
# 668     UradMonitor           pm10           29.0            45.657148
# 760     UradMonitor           pm10           19.0            45.657148
# 850     UradMonitor           pm10           20.0            45.657148
# 938     UradMonitor           pm10           20.0            45.657148
# 1041    UradMonitor           pm10           22.0            45.657148
# 1149    UradMonitor           pm10           23.0            45.657148
# 1238    UradMonitor           pm10           23.0            45.657148
# 1335    UradMonitor           pm10           29.0            45.657148
# 1425    UradMonitor           pm10           26.0            45.657148
# 1516    UradMonitor           pm10           24.0            45.657148
# 1611    UradMonitor           pm10           28.0            45.657148
# 1740    UradMonitor           pm10           30.0            45.657148
# 1960    UradMonitor           pm10           25.0            45.657148
# 2061    UradMonitor           pm10           24.0            45.657148
# 2161    UradMonitor           pm10           22.0            45.657148
# 2255    UradMonitor           pm10           25.0            45.657148
# 2363    UradMonitor           pm10           21.0            45.657148
# 2458    UradMonitor           pm10           22.0            45.657148
# 2568    UradMonitor           pm10           27.0            45.657148
# 2662    UradMonitor           pm10           60.0            45.657148
# 2763    UradMonitor           pm10           60.0            45.657148
# 2854    UradMonitor           pm10           65.0            45.657148
# 2951    UradMonitor           pm10           67.0            45.657148
#
#       _source.LocationLong  _source.TimeStamp _source.Measurement  \
# 15               25.563752      1648202381000               µg/m3
# 112              25.563752      1648198781000               µg/m3
# 208              25.563752      1648195181000               µg/m3
# 309              25.563752      1648191581000               µg/m3
# 396              25.563752      1648187982000               µg/m3
# 500              25.563752      1648184382000               µg/m3
# 585              25.563752      1648180782000               µg/m3
# 668              25.563752      1648177182000               µg/m3
# 760              25.563752      1648173582000               µg/m3
# 850              25.563752      1648169982000               µg/m3
# 938              25.563752      1648166382000               µg/m3
# 1041             25.563752      1648162782000               µg/m3
# 1149             25.563752      1648159182000               µg/m3
# 1238             25.563752      1648155582000               µg/m3
# 1335             25.563752      1648151983000               µg/m3
# 1425             25.563752      1648148383000               µg/m3
# 1516             25.563752      1648144783000               µg/m3
# 1611             25.563752      1648141183000               µg/m3
# 1740             25.563752      1648137583000               µg/m3
# 1960             25.563752      1648133984000               µg/m3
# 2061             25.563752      1648130383000               µg/m3
# 2161             25.563752      1648126784000               µg/m3
# 2255             25.563752      1648123194000               µg/m3
# 2363             25.563752      1648119584000               µg/m3
# 2458             25.563752      1648115984000               µg/m3
# 2568             25.563752      1648112384000               µg/m3
# 2662             25.563752      1648108784000               µg/m3
# 2763             25.563752      1648105184000               µg/m3
# 2854             25.563752      1648101584000               µg/m3
# 2951             25.563752      1648097984000               µg/m3
#
#        LocationId LocationName
# 15    712209000.0  Bartolomeu2
# 112   712209000.0  Bartolomeu2
# 208   712209000.0  Bartolomeu2
# 309   712209000.0  Bartolomeu2
# 396   712209000.0  Bartolomeu2
# 500   712209000.0  Bartolomeu2
# 585   712209000.0  Bartolomeu2
# 668   712209000.0  Bartolomeu2
# 760   712209000.0  Bartolomeu2
# 850   712209000.0  Bartolomeu2
# 938   712209000.0  Bartolomeu2
# 1041  712209000.0  Bartolomeu2
# 1149  712209000.0  Bartolomeu2
# 1238  712209000.0  Bartolomeu2
# 1335  712209000.0  Bartolomeu2
# 1425  712209000.0  Bartolomeu2
# 1516  712209000.0  Bartolomeu2
# 1611  712209000.0  Bartolomeu2
# 1740  712209000.0  Bartolomeu2
# 1960  712209000.0  Bartolomeu2
# 2061  712209000.0  Bartolomeu2
# 2161  712209000.0  Bartolomeu2
# 2255  712209000.0  Bartolomeu2
# 2363  712209000.0  Bartolomeu2
# 2458  712209000.0  Bartolomeu2
# 2568  712209000.0  Bartolomeu2
# 2662  712209000.0  Bartolomeu2
# 2763  712209000.0  Bartolomeu2
# 2854  712209000.0  Bartolomeu2
# 2951  712209000.0  Bartolomeu2

# %%
pm10_centru1 = pm10[pm10.get('LocationName') == 'Centru1']
pm10_centru2 = pm10[pm10.get('LocationName') == 'Centru2']
pm10_centru3 = pm10[pm10.get('LocationName') == 'Centru3']
pm10_centru4 = pm10[pm10.get('LocationName') == 'Centru4']

# %%
import matplotlib.pyplot as plt
plt.close("all")
plt.figure(figsize=(20,10))
# plt.plot(pm10_centru1.get('_source.TimeStamp'), pm10_centru1.get('_source.Value'), color = "red")
plt.plot(pm10_centru2.get('_source.TimeStamp'), pm10_centru2.get('_source.Value'), color = "blue", label="Centru2 PM10 sensor")
plt.plot(pm10_centru3.get('_source.TimeStamp'), pm10_centru3.get('_source.Value'), color = "purple", label="Centru3 PM10 sensor")
plt.plot(pm10_centru4.get('_source.TimeStamp'), pm10_centru4.get('_source.Value'), color = "red", label="Centru4 PM10 sensor")
plt.xlabel("TimeStamp")
plt.ylabel("Value")
plt.title("Last 10000 values for PM10 in Centru")
plt.legend()
plt.savefig('plots_updated/PM10_Centru.jpg', bbox_inches = 'tight')
plt.show()

# %%
pm10_carrefour = pm10[pm10.get('LocationName') == 'Carrefour']
pm10_afi = pm10[pm10.get('LocationName') == 'AFI']
pm10_gara = pm10[pm10.get('LocationName') == 'Gara']

# %%
import matplotlib.pyplot as plt
plt.close("all")
plt.figure(figsize=(20,10))
plt.plot(pm10_carrefour.get('_source.TimeStamp'), pm10_carrefour.get('_source.Value'), color = "red", label="Carrefour PM10 sensor")
plt.plot(pm10_afi.get('_source.TimeStamp'), pm10_afi.get('_source.Value'), color = "blue", label="AFI PM10 sensor")
plt.plot(pm10_gara.get('_source.TimeStamp'), pm10_gara.get('_source.Value'), color = "purple", label="Gara PM10 sensor")
plt.plot(pm10_centru4.get('_source.TimeStamp'), pm10_centru4.get('_source.Value'), color = "black", label="Centru4 PM10 sensor")
plt.xlabel("TimeStamp")
plt.ylabel("Value")
plt.title("Last 10000 values for PM10 in Carrefour-AFI-Gara-Centru4")
plt.legend()
plt.savefig('plots_updated/PM10_C-A-G-C4.jpg', bbox_inches = 'tight')
plt.show()

# %%
# pm10_afi.head(30)
pm10_gara.tail(10)
# Out:
#      _source.Source _source.Sensor  _source.Value  _source.LocationLat  \
# 9081           Waqi           pm10           27.0            45.659833
# 9185           Waqi           pm10           27.0            45.659833
# 9267           Waqi           pm10           27.0            45.659833
# 9366           Waqi           pm10           27.0            45.659833
# 9469           Waqi           pm10           27.0            45.659833
# 9568           Waqi           pm10           26.0            45.659833
# 9654           Waqi           pm10           26.0            45.659833
# 9744           Waqi           pm10           25.0            45.659833
# 9843           Waqi           pm10           25.0            45.659833
# 9931           Waqi           pm10           24.0            45.659833
#
#       _source.LocationLong  _source.TimeStamp _source.Measurement  \
# 9081             25.614488      1647867600000               µg/m3
# 9185             25.614488      1647864000000               µg/m3
# 9267             25.614488      1647860400000               µg/m3
# 9366             25.614488      1647856800000               µg/m3
# 9469             25.614488      1647853200000               µg/m3
# 9568             25.614488      1647849600000               µg/m3
# 9654             25.614488      1647846000000               µg/m3
# 9744             25.614488      1647842400000               µg/m3
# 9843             25.614488      1647838800000               µg/m3
# 9931             25.614488      1647835200000               µg/m3
#
#        LocationId LocationName
# 9081  712743216.0         Gara
# 9185  712743216.0         Gara
# 9267  712743216.0         Gara
# 9366  712743216.0         Gara
# 9469  712743216.0         Gara
# 9568  712743216.0         Gara
# 9654  712743216.0         Gara
# 9744  712743216.0         Gara
# 9843  712743216.0         Gara
# 9931  712743216.0         Gara

# %%
train = pm10_afi[pm10_afi.get('_source.TimeStamp') < 1648123156000]
test = pm10_afi[pm10_afi.get('_source.TimeStamp') >= 1648123156000]

import matplotlib.pyplot as plt
plt.close("all")
plt.figure(figsize=(20,10))
plt.plot(train.get('_source.TimeStamp'), train.get('_source.Value'), color = "black", label = "Training")
plt.plot(test.get('_source.TimeStamp'), test.get('_source.Value'), color = "red", label = "Testing")
plt.xlabel("TimeStamp")
plt.ylabel("Value")
plt.title("Train/Test split for PM10 in AFI")
plt.legend()
plt.savefig('plots_updated/PM10_AFI_Split.jpg', bbox_inches = 'tight')
plt.show()

# %%
pm10_afi = pm10[pm10.get('LocationName') == 'AFI']
train = pm10_afi[pm10_afi.index < 8000]
test = pm10_afi[pm10_afi.index >= 8000]

from statsmodels.tsa.statespace.sarimax import SARIMAX
y = train['_source.Value']

ARMAmodel = SARIMAX(y, order=(1,0,1))
ARMAmodel = ARMAmodel.fit()
y_pred = ARMAmodel.get_forecast(len(test.index))
y_pred_df = y_pred.conf_int(alpha=0.05)
y_pred_df['Predictions'] = ARMAmodel.predict(start = y_pred_df.index[0], end = y_pred_df.index[-1])
y_pred_df.index = test.index
y_pred_out = y_pred_df["Predictions"]


import matplotlib.pyplot as plt
plt.close("all")
plt.figure(figsize=(20,10))
plt.plot(train.index, train.get('_source.Value'), color = "black", label = "Training")
plt.plot(test.index, test.get('_source.Value'), color = "red", label = "Testing")
plt.xlabel("Index")
plt.ylabel("Value")
plt.title("Train/Test/Predictions for PM10 in AFI")
plt.plot(y_pred_out, color='green', label = 'ARMA Predictions')
plt.legend()
plt.savefig('plots_updated/PM10_AFI_ARMA_Prediction.jpg', bbox_inches = 'tight')
plt.show()


import numpy as np
from sklearn.metrics import mean_squared_error

arma_rmse = np.sqrt(mean_squared_error(test["_source.Value"].values, y_pred_df["Predictions"]))
print("RMSE: ", arma_rmse)
# Out:
# C:\VALI\Programs\Miniconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\VALI\Programs\Miniconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\VALI\Programs\Miniconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# C:\VALI\Programs\Miniconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# RMSE:  28.66905124295663

# %%
pm10_afi = pm10[pm10.get('LocationName') == 'AFI']
train = pm10_afi[pm10_afi.index < 8000]
test = pm10_afi[pm10_afi.index >= 8000]

from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.arima.model import ARIMA
y = train['_source.Value']

ARMAmodel = ARIMA(y, order=(2,2,2))
ARMAmodel = ARMAmodel.fit()
y_pred = ARMAmodel.get_forecast(len(test.index))
y_pred_df = y_pred.conf_int(alpha=0.05)
y_pred_df['Predictions'] = ARMAmodel.predict(start = y_pred_df.index[0], end = y_pred_df.index[-1])
y_pred_df.index = test.index
y_pred_out = y_pred_df["Predictions"]


import matplotlib.pyplot as plt
plt.close("all")
plt.figure(figsize=(20,10))
plt.plot(train.index, train.get('_source.Value'), color = "black", label = "Training")
plt.plot(test.index, test.get('_source.Value'), color = "red", label = "Testing")
plt.xlabel("Index")
plt.ylabel("Value")
plt.title("Train/Test/Predictions for PM10 in AFI")
plt.plot(y_pred_out, color='purple', label = 'ARIMA Predictions')
plt.legend()
plt.savefig('plots_updated/PM10_AFI_ARIMA_Prediction.jpg', bbox_inches = 'tight')
plt.show()


import numpy as np
from sklearn.metrics import mean_squared_error

arima_rmse = np.sqrt(mean_squared_error(test["_source.Value"].values, y_pred_df["Predictions"]))
print("RMSE: ", arima_rmse)
# Out:
# C:\VALI\Programs\Miniconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\VALI\Programs\Miniconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\VALI\Programs\Miniconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\VALI\Programs\Miniconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# C:\VALI\Programs\Miniconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# RMSE:  20.08444041246857

# %%
pm10_afi = pm10[pm10.get('LocationName') == 'AFI']
train = pm10_afi[pm10_afi.index < 8000]
test = pm10_afi[pm10_afi.index >= 8000]

from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.arima.model import ARIMA
y = train['_source.Value']

ARMAmodel = ARIMA(y, order=(2,3,2))
ARMAmodel = ARMAmodel.fit()
y_pred = ARMAmodel.get_forecast(len(test.index))
y_pred_df = y_pred.conf_int(alpha=0.05)
y_pred_df['Predictions'] = ARMAmodel.predict(start = y_pred_df.index[0], end = y_pred_df.index[-1])
y_pred_df.index = test.index
y_pred_out = y_pred_df["Predictions"]


import matplotlib.pyplot as plt
plt.close("all")
plt.figure(figsize=(20,10))
plt.plot(train.index, train.get('_source.Value'), color = "black", label = "Training")
plt.plot(test.index, test.get('_source.Value'), color = "red", label = "Testing")
plt.xlabel("Index")
plt.ylabel("Value")
plt.title("Train/Test/Predictions for PM10 in AFI")
plt.plot(y_pred_out, color='purple', label = 'ARIMA Predictions2')
plt.legend()
plt.savefig('plots_updated/PM10_AFI_ARIMA_Prediction2.jpg', bbox_inches = 'tight')
plt.show()


import numpy as np
from sklearn.metrics import mean_squared_error

arima_rmse2 = np.sqrt(mean_squared_error(test["_source.Value"].values, y_pred_df["Predictions"]))
print("RMSE: ", arima_rmse2)
# Out:
# C:\VALI\Programs\Miniconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\VALI\Programs\Miniconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\VALI\Programs\Miniconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\VALI\Programs\Miniconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# C:\VALI\Programs\Miniconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# RMSE:  18.403660954382413

# %%
pm10_afi = pm10[pm10.get('LocationName') == 'AFI']
train = pm10_afi[pm10_afi.index < 8000]
test = pm10_afi[pm10_afi.index >= 8000]

from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.arima.model import ARIMA
y = train['_source.Value']

ARMAmodel = ARIMA(y, order=(9,3,6))
ARMAmodel = ARMAmodel.fit()
y_pred = ARMAmodel.get_forecast(len(test.index))
y_pred_df = y_pred.conf_int(alpha=0.05)
y_pred_df['Predictions'] = ARMAmodel.predict(start = y_pred_df.index[0], end = y_pred_df.index[-1])
y_pred_df.index = test.index
y_pred_out = y_pred_df["Predictions"]


import matplotlib.pyplot as plt
plt.close("all")
plt.figure(figsize=(20,10))
plt.plot(train.index, train.get('_source.Value'), color = "black", label = "Training")
plt.plot(test.index, test.get('_source.Value'), color = "red", label = "Testing")
plt.xlabel("Index")
plt.ylabel("Value")
plt.title("Train/Test/Predictions for PM10 in AFI")
plt.plot(y_pred_out, color='purple', label = 'ARIMA Predictions3')
plt.legend()
plt.savefig('plots_updated/PM10_AFI_ARIMA_Prediction3.jpg', bbox_inches = 'tight')
plt.show()


import numpy as np
from sklearn.metrics import mean_squared_error

arima_rmse3 = np.sqrt(mean_squared_error(test["_source.Value"].values, y_pred_df["Predictions"]))
print("RMSE: ", arima_rmse3)
# Out:
# C:\VALI\Programs\Miniconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\VALI\Programs\Miniconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\VALI\Programs\Miniconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\VALI\Programs\Miniconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# C:\VALI\Programs\Miniconda3\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\VALI\Programs\Miniconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# C:\VALI\Programs\Miniconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# RMSE:  16.5164747553165
