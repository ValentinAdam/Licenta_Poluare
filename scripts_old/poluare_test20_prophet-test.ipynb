# %%
import pandas as pd
import numpy as np
import datetime
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
from fbprophet import Prophet
from scalecast.Forecaster import Forecaster
from scalecast.MVForecaster import MVForecaster
from scalecast import GridGenerator
from scalecast.notebook import tune_test_forecast

# %%
# read in data
data = pd.read_csv('csv/82000278_Toamnei_CO2_2021_08_1week_v3.csv')

# %%
# set graph sizes
sns.set(rc={'figure.figsize':(30,15)})

# %%
data.head()
# Out:
#          time  co2
# 0  1627862426  612
# 1  1627862486  610
# 2  1627862546  606
# 3  1627862606  609
# 4  1627862666  606

# %%
result = data.dtypes
result
# Out:
# time    int64
# co2     int64
# dtype: object

# %%
# the dataset is in sequential order
data = data.sort_values('time')
data
# Out:
#            time  co2
# 0    1627862426  612
# 1    1627862486  610
# 2    1627862546  606
# 3    1627862606  609
# 4    1627862666  606
# ..          ...  ...
# 676  1627902985  543
# 677  1627903045  544
# 678  1627903105  546
# 679  1627903166  551
# 680  1627903224  548
#
# [681 rows x 2 columns]

# %%
# data['time'] = data['time'] - 1627862425
# data

# %%
# data['time'] = data['time'].astype(float)
# data['co2'] = data['co2'].astype(float)

# %%
data
# Out:
#            time  co2
# 0    1627862426  612
# 1    1627862486  610
# 2    1627862546  606
# 3    1627862606  609
# 4    1627862666  606
# ..          ...  ...
# 676  1627902985  543
# 677  1627903045  544
# 678  1627903105  546
# 679  1627903166  551
# 680  1627903224  548
#
# [681 rows x 2 columns]

# %%
# data['date'] = pd.to_datetime(data['date'])
# data

# %%
# import matplotlib.pyplot as plt
# plt.close("all")
# # fig = plt.figure(figsize=(20,10), frameon=True)
# plt.figure(figsize=(30,15))
# plt.plot(data.get('date'), data.get('co2'), label="CO2 values", color = "blue")
# # plt.scatter(dataframe.get('_source.TimeStamp'), dataframe.get('_source.Value'), color = "red")
# plt.xlabel("TimeStamp", fontsize=16)
# plt.ylabel("Value", fontsize=16)
# plt.title("CO2 values on 1 week", fontsize=18)
# plt.legend(fontsize=16)
# # plt.savefig('plots_from_csv/CSV_Tests_1month.jpg', bbox_inches = 'tight')
# plt.show()

# %%
import matplotlib.pyplot as plt
plt.close("all")
# fig = plt.figure(figsize=(20,10), frameon=True)
plt.figure(figsize=(30,15))
plt.plot(data.get('time'), data.get('co2'), label="CO2 values", color = "blue")
# plt.scatter(dataframe.get('_source.TimeStamp'), dataframe.get('_source.Value'), color = "red")
plt.xlabel("TimeStamp", fontsize=16)
plt.ylabel("Value", fontsize=16)
plt.title("CO2 values on 1 week", fontsize=18)
plt.legend(fontsize=16)
# plt.savefig('plots_from_csv/CSV_Tests_1month.jpg', bbox_inches = 'tight')
plt.show()

# %%
#Let’s load the series we want to predict, Unique Visits, into a Forecaster object:
f = Forecaster(y=data['co2'],current_dates=data['time'], ForecastLength=600)
f
# Out:
# Forecaster(
#     DateStartActuals=1970-01-01T00:00:01.627862426
#     DateEndActuals=1970-01-01T00:00:01.627903224
#     Freq=None
#     N_actuals=681
#     ForecastLength=0
#     Xvars=[]
#     Differenced=0
#     TestLength=1
#     ValidationLength=1
#     ValidationMetric=rmse
#     ForecastsEvaluated=[]
#     CILevel=0.95
#     BootstrapSamples=100
#     CurrentEstimator=None
# )

# %%
#This shows we have 2,167 daily observations from 9/14/2014 through 8/19/2020 to forecast with.
#The first thing we should do after initializing the object is set its test length. We can choose a number of observations to use by passing an int to the function below,
#or split the data fractionally by passing a float between 0 and 1.
f.set_test_length(.2)

# %%
#Before beginning the forecasting process, we should get a better idea of the signals within the time series itself. 
#Using ACF, PACF, and Periodogram plots, we can observe how the series is auto-correlated. We can leave the test set out of all visualizations (train_only=True) 
#to not leak data when making decisions about which signals exist in the data.
f.plot_acf(train_only=True,lags=35)
plt.show()

# %%
f.plot_pacf(train_only=True,lags=35)
plt.show()

# %%
a, b = f.plot_periodogram(train_only=True)
plt.semilogy(a, b)
plt.show()

# %%
#There might be some drift in the data.
# f.seasonal_decompose(train_only=True).plot()
# plt.show()

# %%
critical_pval = 0.05
print('-'*100)
print('Augmented Dickey-Fuller results:')
stat, pval, _, _, _, _ = f.adf_test(full_res=True)
print('the test-stat value is: {:.2f}'.format(stat))
print('the p-value is {:.4f}'.format(pval))
print('the series is {}'.format('stationary' if pval < critical_pval else 'not stationary'))
print('-'*100)
# Out:
# ----------------------------------------------------------------------------------------------------
# Augmented Dickey-Fuller results:
# the test-stat value is: 0.49
# the p-value is 0.9845
# the series is not stationary
# ----------------------------------------------------------------------------------------------------

# %%
f.generate_future_dates(60) # forecast horizon
f.set_validation_length(60) # validation set length for tuning hyperparameters
f.add_ar_terms(7) # 7 dep variable lags
f.add_AR_terms((5,7)) # 5 weekly seasonaly dep variable lags
f.add_seasonal_regressors(
    'month',
    'quarter',
    'week',
    'dayofyear',
    raw=False,
    sincos=True) # wave-form seasonality
f.add_seasonal_regressors(
    'dayofweek',
    'week',
    raw=False,
    dummy=True,
    drop_first=True
) # dummy variable seasonality
f.add_seasonal_regressors('year') # yearly trend
f
# Out:
# Forecaster(
#     DateStartActuals=1970-01-01T00:00:01.627862426
#     DateEndActuals=1970-01-01T00:00:01.627903224
#     Freq=None
#     N_actuals=681
#     ForecastLength=60
#     Xvars=['AR1', 'AR2', 'AR3', 'AR4', 'AR5', 'AR6', 'AR7', 'AR14', 'AR21', 'AR28', 'AR35', 'monthsin', 'monthcos', 'quartersin', 'quartercos', 'weeksin', 'weekcos', 'dayofyearsin', 'dayofyearcos', 'year']
#     Differenced=0
#     TestLength=136
#     ValidationLength=60
#     ValidationMetric=rmse
#     ForecastsEvaluated=[]
#     CILevel=0.95
#     BootstrapSamples=100
#     CurrentEstimator=None
# )

# %%
f.set_estimator('prophet')
f.manual_forecast()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\VALI\Repos\Licenta_Poluare\poluare_test20_profetul-vietii-2.ipynb Cell 21' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/VALI/Repos/Licenta_Poluare/poluare_test20_profetul-vietii-2.ipynb#ch0000016?line=0'>1</a> f.set_estimator('prophet')
# ----> <a href='vscode-notebook-cell:/c%3A/VALI/Repos/Licenta_Poluare/poluare_test20_profetul-vietii-2.ipynb#ch0000016?line=1'>2</a> f.manual_forecast()
#
# File c:\VALI\Programs\Miniconda3\envs\myenv\lib\site-packages\scalecast\Forecaster.py:2773, in Forecaster.manual_forecast(self, call_me, dynamic_testing, test_only, **kwargs)
#    <a href='file:///c%3A/VALI/Programs/Miniconda3/envs/myenv/lib/site-packages/scalecast/Forecaster.py?line=2767'>2768</a> self.dynamic_testing = dynamic_testing
#    <a href='file:///c%3A/VALI/Programs/Miniconda3/envs/myenv/lib/site-packages/scalecast/Forecaster.py?line=2768'>2769</a> self.call_me = self.estimator if call_me is None else call_me
#    <a href='file:///c%3A/VALI/Programs/Miniconda3/envs/myenv/lib/site-packages/scalecast/Forecaster.py?line=2769'>2770</a> result = (
#    <a href='file:///c%3A/VALI/Programs/Miniconda3/envs/myenv/lib/site-packages/scalecast/Forecaster.py?line=2770'>2771</a>     self._forecast_sklearn(fcster=self.estimator, dynamic_testing=dynamic_testing, test_only=test_only, **kwargs)
#    <a href='file:///c%3A/VALI/Programs/Miniconda3/envs/myenv/lib/site-packages/scalecast/Forecaster.py?line=2771'>2772</a>     if self.estimator in _sklearn_estimators_
# -> <a href='file:///c%3A/VALI/Programs/Miniconda3/envs/myenv/lib/site-packages/scalecast/Forecaster.py?line=2772'>2773</a>     else getattr(self, f"_forecast_{self.estimator}")(dynamic_testing=dynamic_testing, test_only=test_only, **kwargs)
#    <a href='file:///c%3A/VALI/Programs/Miniconda3/envs/myenv/lib/site-packages/scalecast/Forecaster.py?line=2773'>2774</a> ) # 0 - forecast, 1 - fitted vals, 2 - Xvars, 3 - regr
#    <a href='file:///c%3A/VALI/Programs/Miniconda3/envs/myenv/lib/site-packages/scalecast/Forecaster.py?line=2774'>2775</a> self.forecast = [i for i in result[0]]
#    <a href='file:///c%3A/VALI/Programs/Miniconda3/envs/myenv/lib/site-packages/scalecast/Forecaster.py?line=2775'>2776</a> self.fitted_values = [i for i in result[1]]
#
# File c:\VALI\Programs\Miniconda3\envs\myenv\lib\site-packages\scalecast\Forecaster.py:853, in Forecaster._forecast_prophet(self, tune, Xvars, dynamic_testing, cap, floor, test_only, **kwargs)
#     <a href='file:///c%3A/VALI/Programs/Miniconda3/envs/myenv/lib/site-packages/scalecast/Forecaster.py?line=850'>851</a> regr = Prophet(**kwargs)
#     <a href='file:///c%3A/VALI/Programs/Miniconda3/envs/myenv/lib/site-packages/scalecast/Forecaster.py?line=851'>852</a> regr.fit(X)
# --> <a href='file:///c%3A/VALI/Programs/Miniconda3/envs/myenv/lib/site-packages/scalecast/Forecaster.py?line=852'>853</a> fcst = regr.predict(p)
#     <a href='file:///c%3A/VALI/Programs/Miniconda3/envs/myenv/lib/site-packages/scalecast/Forecaster.py?line=853'>854</a> return (fcst["yhat"],regr.predict(X)["yhat"],Xvars,regr)
#
# File c:\VALI\Programs\Miniconda3\envs\myenv\lib\site-packages\fbprophet\forecaster.py:1204, in Prophet.predict(self, df)
#    <a href='file:///c%3A/VALI/Programs/Miniconda3/envs/myenv/lib/site-packages/fbprophet/forecaster.py?line=1201'>1202</a> seasonal_components = self.predict_seasonal_components(df)
#    <a href='file:///c%3A/VALI/Programs/Miniconda3/envs/myenv/lib/site-packages/fbprophet/forecaster.py?line=1202'>1203</a> if self.uncertainty_samples:
# -> <a href='file:///c%3A/VALI/Programs/Miniconda3/envs/myenv/lib/site-packages/fbprophet/forecaster.py?line=1203'>1204</a>     intervals = self.predict_uncertainty(df)
#    <a href='file:///c%3A/VALI/Programs/Miniconda3/envs/myenv/lib/site-packages/fbprophet/forecaster.py?line=1204'>1205</a> else:
#    <a href='file:///c%3A/VALI/Programs/Miniconda3/envs/myenv/lib/site-packages/fbprophet/forecaster.py?line=1205'>1206</a>     intervals = None
#
# File c:\VALI\Programs\Miniconda3\envs\myenv\lib\site-packages\fbprophet\forecaster.py:1435, in Prophet.predict_uncertainty(self, df)
#    <a href='file:///c%3A/VALI/Programs/Miniconda3/envs/myenv/lib/site-packages/fbprophet/forecaster.py?line=1423'>1424</a> def predict_uncertainty(self, df):
#    <a href='file:///c%3A/VALI/Programs/Miniconda3/envs/myenv/lib/site-packages/fbprophet/forecaster.py?line=1424'>1425</a>     """Prediction intervals for yhat and trend.
#    <a href='file:///c%3A/VALI/Programs/Miniconda3/envs/myenv/lib/site-packages/fbprophet/forecaster.py?line=1425'>1426</a>
#    <a href='file:///c%3A/VALI/Programs/Miniconda3/envs/myenv/lib/site-packages/fbprophet/forecaster.py?line=1426'>1427</a>     Parameters
#    (...)
#    <a href='file:///c%3A/VALI/Programs/Miniconda3/envs/myenv/lib/site-packages/fbprophet/forecaster.py?line=1432'>1433</a>     Dataframe with uncertainty intervals.
#    <a href='file:///c%3A/VALI/Programs/Miniconda3/envs/myenv/lib/site-packages/fbprophet/forecaster.py?line=1433'>1434</a>     """
# -> <a href='file:///c%3A/VALI/Programs/Miniconda3/envs/myenv/lib/site-packages/fbprophet/forecaster.py?line=1434'>1435</a>     sim_values = self.sample_posterior_predictive(df)
#    <a href='file:///c%3A/VALI/Programs/Miniconda3/envs/myenv/lib/site-packages/fbprophet/forecaster.py?line=1436'>1437</a>     lower_p = 100 * (1.0 - self.interval_width) / 2
#    <a href='file:///c%3A/VALI/Programs/Miniconda3/envs/myenv/lib/site-packages/fbprophet/forecaster.py?line=1437'>1438</a>     upper_p = 100 * (1.0 + self.interval_width) / 2
#
# File c:\VALI\Programs\Miniconda3\envs\myenv\lib\site-packages\fbprophet\forecaster.py:1388, in Prophet.sample_posterior_predictive(self, df)
#    <a href='file:///c%3A/VALI/Programs/Miniconda3/envs/myenv/lib/site-packages/fbprophet/forecaster.py?line=1385'>1386</a> for i in range(n_iterations):
#    <a href='file:///c%3A/VALI/Programs/Miniconda3/envs/myenv/lib/site-packages/fbprophet/forecaster.py?line=1386'>1387</a>     for _j in range(samp_per_iter):
# -> <a href='file:///c%3A/VALI/Programs/Miniconda3/envs/myenv/lib/site-packages/fbprophet/forecaster.py?line=1387'>1388</a>         sim = self.sample_model(
#    <a href='file:///c%3A/VALI/Programs/Miniconda3/envs/myenv/lib/site-packages/fbprophet/forecaster.py?line=1388'>1389</a>             df=df,
#    <a href='file:///c%3A/VALI/Programs/Miniconda3/envs/myenv/lib/site-packages/fbprophet/forecaster.py?line=1389'>1390</a>             seasonal_features=seasonal_features,
#    <a href='file:///c%3A/VALI/Programs/Miniconda3/envs/myenv/lib/site-packages/fbprophet/forecaster.py?line=1390'>1391</a>             iteration=i,
#    <a href='file:///c%3A/VALI/Programs/Miniconda3/envs/myenv/lib/site-packages/fbprophet/forecaster.py?line=1391'>1392</a>             s_a=component_cols['additive_terms'],
#    <a href='file:///c%3A/VALI/Programs/Miniconda3/envs/myenv/lib/site-packages/fbprophet/forecaster.py?line=1392'>1393</a>             s_m=component_cols['multiplicative_terms'],
#    <a href='file:///c%3A/VALI/Programs/Miniconda3/envs/myenv/lib/site-packages/fbprophet/forecaster.py?line=1393'>1394</a>         )
#    <a href='file:///c%3A/VALI/Programs/Miniconda3/envs/myenv/lib/site-packages/fbprophet/forecaster.py?line=1394'>1395</a>         for key in sim_values:
#    <a href='file:///c%3A/VALI/Programs/Miniconda3/envs/myenv/lib/site-packages/fbprophet/forecaster.py?line=1395'>1396</a>             sim_values[key].append(sim[key])
#
# File c:\VALI\Programs\Miniconda3\envs\myenv\lib\site-packages\fbprophet\forecaster.py:1464, in Prophet.sample_model(self, df, seasonal_features, iteration, s_a, s_m)
#    <a href='file:///c%3A/VALI/Programs/Miniconda3/envs/myenv/lib/site-packages/fbprophet/forecaster.py?line=1448'>1449</a> def sample_model(self, df, seasonal_features, iteration, s_a, s_m):
#    <a href='file:///c%3A/VALI/Programs/Miniconda3/envs/myenv/lib/site-packages/fbprophet/forecaster.py?line=1449'>1450</a>     """Simulate observations from the extrapolated generative model.
#    <a href='file:///c%3A/VALI/Programs/Miniconda3/envs/myenv/lib/site-packages/fbprophet/forecaster.py?line=1450'>1451</a>
#    <a href='file:///c%3A/VALI/Programs/Miniconda3/envs/myenv/lib/site-packages/fbprophet/forecaster.py?line=1451'>1452</a>     Parameters
#    (...)
#    <a href='file:///c%3A/VALI/Programs/Miniconda3/envs/myenv/lib/site-packages/fbprophet/forecaster.py?line=1461'>1462</a>     Dataframe with trend and yhat, each like df['t'].
#    <a href='file:///c%3A/VALI/Programs/Miniconda3/envs/myenv/lib/site-packages/fbprophet/forecaster.py?line=1462'>1463</a>     """
# -> <a href='file:///c%3A/VALI/Programs/Miniconda3/envs/myenv/lib/site-packages/fbprophet/forecaster.py?line=1463'>1464</a>     trend = self.sample_predictive_trend(df, iteration)
#    <a href='file:///c%3A/VALI/Programs/Miniconda3/envs/myenv/lib/site-packages/fbprophet/forecaster.py?line=1465'>1466</a>     beta = self.params['beta'][iteration]
#    <a href='file:///c%3A/VALI/Programs/Miniconda3/envs/myenv/lib/site-packages/fbprophet/forecaster.py?line=1466'>1467</a>     Xb_a = np.matmul(seasonal_features.values,
#    <a href='file:///c%3A/VALI/Programs/Miniconda3/envs/myenv/lib/site-packages/fbprophet/forecaster.py?line=1467'>1468</a>                      beta * s_a.values) * self.y_scale
#
# File c:\VALI\Programs\Miniconda3\envs\myenv\lib\site-packages\fbprophet\forecaster.py:1501, in Prophet.sample_predictive_trend(self, df, iteration)
#    <a href='file:///c%3A/VALI/Programs/Miniconda3/envs/myenv/lib/site-packages/fbprophet/forecaster.py?line=1498'>1499</a> if T > 1:
#    <a href='file:///c%3A/VALI/Programs/Miniconda3/envs/myenv/lib/site-packages/fbprophet/forecaster.py?line=1499'>1500</a>     S = len(self.changepoints_t)
# -> <a href='file:///c%3A/VALI/Programs/Miniconda3/envs/myenv/lib/site-packages/fbprophet/forecaster.py?line=1500'>1501</a>     n_changes = np.random.poisson(S * (T - 1))
#    <a href='file:///c%3A/VALI/Programs/Miniconda3/envs/myenv/lib/site-packages/fbprophet/forecaster.py?line=1501'>1502</a> else:
#    <a href='file:///c%3A/VALI/Programs/Miniconda3/envs/myenv/lib/site-packages/fbprophet/forecaster.py?line=1502'>1503</a>     n_changes = 0
#
# File mtrand.pyx:3595, in numpy.random.mtrand.RandomState.poisson()
#
# File _common.pyx:882, in numpy.random._common.disc()
#
# File _common.pyx:431, in numpy.random._common.check_constraint()
#
# ValueError: lam value too large

# %%
f.plot_test_set(ci=True,models='prophet')
plt.show()
