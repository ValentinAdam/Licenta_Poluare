# %%
import pandas as pd

# %%
import requests
from requests.auth import HTTPBasicAuth
auth = HTTPBasicAuth('elastic', 'AWbtmGda2Q7BI2bYpdjyF4qd')
url = 'https://8f9677360fc34e2eb943d737b2597c7b.us-east-1.aws.found.io:9243/brasov-dev/_search?size=200000&q=*&sort=TimeStamp:desc'

# %%
response = requests.get(url=url, auth=auth)

# %%
response
# Out:
# <Response [200]>

# %%
import json
data = json.loads(response.text)

# %%
data
# Out:
# {'took': 5326,
#  'timed_out': False,
#  '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 10000, 'relation': 'gte'},
#   'max_score': None,
#   'hits': [{'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'EzI25X8B3mQrnl8XHqm6',
#     '_score': None,
#     '_source': {'Source': 'Waqi',
#      'Sensor': 'no2',
#      'Value': 1.2,
#      'LocationLat': 45.7167,
#      'LocationLong': 25.6333,
#      'TimeStamp': 1648818000000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648818000000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'FDI25X8B3mQrnl8XHqm9',
#     '_score': None,
#     '_source': {'Source': 'Waqi',
#      'Sensor': 'so2',
#      'Value': 1.4,
#      'LocationLat': 45.7167,
#      'LocationLong': 25.6333,
#      'TimeStamp': 1648818000000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648818000000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'FTI25X8B3mQrnl8XHqm9',
#     '_score': None,
#     '_source': {'Source': 'Waqi',
#      'Sensor': 'pm10',
#      'Value': 11,
#      'LocationLat': 45.7167,
#      'LocationLong': 25.6333,
#      'TimeStamp': 1648818000000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648818000000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'FjI25X8B3mQrnl8XH6ke',
#     '_score': None,
#     '_source': {'Source': 'Waqi',
#      'Sensor': 'no2',
#      'Value': 6.7,
#      'LocationLat': 45.6542706,
#      'LocationLong': 25.6240614,
#      'TimeStamp': 1648818000000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648818000000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'hjI25X8B3mQrnl8XGKjw',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm25',
#      'Value': 10,
#      'LocationLat': 45.6536,
#      'LocationLong': 25.599,
#      'TimeStamp': 1648818000000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648818000000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'hzI25X8B3mQrnl8XGKjy',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm1',
#      'Value': 2,
#      'LocationLat': 45.6536,
#      'LocationLong': 25.599,
#      'TimeStamp': 1648818000000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648818000000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'izI25X8B3mQrnl8XGagE',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm10',
#      'Value': 12,
#      'LocationLat': 45.6536,
#      'LocationLong': 25.599,
#      'TimeStamp': 1648818000000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648818000000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'EjI25X8B3mQrnl8XHqm6',
#     '_score': None,
#     '_source': {'Source': 'Waqi',
#      'Sensor': 'o3',
#      'Value': 41.5,
#      'LocationLat': 45.7167,
#      'LocationLong': 25.6333,
#      'TimeStamp': 1648818000000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648818000000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'FzI25X8B3mQrnl8XH6ke',
#     '_score': None,
#     '_source': {'Source': 'Waqi',
#      'Sensor': 'so2',
#      'Value': 1.8,
#      'LocationLat': 45.6542706,
#      'LocationLong': 25.6240614,
#      'TimeStamp': 1648818000000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648818000000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'GDI25X8B3mQrnl8XH6kh',
#     '_score': None,
#     '_source': {'Source': 'Waqi',
#      'Sensor': 'pm10',
#      'Value': 13,
#      'LocationLat': 45.6542706,
#      'LocationLong': 25.6240614,
#      'TimeStamp': 1648818000000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648818000000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'GTI25X8B3mQrnl8XH6kv',
#     '_score': None,
#     '_source': {'Source': 'Waqi',
#      'Sensor': 'pm10',
#      'Value': 12,
#      'LocationLat': 45.6598333,
#      'LocationLong': 25.6144883,
#      'TimeStamp': 1648818000000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648818000000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'GjI25X8B3mQrnl8XH6la',
#     '_score': None,
#     '_source': {'Source': 'Waqi',
#      'Sensor': 'so2',
#      'Value': 1.8,
#      'LocationLat': 45.6491174,
#      'LocationLong': 25.6041355,
#      'TimeStamp': 1648818000000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648818000000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'GzI25X8B3mQrnl8XH6la',
#     '_score': None,
#     '_source': {'Source': 'Waqi',
#      'Sensor': 'pm10',
#      'Value': 13,
#      'LocationLat': 45.6491174,
#      'LocationLong': 25.6041355,
#      'TimeStamp': 1648818000000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648818000000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'HDI25X8B3mQrnl8XH6lb',
#     '_score': None,
#     '_source': {'Source': 'Waqi',
#      'Sensor': 'no2',
#      'Value': 11.9,
#      'LocationLat': 45.6343302,
#      'LocationLong': 25.6338716,
#      'TimeStamp': 1648818000000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648818000000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'HTI25X8B3mQrnl8XH6lc',
#     '_score': None,
#     '_source': {'Source': 'Waqi',
#      'Sensor': 'pm10',
#      'Value': 7,
#      'LocationLat': 45.6343302,
#      'LocationLong': 25.6338716,
#      'TimeStamp': 1648818000000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648818000000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'HjI25X8B3mQrnl8XH6ld',
#     '_score': None,
#     '_source': {'Source': 'Waqi',
#      'Sensor': 'o3',
#      'Value': 35.4,
#      'LocationLat': 45.6491174,
#      'LocationLong': 25.6041355,
#      'TimeStamp': 1648818000000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648818000000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'HzI25X8B3mQrnl8XH6le',
#     '_score': None,
#     '_source': {'Source': 'Waqi',
#      'Sensor': 'no2',
#      'Value': 7.2,
#      'LocationLat': 45.6491174,
#      'LocationLong': 25.6041355,
#      'TimeStamp': 1648818000000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648818000000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'IDI25X8B3mQrnl8XH6m6',
#     '_score': None,
#     '_source': {'Source': 'Waqi',
#      'Sensor': 'no2',
#      'Value': 13.6,
#      'LocationLat': 45.6598333,
#      'LocationLong': 25.6144883,
#      'TimeStamp': 1648818000000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648818000000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'ljI25X8B3mQrnl8XGqiM',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm1',
#      'Value': 2,
#      'LocationLat': 45.645914,
#      'LocationLong': 25.602642,
#      'TimeStamp': 1648817999000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648817999000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'oDI25X8B3mQrnl8XG6hf',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm25',
#      'Value': 3,
#      'LocationLat': 45.645914,
#      'LocationLong': 25.602642,
#      'TimeStamp': 1648817999000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648817999000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': '0jI25X8B3mQrnl8XHKiW',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm10',
#      'Value': 3,
#      'LocationLat': 45.645914,
#      'LocationLong': 25.602642,
#      'TimeStamp': 1648817999000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648817999000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'qzI25X8B3mQrnl8XG6i_',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm25',
#      'Value': 1,
#      'LocationLat': 45.641274,
#      'LocationLong': 25.614817,
#      'TimeStamp': 1648817997000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648817997000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'BDI25X8B3mQrnl8XHalJ',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm10',
#      'Value': 2,
#      'LocationLat': 45.641274,
#      'LocationLong': 25.614817,
#      'TimeStamp': 1648817997000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648817997000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': '6DI25X8B3mQrnl8XHKjc',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm1',
#      'Value': 1,
#      'LocationLat': 45.641274,
#      'LocationLong': 25.614817,
#      'TimeStamp': 1648817997000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648817997000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'pzI25X8B3mQrnl8XG6if',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm10',
#      'Value': 1,
#      'LocationLat': 45.646976,
#      'LocationLong': 25.595224,
#      'TimeStamp': 1648817996000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648817996000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': '1TI25X8B3mQrnl8XHKia',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm1',
#      'Value': 0,
#      'LocationLat': 45.646976,
#      'LocationLong': 25.595224,
#      'TimeStamp': 1648817996000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648817996000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': '8zI25X8B3mQrnl8XHKjr',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm25',
#      'Value': 0,
#      'LocationLat': 45.646976,
#      'LocationLong': 25.595224,
#      'TimeStamp': 1648817996000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648817996000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'eTI25X8B3mQrnl8XF6g2',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm25',
#      'Value': 6,
#      'LocationLat': 45.653509,
#      'LocationLong': 25.56612,
#      'TimeStamp': 1648817989000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648817989000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'ejI25X8B3mQrnl8XF6hv',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm1',
#      'Value': 4,
#      'LocationLat': 45.653509,
#      'LocationLong': 25.56612,
#      'TimeStamp': 1648817989000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648817989000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'fzI25X8B3mQrnl8XGKhV',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm10',
#      'Value': 7,
#      'LocationLat': 45.653509,
#      'LocationLong': 25.56612,
#      'TimeStamp': 1648817989000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648817989000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'yTI25X8B3mQrnl8XHKiE',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'o3',
#      'Value': 20,
#      'LocationLat': 45.651464,
#      'LocationLong': 25.615426,
#      'TimeStamp': 1648817983000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648817983000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'yjI25X8B3mQrnl8XHKiG',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm1',
#      'Value': 3,
#      'LocationLat': 45.651464,
#      'LocationLong': 25.615426,
#      'TimeStamp': 1648817983000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648817983000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'pDI25X8B3mQrnl8XG6iT',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm1',
#      'Value': 7,
#      'LocationLat': 45.55914,
#      'LocationLong': 25.324771,
#      'TimeStamp': 1648817983000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648817983000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'pjI25X8B3mQrnl8XG6id',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm25',
#      'Value': 7,
#      'LocationLat': 45.55914,
#      'LocationLong': 25.324771,
#      'TimeStamp': 1648817983000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648817983000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'zjI25X8B3mQrnl8XHKiO',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm10',
#      'Value': 9,
#      'LocationLat': 45.55914,
#      'LocationLong': 25.324771,
#      'TimeStamp': 1648817983000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648817983000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': '0DI25X8B3mQrnl8XHKiQ',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm10',
#      'Value': 5,
#      'LocationLat': 45.651464,
#      'LocationLong': 25.615426,
#      'TimeStamp': 1648817983000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648817983000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': '0TI25X8B3mQrnl8XHKiT',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'cho2',
#      'Value': 7,
#      'LocationLat': 45.651464,
#      'LocationLong': 25.615426,
#      'TimeStamp': 1648817983000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648817983000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': '5jI25X8B3mQrnl8XHKjb',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm25',
#      'Value': 5,
#      'LocationLat': 45.651464,
#      'LocationLong': 25.615426,
#      'TimeStamp': 1648817983000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648817983000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': '7TI25X8B3mQrnl8XHKjk',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'co2',
#      'Value': 550,
#      'LocationLat': 45.651464,
#      'LocationLong': 25.615426,
#      'TimeStamp': 1648817983000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648817983000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'xjI25X8B3mQrnl8XHKiA',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm10',
#      'Value': 6,
#      'LocationLat': 45.700748,
#      'LocationLong': 25.442761,
#      'TimeStamp': 1648817981000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648817981000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'kDI25X8B3mQrnl8XGajN',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm25',
#      'Value': 5,
#      'LocationLat': 45.700748,
#      'LocationLong': 25.442761,
#      'TimeStamp': 1648817981000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648817981000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'kzI25X8B3mQrnl8XGqgo',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm1',
#      'Value': 3,
#      'LocationLat': 45.700748,
#      'LocationLong': 25.442761,
#      'TimeStamp': 1648817981000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648817981000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'fjI25X8B3mQrnl8XF6jj',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm10',
#      'Value': 16,
#      'LocationLat': 45.6568,
#      'LocationLong': 25.5917,
#      'TimeStamp': 1648817974000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648817974000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'mTI25X8B3mQrnl8XG6g0',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm1',
#      'Value': 3,
#      'LocationLat': 45.6568,
#      'LocationLong': 25.5917,
#      'TimeStamp': 1648817974000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648817974000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'mzI25X8B3mQrnl8XG6g2',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm25',
#      'Value': 11,
#      'LocationLat': 45.6568,
#      'LocationLong': 25.5917,
#      'TimeStamp': 1648817974000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648817974000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'gTI25X8B3mQrnl8XGKiB',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm25',
#      'Value': 14,
#      'LocationLat': 45.702594,
#      'LocationLong': 25.456175,
#      'TimeStamp': 1648817966000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648817966000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'iTI25X8B3mQrnl8XGKj6',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm10',
#      'Value': 20,
#      'LocationLat': 45.702594,
#      'LocationLong': 25.456175,
#      'TimeStamp': 1648817966000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648817966000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'jzI25X8B3mQrnl8XGai0',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm1',
#      'Value': 1,
#      'LocationLat': 45.702594,
#      'LocationLong': 25.456175,
#      'TimeStamp': 1648817966000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648817966000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'rTI25X8B3mQrnl8XG6jb',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm10',
#      'Value': 2,
#      'LocationLat': 45.614267,
#      'LocationLong': 25.63325,
#      'TimeStamp': 1648817965000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648817965000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'sDI25X8B3mQrnl8XG6j8',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm1',
#      'Value': 1,
#      'LocationLat': 45.614267,
#      'LocationLong': 25.63325,
#      'TimeStamp': 1648817965000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648817965000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'DDI25X8B3mQrnl8XHaml',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm25',
#      'Value': 2,
#      'LocationLat': 45.614267,
#      'LocationLong': 25.63325,
#      'TimeStamp': 1648817965000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648817965000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'wzI25X8B3mQrnl8XHKh-',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'o3',
#      'Value': 59,
#      'LocationLat': 45.673977,
#      'LocationLong': 25.606484,
#      'TimeStamp': 1648817964000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648817964000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'yDI25X8B3mQrnl8XHKiD',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'co2',
#      'Value': 484,
#      'LocationLat': 45.673977,
#      'LocationLong': 25.606484,
#      'TimeStamp': 1648817964000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648817964000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'zDI25X8B3mQrnl8XHKiN',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'cho2',
#      'Value': 0,
#      'LocationLat': 45.673977,
#      'LocationLong': 25.606484,
#      'TimeStamp': 1648817964000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648817964000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'BjI25X8B3mQrnl8XHalK',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm10',
#      'Value': 5,
#      'LocationLat': 45.673977,
#      'LocationLong': 25.606484,
#      'TimeStamp': 1648817964000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648817964000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'gjI25X8B3mQrnl8XGKiW',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm25',
#      'Value': 14,
#      'LocationLat': 45.39324,
#      'LocationLong': 25.442933,
#      'TimeStamp': 1648817964000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648817964000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'gzI25X8B3mQrnl8XGKiu',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm10',
#      'Value': 20,
#      'LocationLat': 45.39324,
#      'LocationLong': 25.442933,
#      'TimeStamp': 1648817964000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648817964000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'hDI25X8B3mQrnl8XGKjH',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm1',
#      'Value': 4,
#      'LocationLat': 45.39324,
#      'LocationLong': 25.442933,
#      'TimeStamp': 1648817964000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648817964000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'zTI25X8B3mQrnl8XHKiN',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm25',
#      'Value': 5,
#      'LocationLat': 45.673977,
#      'LocationLong': 25.606484,
#      'TimeStamp': 1648817964000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648817964000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'zzI25X8B3mQrnl8XHKiQ',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm1',
#      'Value': 3,
#      'LocationLat': 45.673977,
#      'LocationLong': 25.606484,
#      'TimeStamp': 1648817964000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648817964000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'rDI25X8B3mQrnl8XG6jI',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm1',
#      'Value': 3,
#      'LocationLat': 45.703546,
#      'LocationLong': 25.679012,
#      'TimeStamp': 1648817962000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648817962000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'ozI25X8B3mQrnl8XG6iK',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm1',
#      'Value': 0,
#      'LocationLat': 45.71737,
#      'LocationLong': 25.68571,
#      'TimeStamp': 1648817962000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648817962000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'qTI25X8B3mQrnl8XG6i-',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm10',
#      'Value': 9,
#      'LocationLat': 45.703546,
#      'LocationLong': 25.679012,
#      'TimeStamp': 1648817962000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648817962000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': '0zI25X8B3mQrnl8XHKiX',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm10',
#      'Value': 2,
#      'LocationLat': 45.71737,
#      'LocationLong': 25.68571,
#      'TimeStamp': 1648817962000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648817962000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': '7DI25X8B3mQrnl8XHKji',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm25',
#      'Value': 5,
#      'LocationLat': 45.703546,
#      'LocationLong': 25.679012,
#      'TimeStamp': 1648817962000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648817962000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': '7zI25X8B3mQrnl8XHKjk',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm25',
#      'Value': 1,
#      'LocationLat': 45.71737,
#      'LocationLong': 25.68571,
#      'TimeStamp': 1648817962000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648817962000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'AzI25X8B3mQrnl8XHalH',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm10',
#      'Value': 9,
#      'LocationLat': 45.657148,
#      'LocationLong': 25.563752,
#      'TimeStamp': 1648817961000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648817961000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'BTI25X8B3mQrnl8XHalJ',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm25',
#      'Value': 8,
#      'LocationLat': 45.657148,
#      'LocationLong': 25.563752,
#      'TimeStamp': 1648817961000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648817961000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'CDI25X8B3mQrnl8XHalL',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'cho2',
#      'Value': 7,
#      'LocationLat': 45.657148,
#      'LocationLong': 25.563752,
#      'TimeStamp': 1648817961000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648817961000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'DTI25X8B3mQrnl8XHamx',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm1',
#      'Value': 6,
#      'LocationLat': 45.657148,
#      'LocationLong': 25.563752,
#      'TimeStamp': 1648817961000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648817961000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': '3DI25X8B3mQrnl8XHKiq',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'o3',
#      'Value': 20,
#      'LocationLat': 45.657148,
#      'LocationLong': 25.563752,
#      'TimeStamp': 1648817961000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648817961000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': '7jI25X8B3mQrnl8XHKjk',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'co2',
#      'Value': 605,
#      'LocationLat': 45.657148,
#      'LocationLong': 25.563752,
#      'TimeStamp': 1648817961000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648817961000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'vjI25X8B3mQrnl8XHKhV',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm10',
#      'Value': 7,
#      'LocationLat': 45.7017883,
#      'LocationLong': 25.5482448,
#      'TimeStamp': 1648817953000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648817953000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'nDI25X8B3mQrnl8XG6g9',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm1',
#      'Value': 1,
#      'LocationLat': 45.7017883,
#      'LocationLong': 25.5482448,
#      'TimeStamp': 1648817953000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648817953000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': '3TI25X8B3mQrnl8XHKi1',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm25',
#      'Value': 5,
#      'LocationLat': 45.7017883,
#      'LocationLong': 25.5482448,
#      'TimeStamp': 1648817953000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648817953000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': '2zI25X8B3mQrnl8XHKio',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm1',
#      'Value': 3,
#      'LocationLat': 45.638767,
#      'LocationLong': 25.586021,
#      'TimeStamp': 1648817951000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648817951000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': '3jI25X8B3mQrnl8XHKi_',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm10',
#      'Value': 4,
#      'LocationLat': 45.638767,
#      'LocationLong': 25.586021,
#      'TimeStamp': 1648817951000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648817951000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': '-jI25X8B3mQrnl8XHKjx',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm25',
#      'Value': 4,
#      'LocationLat': 45.638767,
#      'LocationLong': 25.586021,
#      'TimeStamp': 1648817951000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648817951000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'BzI25X8B3mQrnl8XHalL',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm25',
#      'Value': 9,
#      'LocationLat': 45.676195,
#      'LocationLong': 25.645632,
#      'TimeStamp': 1648817950000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648817950000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'DzI25X8B3mQrnl8XHam3',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm10',
#      'Value': 10,
#      'LocationLat': 45.676195,
#      'LocationLong': 25.645632,
#      'TimeStamp': 1648817950000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648817950000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': '4DI25X8B3mQrnl8XHKjY',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'cho2',
#      'Value': 7,
#      'LocationLat': 45.676195,
#      'LocationLong': 25.645632,
#      'TimeStamp': 1648817950000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648817950000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': '6zI25X8B3mQrnl8XHKje',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'co2',
#      'Value': 574,
#      'LocationLat': 45.676195,
#      'LocationLong': 25.645632,
#      'TimeStamp': 1648817950000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648817950000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': '8TI25X8B3mQrnl8XHKjn',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'o3',
#      'Value': 25,
#      'LocationLat': 45.676195,
#      'LocationLong': 25.645632,
#      'TimeStamp': 1648817950000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648817950000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': '_DI25X8B3mQrnl8XHKjz',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm1',
#      'Value': 7,
#      'LocationLat': 45.676195,
#      'LocationLong': 25.645632,
#      'TimeStamp': 1648817950000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648817950000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'rjI25X8B3mQrnl8XG6jc',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm1',
#      'Value': 1,
#      'LocationLat': 45.698269,
#      'LocationLong': 25.558889,
#      'TimeStamp': 1648817949000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648817949000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': '_jI25X8B3mQrnl8XHahB',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm10',
#      'Value': 4,
#      'LocationLat': 45.698269,
#      'LocationLong': 25.558889,
#      'TimeStamp': 1648817949000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648817949000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': '5TI25X8B3mQrnl8XHKjb',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm25',
#      'Value': 2,
#      'LocationLat': 45.698269,
#      'LocationLong': 25.558889,
#      'TimeStamp': 1648817949000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648817949000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': '2jI25X8B3mQrnl8XHKik',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm1',
#      'Value': 1,
#      'LocationLat': 45.623958,
#      'LocationLong': 25.481535,
#      'TimeStamp': 1648817945000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648817945000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': '8jI25X8B3mQrnl8XHKjo',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm10',
#      'Value': 3,
#      'LocationLat': 45.623958,
#      'LocationLong': 25.481535,
#      'TimeStamp': 1648817945000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648817945000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': '-zI25X8B3mQrnl8XHKjx',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm25',
#      'Value': 2,
#      'LocationLat': 45.623958,
#      'LocationLong': 25.481535,
#      'TimeStamp': 1648817945000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648817945000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'uzI25X8B3mQrnl8XHKg9',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm25',
#      'Value': 10,
#      'LocationLat': 45.665184,
#      'LocationLong': 25.558891,
#      'TimeStamp': 1648817913000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648817913000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'vTI25X8B3mQrnl8XHKhF',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm1',
#      'Value': 1,
#      'LocationLat': 45.665184,
#      'LocationLong': 25.558891,
#      'TimeStamp': 1648817913000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648817913000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': '-TI25X8B3mQrnl8XHKju',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm10',
#      'Value': 7,
#      'LocationLat': 45.665184,
#      'LocationLong': 25.558891,
#      'TimeStamp': 1648817913000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648817913000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'tjI25X8B3mQrnl8XHKgu',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm25',
#      'Value': 16,
#      'LocationLat': 45.657861,
#      'LocationLong': 25.621916,
#      'TimeStamp': 1648817908000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648817908000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'uTI25X8B3mQrnl8XHKg2',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm1',
#      'Value': 6,
#      'LocationLat': 45.657861,
#      'LocationLong': 25.621916,
#      'TimeStamp': 1648817908000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648817908000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'ujI25X8B3mQrnl8XHKg7',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm10',
#      'Value': 13,
#      'LocationLat': 45.657861,
#      'LocationLong': 25.621916,
#      'TimeStamp': 1648817908000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648817908000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'ezI25X8B3mQrnl8XF6h2',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm10',
#      'Value': 14,
#      'LocationLat': 45.704032,
#      'LocationLong': 25.640955,
#      'TimeStamp': 1648816226000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648816226000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'hTI25X8B3mQrnl8XGKjJ',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm1',
#      'Value': 3,
#      'LocationLat': 45.704032,
#      'LocationLong': 25.640955,
#      'TimeStamp': 1648816226000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648816226000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'jDI25X8B3mQrnl8XGagR',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm25',
#      'Value': 11,
#      'LocationLat': 45.704032,
#      'LocationLong': 25.640955,
#      'TimeStamp': 1648816226000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648816226000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'MYb_5H8Bl-P5I54hJh76',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm10',
#      'Value': 17,
#      'LocationLat': 45.6536,
#      'LocationLong': 25.599,
#      'TimeStamp': 1648814400000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648814400000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'xYb_5H8Bl-P5I54hLx6T',
#     '_score': None,
#     '_source': {'Source': 'Waqi',
#      'Sensor': 'no2',
#      'Value': 11.1,
#      'LocationLat': 45.6598333,
#      'LocationLong': 25.6144883,
#      'TimeStamp': 1648814400000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648814400000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'yIb_5H8Bl-P5I54hMB6M',
#     '_score': None,
#     '_source': {'Source': 'Waqi',
#      'Sensor': 'so2',
#      'Value': 1.7,
#      'LocationLat': 45.6491174,
#      'LocationLong': 25.6041355,
#      'TimeStamp': 1648814400000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648814400000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'yob_5H8Bl-P5I54hMB6N',
#     '_score': None,
#     '_source': {'Source': 'Waqi',
#      'Sensor': 'no2',
#      'Value': 6,
#      'LocationLat': 45.6542706,
#      'LocationLong': 25.6240614,
#      'TimeStamp': 1648814400000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648814400000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'y4b_5H8Bl-P5I54hMB6O',
#     '_score': None,
#     '_source': {'Source': 'Waqi',
#      'Sensor': 'o3',
#      'Value': 35.9,
#      'LocationLat': 45.6491174,
#      'LocationLong': 25.6041355,
#      'TimeStamp': 1648814400000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648814400000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'zIb_5H8Bl-P5I54hMB6Q',
#     '_score': None,
#     '_source': {'Source': 'Waqi',
#      'Sensor': 'pm10',
#      'Value': 13,
#      'LocationLat': 45.6491174,
#      'LocationLong': 25.6041355,
#      'TimeStamp': 1648814400000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648814400000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'zob_5H8Bl-P5I54hMR4C',
#     '_score': None,
#     '_source': {'Source': 'Waqi',
#      'Sensor': 'so2',
#      'Value': 1.4,
#      'LocationLat': 45.7167,
#      'LocationLong': 25.6333,
#      'TimeStamp': 1648814400000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648814400000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'z4b_5H8Bl-P5I54hMR4E',
#     '_score': None,
#     '_source': {'Source': 'Waqi',
#      'Sensor': 'o3',
#      'Value': 42.1,
#      'LocationLat': 45.7167,
#      'LocationLong': 25.6333,
#      'TimeStamp': 1648814400000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648814400000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': '0Ib_5H8Bl-P5I54hMR4h',
#     '_score': None,
#     '_source': {'Source': 'Waqi',
#      'Sensor': 'no2',
#      'Value': 13.8,
#      'LocationLat': 45.6343302,
#      'LocationLong': 25.6338716,
#      'TimeStamp': 1648814400000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648814400000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': '0Yb_5H8Bl-P5I54hMR4i',
#     '_score': None,
#     '_source': {'Source': 'Waqi',
#      'Sensor': 'pm10',
#      'Value': 7,
#      'LocationLat': 45.6343302,
#      'LocationLong': 25.6338716,
#      'TimeStamp': 1648814400000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648814400000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': '0ob_5H8Bl-P5I54hMR66',
#     '_score': None,
#     '_source': {'Source': 'Waqi',
#      'Sensor': 'pm10',
#      'Value': 11,
#      'LocationLat': 45.7167,
#      'LocationLong': 25.6333,
#      'TimeStamp': 1648814400000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648814400000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': '04b_5H8Bl-P5I54hMR67',
#     '_score': None,
#     '_source': {'Source': 'Waqi',
#      'Sensor': 'no2',
#      'Value': 0.9,
#      'LocationLat': 45.7167,
#      'LocationLong': 25.6333,
#      'TimeStamp': 1648814400000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648814400000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'PIb_5H8Bl-P5I54hJx5s',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm25',
#      'Value': 11,
#      'LocationLat': 45.6536,
#      'LocationLong': 25.599,
#      'TimeStamp': 1648814400000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648814400000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'P4b_5H8Bl-P5I54hJx50',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm1',
#      'Value': 3,
#      'LocationLat': 45.6536,
#      'LocationLong': 25.599,
#      'TimeStamp': 1648814400000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648814400000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'xIb_5H8Bl-P5I54hLx6T',
#     '_score': None,
#     '_source': {'Source': 'Waqi',
#      'Sensor': 'pm10',
#      'Value': 12,
#      'LocationLat': 45.6598333,
#      'LocationLong': 25.6144883,
#      'TimeStamp': 1648814400000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648814400000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'xob_5H8Bl-P5I54hLx7L',
#     '_score': None,
#     '_source': {'Source': 'Waqi',
#      'Sensor': 'pm10',
#      'Value': 13,
#      'LocationLat': 45.6542706,
#      'LocationLong': 25.6240614,
#      'TimeStamp': 1648814400000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648814400000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'x4b_5H8Bl-P5I54hLx7R',
#     '_score': None,
#     '_source': {'Source': 'Waqi',
#      'Sensor': 'no2',
#      'Value': 6.1,
#      'LocationLat': 45.6491174,
#      'LocationLong': 25.6041355,
#      'TimeStamp': 1648814400000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648814400000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'yYb_5H8Bl-P5I54hMB6M',
#     '_score': None,
#     '_source': {'Source': 'Waqi',
#      'Sensor': 'so2',
#      'Value': 1.9,
#      'LocationLat': 45.6542706,
#      'LocationLong': 25.6240614,
#      'TimeStamp': 1648814400000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648814400000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'c4b_5H8Bl-P5I54hLB4Q',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm10',
#      'Value': 14,
#      'LocationLat': 45.645914,
#      'LocationLong': 25.602642,
#      'TimeStamp': 1648814399000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648814399000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'e4b_5H8Bl-P5I54hLB5k',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm25',
#      'Value': 12,
#      'LocationLat': 45.645914,
#      'LocationLong': 25.602642,
#      'TimeStamp': 1648814399000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648814399000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'i4b_5H8Bl-P5I54hLB7I',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm1',
#      'Value': 9,
#      'LocationLat': 45.645914,
#      'LocationLong': 25.602642,
#      'TimeStamp': 1648814399000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648814399000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'job_5H8Bl-P5I54hLB7L',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm25',
#      'Value': 7,
#      'LocationLat': 45.641274,
#      'LocationLong': 25.614817,
#      'TimeStamp': 1648814397000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648814397000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'j4b_5H8Bl-P5I54hLB7N',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm10',
#      'Value': 9,
#      'LocationLat': 45.641274,
#      'LocationLong': 25.614817,
#      'TimeStamp': 1648814397000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648814397000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'kYb_5H8Bl-P5I54hLB7R',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm1',
#      'Value': 3,
#      'LocationLat': 45.641274,
#      'LocationLong': 25.614817,
#      'TimeStamp': 1648814397000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648814397000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'lob_5H8Bl-P5I54hLB7e',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm1',
#      'Value': 3,
#      'LocationLat': 45.646976,
#      'LocationLong': 25.595224,
#      'TimeStamp': 1648814396000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648814396000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'm4b_5H8Bl-P5I54hLB7j',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm10',
#      'Value': 13,
#      'LocationLat': 45.646976,
#      'LocationLong': 25.595224,
#      'TimeStamp': 1648814396000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648814396000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': '1ob_5H8Bl-P5I54hNB7O',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm25',
#      'Value': 6,
#      'LocationLat': 45.646976,
#      'LocationLong': 25.595224,
#      'TimeStamp': 1648814396000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648814396000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'XYb_5H8Bl-P5I54hKh75',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm10',
#      'Value': 17,
#      'LocationLat': 45.653509,
#      'LocationLong': 25.56612,
#      'TimeStamp': 1648814389000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648814389000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'ZYb_5H8Bl-P5I54hKx5U',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm1',
#      'Value': 5,
#      'LocationLat': 45.653509,
#      'LocationLong': 25.56612,
#      'TimeStamp': 1648814389000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648814389000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'Nob_5H8Bl-P5I54hJx4L',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm25',
#      'Value': 10,
#      'LocationLat': 45.653509,
#      'LocationLong': 25.56612,
#      'TimeStamp': 1648814389000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648814389000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'dob_5H8Bl-P5I54hLB4V',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'o3',
#      'Value': 20,
#      'LocationLat': 45.651464,
#      'LocationLong': 25.615426,
#      'TimeStamp': 1648814384000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648814384000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'fIb_5H8Bl-P5I54hLB5k',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm10',
#      'Value': 29,
#      'LocationLat': 45.651464,
#      'LocationLong': 25.615426,
#      'TimeStamp': 1648814384000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648814384000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'fob_5H8Bl-P5I54hLB5o',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'cho2',
#      'Value': 7,
#      'LocationLat': 45.651464,
#      'LocationLong': 25.615426,
#      'TimeStamp': 1648814384000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648814384000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'f4b_5H8Bl-P5I54hLB5q',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm1',
#      'Value': 13,
#      'LocationLat': 45.651464,
#      'LocationLong': 25.615426,
#      'TimeStamp': 1648814384000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648814384000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'h4b_5H8Bl-P5I54hLB57',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'co2',
#      'Value': 478,
#      'LocationLat': 45.651464,
#      'LocationLong': 25.615426,
#      'TimeStamp': 1648814384000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648814384000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'iYb_5H8Bl-P5I54hLB59',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm25',
#      'Value': 17,
#      'LocationLat': 45.651464,
#      'LocationLong': 25.615426,
#      'TimeStamp': 1648814384000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648814384000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'VIb_5H8Bl-P5I54hKh7V',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm1',
#      'Value': 15,
#      'LocationLat': 45.55914,
#      'LocationLong': 25.324771,
#      'TimeStamp': 1648814383000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648814383000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'XIb_5H8Bl-P5I54hKh7v',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm10',
#      'Value': 24,
#      'LocationLat': 45.55914,
#      'LocationLong': 25.324771,
#      'TimeStamp': 1648814383000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648814383000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'zYb_5H8Bl-P5I54hMB6Q',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm25',
#      'Value': 19,
#      'LocationLat': 45.55914,
#      'LocationLong': 25.324771,
#      'TimeStamp': 1648814383000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648814383000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'eIb_5H8Bl-P5I54hLB4Y',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm1',
#      'Value': 5,
#      'LocationLat': 45.700748,
#      'LocationLong': 25.442761,
#      'TimeStamp': 1648814381000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648814381000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'QYb_5H8Bl-P5I54hJx7A',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm10',
#      'Value': 13,
#      'LocationLat': 45.700748,
#      'LocationLong': 25.442761,
#      'TimeStamp': 1648814381000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648814381000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'R4b_5H8Bl-P5I54hKB4d',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm25',
#      'Value': 9,
#      'LocationLat': 45.700748,
#      'LocationLong': 25.442761,
#      'TimeStamp': 1648814381000,
# ...
#     '_type': '_doc',
#     '_id': 'l0FH438Bwa_bL2zRt39o',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm25',
#      'Value': 6,
#      'LocationLat': 45.673977,
#      'LocationLong': 25.606484,
#      'TimeStamp': 1648785565000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648785565000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'p0FH438Bwa_bL2zRt3-e',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'cho2',
#      'Value': 0,
#      'LocationLat': 45.673977,
#      'LocationLong': 25.606484,
#      'TimeStamp': 1648785565000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648785565000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'ukFH438Bwa_bL2zRt3-r',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'o3',
#      'Value': 85,
#      'LocationLat': 45.673977,
#      'LocationLong': 25.606484,
#      'TimeStamp': 1648785565000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648785565000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': '0UFH438Bwa_bL2zRt3_L',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm1',
#      'Value': 4,
#      'LocationLat': 45.673977,
#      'LocationLong': 25.606484,
#      'TimeStamp': 1648785565000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648785565000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': '0kFH438Bwa_bL2zRt3_M',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm10',
#      'Value': 5,
#      'LocationLat': 45.673977,
#      'LocationLong': 25.606484,
#      'TimeStamp': 1648785565000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648785565000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': '1UFH438Bwa_bL2zRt3_S',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'co2',
#      'Value': 487,
#      'LocationLat': 45.673977,
#      'LocationLong': 25.606484,
#      'TimeStamp': 1648785565000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648785565000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'SEFH438Bwa_bL2zRtH_n',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm25',
#      'Value': 7,
#      'LocationLat': 45.39324,
#      'LocationLong': 25.442933,
#      'TimeStamp': 1648785564000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648785564000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'S0FH438Bwa_bL2zRtX_F',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm1',
#      'Value': 1,
#      'LocationLat': 45.39324,
#      'LocationLong': 25.442933,
#      'TimeStamp': 1648785564000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648785564000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'U0FH438Bwa_bL2zRtn8a',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm10',
#      'Value': 12,
#      'LocationLat': 45.39324,
#      'LocationLong': 25.442933,
#      'TimeStamp': 1648785564000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648785564000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'kUFH438Bwa_bL2zRt39d',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm10',
#      'Value': 4,
#      'LocationLat': 45.657148,
#      'LocationLong': 25.563752,
#      'TimeStamp': 1648785562000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648785562000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'kkFH438Bwa_bL2zRt39d',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm10',
#      'Value': 2,
#      'LocationLat': 45.703546,
#      'LocationLong': 25.679012,
#      'TimeStamp': 1648785562000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648785562000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'lkFH438Bwa_bL2zRt39n',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm25',
#      'Value': 1,
#      'LocationLat': 45.703546,
#      'LocationLong': 25.679012,
#      'TimeStamp': 1648785562000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648785562000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'okFH438Bwa_bL2zRt391',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm1',
#      'Value': 1,
#      'LocationLat': 45.703546,
#      'LocationLong': 25.679012,
#      'TimeStamp': 1648785562000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648785562000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'pEFH438Bwa_bL2zRt395',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'o3',
#      'Value': 20,
#      'LocationLat': 45.657148,
#      'LocationLong': 25.563752,
#      'TimeStamp': 1648785562000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648785562000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'pkFH438Bwa_bL2zRt3-d',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'cho2',
#      'Value': 7,
#      'LocationLat': 45.657148,
#      'LocationLong': 25.563752,
#      'TimeStamp': 1648785562000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648785562000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'r0FH438Bwa_bL2zRt3-i',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'co2',
#      'Value': 627,
#      'LocationLat': 45.657148,
#      'LocationLong': 25.563752,
#      'TimeStamp': 1648785562000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648785562000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'xkFH438Bwa_bL2zRt3--',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm25',
#      'Value': 4,
#      'LocationLat': 45.657148,
#      'LocationLong': 25.563752,
#      'TimeStamp': 1648785562000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648785562000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'ykFH438Bwa_bL2zRt3_C',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm1',
#      'Value': 3,
#      'LocationLat': 45.657148,
#      'LocationLong': 25.563752,
#      'TimeStamp': 1648785562000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648785562000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'fkFH438Bwa_bL2zRt38y',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm10',
#      'Value': 9,
#      'LocationLat': 45.7017883,
#      'LocationLong': 25.5482448,
#      'TimeStamp': 1648785554000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648785554000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'gEFH438Bwa_bL2zRt383',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm25',
#      'Value': 8,
#      'LocationLat': 45.7017883,
#      'LocationLong': 25.5482448,
#      'TimeStamp': 1648785554000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648785554000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'WUFH438Bwa_bL2zRtn84',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm1',
#      'Value': 3,
#      'LocationLat': 45.7017883,
#      'LocationLong': 25.5482448,
#      'TimeStamp': 1648785554000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648785554000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'nUFH438Bwa_bL2zRt39z',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'cho2',
#      'Value': 7,
#      'LocationLat': 45.676195,
#      'LocationLong': 25.645632,
#      'TimeStamp': 1648785551000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648785551000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'q0FH438Bwa_bL2zRt3-f',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm25',
#      'Value': 1,
#      'LocationLat': 45.638767,
#      'LocationLong': 25.586021,
#      'TimeStamp': 1648785551000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648785551000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'rkFH438Bwa_bL2zRt3-h',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'o3',
#      'Value': 20,
#      'LocationLat': 45.676195,
#      'LocationLong': 25.645632,
#      'TimeStamp': 1648785551000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648785551000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'wEFH438Bwa_bL2zRt3-3',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm10',
#      'Value': 2,
#      'LocationLat': 45.638767,
#      'LocationLong': 25.586021,
#      'TimeStamp': 1648785551000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648785551000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'wUFH438Bwa_bL2zRt3-5',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm1',
#      'Value': 2,
#      'LocationLat': 45.676195,
#      'LocationLong': 25.645632,
#      'TimeStamp': 1648785551000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648785551000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'w0FH438Bwa_bL2zRt3-5',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm1',
#      'Value': 1,
#      'LocationLat': 45.638767,
#      'LocationLong': 25.586021,
#      'TimeStamp': 1648785551000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648785551000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'xEFH438Bwa_bL2zRt3-6',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm10',
#      'Value': 3,
#      'LocationLat': 45.676195,
#      'LocationLong': 25.645632,
#      'TimeStamp': 1648785551000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648785551000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'xUFH438Bwa_bL2zRt3-9',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'co2',
#      'Value': 563,
#      'LocationLat': 45.676195,
#      'LocationLong': 25.645632,
#      'TimeStamp': 1648785551000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648785551000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': '1kFH438Bwa_bL2zRuH-6',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm25',
#      'Value': 3,
#      'LocationLat': 45.676195,
#      'LocationLong': 25.645632,
#      'TimeStamp': 1648785551000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648785551000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'akFH438Bwa_bL2zRtn-w',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm10',
#      'Value': 5,
#      'LocationLat': 45.698269,
#      'LocationLong': 25.558889,
#      'TimeStamp': 1648785549000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648785549000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'a0FH438Bwa_bL2zRtn-x',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm25',
#      'Value': 4,
#      'LocationLat': 45.698269,
#      'LocationLong': 25.558889,
#      'TimeStamp': 1648785549000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648785549000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'qEFH438Bwa_bL2zRt3-f',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm1',
#      'Value': 3,
#      'LocationLat': 45.698269,
#      'LocationLong': 25.558889,
#      'TimeStamp': 1648785549000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648785549000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'ZkFH438Bwa_bL2zRtn-N',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm1',
#      'Value': 3,
#      'LocationLat': 45.623958,
#      'LocationLong': 25.481535,
#      'TimeStamp': 1648785546000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648785546000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'YEFH438Bwa_bL2zRtn9y',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm25',
#      'Value': 4,
#      'LocationLat': 45.623958,
#      'LocationLong': 25.481535,
#      'TimeStamp': 1648785546000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648785546000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'Y0FH438Bwa_bL2zRtn9-',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm10',
#      'Value': 8,
#      'LocationLat': 45.623958,
#      'LocationLong': 25.481535,
#      'TimeStamp': 1648785546000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648785546000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'g0FH438Bwa_bL2zRt389',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm10',
#      'Value': 3,
#      'LocationLat': 45.665184,
#      'LocationLong': 25.558891,
#      'TimeStamp': 1648785515000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648785515000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'iUFH438Bwa_bL2zRt39E',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm1',
#      'Value': 0,
#      'LocationLat': 45.665184,
#      'LocationLong': 25.558891,
#      'TimeStamp': 1648785515000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648785515000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'YUFH438Bwa_bL2zRtn96',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm25',
#      'Value': 8,
#      'LocationLat': 45.665184,
#      'LocationLong': 25.558891,
#      'TimeStamp': 1648785515000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648785515000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'oUFH438Bwa_bL2zRt391',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm25',
#      'Value': 7,
#      'LocationLat': 45.657861,
#      'LocationLong': 25.621916,
#      'TimeStamp': 1648785510000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648785510000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'qkFH438Bwa_bL2zRt3-f',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm1',
#      'Value': 0,
#      'LocationLat': 45.657861,
#      'LocationLong': 25.621916,
#      'TimeStamp': 1648785510000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648785510000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'vkFH438Bwa_bL2zRt3-1',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm10',
#      'Value': 1,
#      'LocationLat': 45.657861,
#      'LocationLong': 25.621916,
#      'TimeStamp': 1648785510000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648785510000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'dkFH438Bwa_bL2zRt38S',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm25',
#      'Value': 0,
#      'LocationLat': 45.71737,
#      'LocationLong': 25.68571,
#      'TimeStamp': 1648785325000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648785325000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'hkFH438Bwa_bL2zRt38_',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm1',
#      'Value': 0,
#      'LocationLat': 45.71737,
#      'LocationLong': 25.68571,
#      'TimeStamp': 1648785325000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648785325000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'kEFH438Bwa_bL2zRt39b',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm10',
#      'Value': 1,
#      'LocationLat': 45.71737,
#      'LocationLong': 25.68571,
#      'TimeStamp': 1648785325000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648785325000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': '5EEQ438Bwa_bL2zRyX5s',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm1',
#      'Value': 5,
#      'LocationLat': 45.589267,
#      'LocationLong': 25.46445,
#      'TimeStamp': 1648782000000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648782000000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'AkEQ438Bwa_bL2zRy3-b',
#     '_score': None,
#     '_source': {'Source': 'Waqi',
#      'Sensor': 'pm10',
#      'Value': 11,
#      'LocationLat': 45.6343302,
#      'LocationLong': 25.6338716,
#      'TimeStamp': 1648782000000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648782000000]},
#    ...]}}

# %%
from pandas import json_normalize
dataframe = json_normalize(data['hits']['hits'])

# %%
dataframe
# Out:
#             _index _type                   _id _score             sort  \
# 0       brasov-dev  _doc  EzI25X8B3mQrnl8XHqm6   None  [1648818000000]
# 1       brasov-dev  _doc  FDI25X8B3mQrnl8XHqm9   None  [1648818000000]
# 2       brasov-dev  _doc  FTI25X8B3mQrnl8XHqm9   None  [1648818000000]
# 3       brasov-dev  _doc  FjI25X8B3mQrnl8XH6ke   None  [1648818000000]
# 4       brasov-dev  _doc  hjI25X8B3mQrnl8XGKjw   None  [1648818000000]
# ...            ...   ...                   ...    ...              ...
# 199995  brasov-dev  _doc  pTxpaX4Bwa_bL2zRINoG   None  [1642442400000]
# 199996  brasov-dev  _doc  tzxpaX4Bwa_bL2zRJdr9   None  [1642442400000]
# 199997  brasov-dev  _doc  uDxpaX4Bwa_bL2zRJdr9   None  [1642442400000]
# 199998  brasov-dev  _doc  uTxpaX4Bwa_bL2zRJdr-   None  [1642442400000]
# 199999  brasov-dev  _doc  pDxpaX4Bwa_bL2zRINoG   None  [1642442400000]
#
#        _source.Source _source.Sensor  _source.Value  _source.LocationLat  \
# 0                Waqi            no2            1.2            45.716700
# 1                Waqi            so2            1.4            45.716700
# 2                Waqi           pm10           11.0            45.716700
# 3                Waqi            no2            6.7            45.654271
# 4         UradMonitor           pm25           10.0            45.653600
# ...               ...            ...            ...                  ...
# 199995           Waqi           pm10           11.0            45.634330
# 199996           Waqi            no2            2.8            45.716700
# 199997           Waqi           pm10           36.0            45.716700
# 199998           Waqi            so2            1.1            45.716700
# 199999           Waqi            no2            5.5            45.634330
#
#         _source.LocationLong  _source.TimeStamp _source.Measurement
# 0                  25.633300      1648818000000               µg/m3
# 1                  25.633300      1648818000000               µg/m3
# 2                  25.633300      1648818000000               µg/m3
# 3                  25.624061      1648818000000               µg/m3
# 4                  25.599000      1648818000000               µg/m3
# ...                      ...                ...                 ...
# 199995             25.633872      1642442400000               µg/m3
# 199996             25.633300      1642442400000               µg/m3
# 199997             25.633300      1642442400000               µg/m3
# 199998             25.633300      1642442400000               µg/m3
# 199999             25.633872      1642442400000               µg/m3
#
# [200000 rows x 12 columns]

# %%
dataframe_size = len(dataframe.index)
dataframe_size
# Out:
# 200000

# %%
import matplotlib.pyplot as plt
hist_sensor = plt.figure(figsize = (25,10))
ax = hist_sensor.gca()

dataframe.get('_source.Sensor').value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
dataframe['LocationId'] = dataframe['_source.LocationLat']*10000000 + dataframe['_source.LocationLong']*10000000
dataframe['LocationName'] = ""
dataframe.loc[dataframe['LocationId'] == 712668900.0, 'LocationName'] = 'Toamnei' 
dataframe.loc[dataframe['LocationId'] == 712196290.0, 'LocationName'] = 'Carierei'
dataframe.loc[dataframe['LocationId'] == 712209000.0, 'LocationName'] = 'Brintex'
dataframe.loc[dataframe['LocationId'] == 712240750.0, 'LocationName'] = 'Avantgarden'
dataframe.loc[dataframe['LocationId'] == 708361730.0, 'LocationName'] = 'Bucegi'
dataframe.loc[dataframe['LocationId'] == 712682018.0, 'LocationName'] = 'Carrefour'
dataframe.loc[dataframe['LocationId'] == 712307300.0, 'LocationName'] = 'Centru'
dataframe.loc[dataframe['LocationId'] == 712422000.0, 'LocationName'] = 'Cetatuie'
dataframe.loc[dataframe['LocationId'] == 712485560.0, 'LocationName'] = 'Basarab'
dataframe.loc[dataframe['LocationId'] == 712532529.0, 'LocationName'] = 'Patria'
dataframe.loc[dataframe['LocationId'] == 711435090.0, 'LocationName'] = 'Codlea1'
dataframe.loc[dataframe['LocationId'] == 711587690.0, 'LocationName'] = 'Codlea2'
dataframe.loc[dataframe['LocationId'] == 712526000.0, 'LocationName'] = 'Colina1'
dataframe.loc[dataframe['LocationId'] == 712485000.0, 'LocationName'] = 'Colina2'
dataframe.loc[dataframe['LocationId'] == 711054930.0, 'LocationName'] = 'Cristian'
dataframe.loc[dataframe['LocationId'] == 712743216.0, 'LocationName'] = 'Gara'
dataframe.loc[dataframe['LocationId'] == 713825580.0, 'LocationName'] = 'Harman1'
dataframe.loc[dataframe['LocationId'] == 714030800.0, 'LocationName'] = 'Harman2'
dataframe.loc[dataframe['LocationId'] == 712560910.0, 'LocationName'] = 'Racadau'
dataframe.loc[dataframe['LocationId'] == 710537170.0, 'LocationName'] = 'Rasnov'
dataframe.loc[dataframe['LocationId'] == 713449870.0, 'LocationName'] = 'Sanpetru1'
dataframe.loc[dataframe['LocationId'] == 713500000.0, 'LocationName'] = 'Sanpetru2'
dataframe.loc[dataframe['LocationId'] == 712475170.0, 'LocationName'] = 'Saturn'
dataframe.loc[dataframe['LocationId'] == 712500331.0, 'LocationName'] = 'Stupini1'
dataframe.loc[dataframe['LocationId'] == 712571580.0, 'LocationName'] = 'Stupini2'
dataframe.loc[dataframe['LocationId'] == 712804610.0, 'LocationName'] = 'Tractorul'
dataframe.loc[dataframe['LocationId'] == 713218270.0, 'LocationName'] = 'TriajH'
dataframe.loc[dataframe['LocationId'] == 712783320.0, 'LocationName'] = 'Vlahuta1'
dataframe.loc[dataframe['LocationId'] == 712797770.0, 'LocationName'] = 'Vlahuta2'
dataframe.loc[dataframe['LocationId'] == 708839110.0, 'LocationName'] = 'Zarnesti'
dataframe.loc[dataframe['LocationId'] == 712247880.0, 'LocationName'] = 'Saguna'
dataframe.loc[dataframe['LocationId'] == 712352710.0, 'LocationName'] = 'Livada'
dataframe.head(10)
# Out:
#        _index _type                   _id _score             sort  \
# 0  brasov-dev  _doc  EzI25X8B3mQrnl8XHqm6   None  [1648818000000]
# 1  brasov-dev  _doc  FDI25X8B3mQrnl8XHqm9   None  [1648818000000]
# 2  brasov-dev  _doc  FTI25X8B3mQrnl8XHqm9   None  [1648818000000]
# 3  brasov-dev  _doc  FjI25X8B3mQrnl8XH6ke   None  [1648818000000]
# 4  brasov-dev  _doc  hjI25X8B3mQrnl8XGKjw   None  [1648818000000]
# 5  brasov-dev  _doc  hzI25X8B3mQrnl8XGKjy   None  [1648818000000]
# 6  brasov-dev  _doc  izI25X8B3mQrnl8XGagE   None  [1648818000000]
# 7  brasov-dev  _doc  EjI25X8B3mQrnl8XHqm6   None  [1648818000000]
# 8  brasov-dev  _doc  FzI25X8B3mQrnl8XH6ke   None  [1648818000000]
# 9  brasov-dev  _doc  GDI25X8B3mQrnl8XH6kh   None  [1648818000000]
#
#   _source.Source _source.Sensor  _source.Value  _source.LocationLat  \
# 0           Waqi            no2            1.2            45.716700
# 1           Waqi            so2            1.4            45.716700
# 2           Waqi           pm10           11.0            45.716700
# 3           Waqi            no2            6.7            45.654271
# 4    UradMonitor           pm25           10.0            45.653600
# 5    UradMonitor            pm1            2.0            45.653600
# 6    UradMonitor           pm10           12.0            45.653600
# 7           Waqi             o3           41.5            45.716700
# 8           Waqi            so2            1.8            45.654271
# 9           Waqi           pm10           13.0            45.654271
#
#    _source.LocationLong  _source.TimeStamp _source.Measurement   LocationId  \
# 0             25.633300      1648818000000               µg/m3  713500000.0
# 1             25.633300      1648818000000               µg/m3  713500000.0
# 2             25.633300      1648818000000               µg/m3  713500000.0
# 3             25.624061      1648818000000               µg/m3  712783320.0
# 4             25.599000      1648818000000               µg/m3  712526000.0
# 5             25.599000      1648818000000               µg/m3  712526000.0
# 6             25.599000      1648818000000               µg/m3  712526000.0
# 7             25.633300      1648818000000               µg/m3  713500000.0
# 8             25.624061      1648818000000               µg/m3  712783320.0
# 9             25.624061      1648818000000               µg/m3  712783320.0
#
#   LocationName
# 0    Sanpetru2
# 1    Sanpetru2
# 2    Sanpetru2
# 3     Vlahuta1
# 4      Colina1
# 5      Colina1
# 6      Colina1
# 7    Sanpetru2
# 8     Vlahuta1
# 9     Vlahuta1

# %%
# dataframe.groupby(['LocationName']).size().reset_index().rename(columns={0:'count'})

# %%
# hist_location = dataframe.get('LocationName').hist()
import matplotlib.pyplot as plt
hist_location = plt.figure(figsize = (25,10))
ax = hist_location.gca()
# dataframe.get('LocationName').hist(ax = ax)

dataframe.get('LocationName').value_counts().plot(kind='bar')
# dataframe.get('LocationName').value_counts(sort=False).plot.bar(rot=0)
# Out:
# <AxesSubplot:>

# %%
dataframe_v2 = dataframe[[i for i in list(dataframe.columns) if i != '_index']]
dataframe_v2 = dataframe_v2[[i for i in list(dataframe_v2.columns) if i != '_type']]
dataframe_v2 = dataframe_v2[[i for i in list(dataframe_v2.columns) if i != '_id']]
dataframe_v2 = dataframe_v2[[i for i in list(dataframe_v2.columns) if i != '_score']]
dataframe_v2 = dataframe_v2[[i for i in list(dataframe_v2.columns) if i != 'sort']]
dataframe_v2.head(7)
# dataframe_v2
# Out:
#   _source.Source _source.Sensor  _source.Value  _source.LocationLat  \
# 0           Waqi            no2            1.2            45.716700
# 1           Waqi            so2            1.4            45.716700
# 2           Waqi           pm10           11.0            45.716700
# 3           Waqi            no2            6.7            45.654271
# 4    UradMonitor           pm25           10.0            45.653600
# 5    UradMonitor            pm1            2.0            45.653600
# 6    UradMonitor           pm10           12.0            45.653600
#
#    _source.LocationLong  _source.TimeStamp _source.Measurement   LocationId  \
# 0             25.633300      1648818000000               µg/m3  713500000.0
# 1             25.633300      1648818000000               µg/m3  713500000.0
# 2             25.633300      1648818000000               µg/m3  713500000.0
# 3             25.624061      1648818000000               µg/m3  712783320.0
# 4             25.599000      1648818000000               µg/m3  712526000.0
# 5             25.599000      1648818000000               µg/m3  712526000.0
# 6             25.599000      1648818000000               µg/m3  712526000.0
#
#   LocationName
# 0    Sanpetru2
# 1    Sanpetru2
# 2    Sanpetru2
# 3     Vlahuta1
# 4      Colina1
# 5      Colina1
# 6      Colina1

# %%
cho2 = dataframe_v2[dataframe_v2.get('_source.Sensor') == 'cho2']
co2 = dataframe_v2[dataframe_v2.get('_source.Sensor') == 'co2']
no2 = dataframe_v2[dataframe_v2.get('_source.Sensor') == 'no2']
o3 = dataframe_v2[dataframe_v2.get('_source.Sensor') == 'o3']
pm1 = dataframe_v2[dataframe_v2.get('_source.Sensor') == 'pm1']
pm10 = dataframe_v2[dataframe_v2.get('_source.Sensor') == 'pm10']
pm25 = dataframe_v2[dataframe_v2.get('_source.Sensor') == 'pm25']
so2 = dataframe_v2[dataframe_v2.get('_source.Sensor') == 'so2']

# %%
print('Lungime dataframe: ',len(dataframe_v2))
print('Lungime dataframe cho2: ',len(cho2))
print('Lungime dataframe co2: ',len(co2))
print('Lungime dataframe no2: ',len(no2))
print('Lungime dataframe o3: ',len(o3))
print('Lungime dataframe pm1: ',len(pm1))
print('Lungime dataframe pm10: ',len(pm10))
print('Lungime dataframe pm25: ',len(pm25))
print('Lungime dataframe so2: ',len(so2))
# Out:
# Lungime dataframe:  200000
# Lungime dataframe cho2:  8837
# Lungime dataframe co2:  8840
# Lungime dataframe no2:  8812
# Lungime dataframe o3:  12361
# Lungime dataframe pm1:  49015
# Lungime dataframe pm10:  57832
# Lungime dataframe pm25:  49017
# Lungime dataframe so2:  5286

# %%
import matplotlib.pyplot as plt
plt.close("all")
# fig = plt.figure(figsize=(20,10), frameon=True)
plt.figure(figsize=(20,10))
plt.plot(so2.get('_source.TimeStamp'), so2.get('_source.Value'), label="All SO2 sensors")
plt.scatter(so2.get('_source.TimeStamp'), so2.get('_source.Value'), color = "red")
plt.xlabel("TimeStamp")
plt.ylabel("Value")
plt.title("Last 100k values for all SO2 sensors")
plt.legend()
plt.savefig('plots_updated/SO2.jpg', bbox_inches = 'tight')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.linear_model import LinearRegression

# %%
X = so2[["_source.TimeStamp"]].values
y = so2[["_source.Value"]].values

# %%
regressor = LinearRegression()
regressor.fit(X, y)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(X)

# %%
print("Slope: ", float(regressor.coef_))
print("Intercept: ", float(regressor.intercept_))
# float("{:.8f}".format(float(regressor.intercept_)))
# Out:
# Slope:  4.8035345759474966e-11
# Intercept:  -77.13854005485213

# %%
plt.figure(figsize=(20,10))
# plt.scatter(X, y, color = 'blue')
plt.plot(X,y, color = 'blue', label="All SO2 values")
plt.plot(X, regressor.predict(X), color = 'red', label="SO2 linear regression")
plt.title('Linear regression on last 100k SO2 values')
plt.xlabel('TimeStamp')
plt.ylabel('Value')
plt.legend()
plt.savefig('plots_updated/SO2_regression.jpg', bbox_inches = 'tight')
plt.show()

# %%
so2.head(6) #Vlahuta1, Centru4, Sanpetru2
# Out:
#     _source.Source _source.Sensor  _source.Value  _source.LocationLat  \
# 1             Waqi            so2            1.4            45.716700
# 8             Waqi            so2            1.8            45.654271
# 11            Waqi            so2            1.8            45.649117
# 101           Waqi            so2            1.7            45.649117
# 105           Waqi            so2            1.4            45.716700
# 116           Waqi            so2            1.9            45.654271
#
#      _source.LocationLong  _source.TimeStamp _source.Measurement   LocationId  \
# 1               25.633300      1648818000000               µg/m3  713500000.0
# 8               25.624061      1648818000000               µg/m3  712783320.0
# 11              25.604136      1648818000000               µg/m3  712532529.0
# 101             25.604136      1648814400000               µg/m3  712532529.0
# 105             25.633300      1648814400000               µg/m3  713500000.0
# 116             25.624061      1648814400000               µg/m3  712783320.0
#
#     LocationName
# 1      Sanpetru2
# 8       Vlahuta1
# 11        Patria
# 101       Patria
# 105    Sanpetru2
# 116     Vlahuta1

# %%
so2_vlahuta1 = so2[so2.get('LocationName') == 'Vlahuta1']
so2_patria = so2[so2.get('LocationName') == 'Patria']
so2_sanpetru2 = so2[so2.get('LocationName') == 'Sanpetru2']

# %%
import matplotlib.pyplot as plt
plt.close("all")
plt.figure(figsize=(20,10))
plt.plot(so2_vlahuta1.get('_source.TimeStamp'), so2_vlahuta1.get('_source.Value'), color = "red", label="Vlahuta1 SO2 sensor")
plt.plot(so2_patria.get('_source.TimeStamp'), so2_patria.get('_source.Value'), color = "blue", label="Centru4 SO2 sensor")
plt.plot(so2_sanpetru2.get('_source.TimeStamp'), so2_sanpetru2.get('_source.Value'), color = "purple", label="Sanpetru2 SO2 sensor")
plt.xlabel("TimeStamp")
plt.ylabel("Value")
plt.title("Last 100k values for SO2")
plt.legend()
plt.savefig('plots_updated/SO2_all.jpg', bbox_inches = 'tight')
plt.show()

# %%
pm10_carierei = pm10[pm10.get('LocationName') == 'Carierei']
pm10_brintex = pm10[pm10.get('LocationName') == 'Brintex']
pm10_avantgarden = pm10[pm10.get('LocationName') == 'Avantgarden']

# %%
import matplotlib.pyplot as plt
plt.close("all")
plt.figure(figsize=(20,10))
plt.plot(pm10_carierei.get('_source.TimeStamp'), pm10_carierei.get('_source.Value'), color = "red", label="Carierei PM10 sensor")
plt.plot(pm10_brintex.get('_source.TimeStamp'), pm10_brintex.get('_source.Value'), color = "blue", label="Brintex PM10 sensor")
plt.plot(pm10_avantgarden.get('_source.TimeStamp'), pm10_avantgarden.get('_source.Value'), color = "purple", label="Avantgarden PM10 sensor")
plt.xlabel("TimeStamp")
plt.ylabel("Value")
plt.title("Last 100k values for PM10 in Bartolomeu")
plt.legend()
plt.savefig('plots_updated/PM10_Bartolomeu.jpg', bbox_inches = 'tight')
plt.show()

# %%
pm10_centru = pm10[pm10.get('LocationName') == 'Centru']
pm10_cetatuie = pm10[pm10.get('LocationName') == 'Cetatuie']
pm10_basarab = pm10[pm10.get('LocationName') == 'Basarab']
pm10_patria = pm10[pm10.get('LocationName') == 'Patria']

# %%
import matplotlib.pyplot as plt
plt.close("all")
plt.figure(figsize=(20,10))
plt.plot(pm10_centru.get('_source.TimeStamp'), pm10_centru.get('_source.Value'), color = "green", label="Centru PM10 sensor")
plt.plot(pm10_cetatuie.get('_source.TimeStamp'), pm10_cetatuie.get('_source.Value'), color = "blue", label="Cetatuie PM10 sensor")
plt.plot(pm10_basarab.get('_source.TimeStamp'), pm10_basarab.get('_source.Value'), color = "purple", label="Basarab PM10 sensor")
plt.plot(pm10_patria.get('_source.TimeStamp'), pm10_patria.get('_source.Value'), color = "red", label="Patria PM10 sensor")
plt.xlabel("TimeStamp")
plt.ylabel("Value")
plt.title("Last 100k values for PM10 in City Center")
plt.legend()
plt.savefig('plots_updated/PM10_Centru.jpg', bbox_inches = 'tight')
plt.show()

# %%
pm10_carrefour = pm10[pm10.get('LocationName') == 'Carrefour']
pm10_toamnei = pm10[pm10.get('LocationName') == 'Toamnei']
pm10_gara = pm10[pm10.get('LocationName') == 'Gara']

# %%
import matplotlib.pyplot as plt
plt.close("all")
plt.figure(figsize=(20,10))
plt.plot(pm10_carrefour.get('_source.TimeStamp'), pm10_carrefour.get('_source.Value'), color = "red", label="Carrefour PM10 sensor")
plt.plot(pm10_toamnei.get('_source.TimeStamp'), pm10_toamnei.get('_source.Value'), color = "blue", label="Toamnei PM10 sensor")
plt.plot(pm10_gara.get('_source.TimeStamp'), pm10_gara.get('_source.Value'), color = "purple", label="Gara PM10 sensor")
plt.plot(pm10_patria.get('_source.TimeStamp'), pm10_patria.get('_source.Value'), color = "black", label="Patria PM10 sensor")
plt.xlabel("TimeStamp")
plt.ylabel("Value")
plt.title("Last 100k values for various PM10 sensors")
plt.legend()
plt.savefig('plots_updated/PM10_strange.jpg', bbox_inches = 'tight')
plt.show()

# %%
# pm10_afi.head(30)
pm10_gara.tail(10)
# Out:
#        _source.Source _source.Sensor  _source.Value  _source.LocationLat  \
# 198963           Waqi           pm10           20.0            45.659833
# 199086           Waqi           pm10           24.0            45.659833
# 199191           Waqi           pm10           28.0            45.659833
# 199300           Waqi           pm10           32.0            45.659833
# 199402           Waqi           pm10           37.0            45.659833
# 199530           Waqi           pm10           39.0            45.659833
# 199658           Waqi           pm10           42.0            45.659833
# 199771           Waqi           pm10           45.0            45.659833
# 199882           Waqi           pm10           47.0            45.659833
# 199993           Waqi           pm10           48.0            45.659833
#
#         _source.LocationLong  _source.TimeStamp _source.Measurement  \
# 198963             25.614488      1642474800000               µg/m3
# 199086             25.614488      1642471200000               µg/m3
# 199191             25.614488      1642467600000               µg/m3
# 199300             25.614488      1642464000000               µg/m3
# 199402             25.614488      1642460400000               µg/m3
# 199530             25.614488      1642456800000               µg/m3
# 199658             25.614488      1642453200000               µg/m3
# 199771             25.614488      1642449600000               µg/m3
# 199882             25.614488      1642446000000               µg/m3
# 199993             25.614488      1642442400000               µg/m3
#
#          LocationId LocationName
# 198963  712743216.0         Gara
# 199086  712743216.0         Gara
# 199191  712743216.0         Gara
# 199300  712743216.0         Gara
# 199402  712743216.0         Gara
# 199530  712743216.0         Gara
# 199658  712743216.0         Gara
# 199771  712743216.0         Gara
# 199882  712743216.0         Gara
# 199993  712743216.0         Gara

# %%
train = pm10_toamnei[pm10_toamnei.get('_source.TimeStamp') < 1648123156000]
test = pm10_toamnei[pm10_toamnei.get('_source.TimeStamp') >= 1648123156000]

import matplotlib.pyplot as plt
plt.close("all")
plt.figure(figsize=(20,10))
plt.plot(train.get('_source.TimeStamp'), train.get('_source.Value'), color = "black", label = "Training")
plt.plot(test.get('_source.TimeStamp'), test.get('_source.Value'), color = "red", label = "Testing")
plt.xlabel("TimeStamp")
plt.ylabel("Value")
plt.title("Train/Test split for PM10 in Toamnei")
plt.legend()
plt.savefig('plots_updated/PM10_Toamnei_Split.jpg', bbox_inches = 'tight')
plt.show()

# %%
pm10_toamnei = pm10[pm10.get('LocationName') == 'Toamnei']
train = pm10_toamnei[pm10_toamnei.index < dataframe_size*(3/4)]
test = pm10_toamnei[pm10_toamnei.index >= dataframe_size*(3/4)]

from statsmodels.tsa.statespace.sarimax import SARIMAX
y = train['_source.Value']

ARMAmodel = SARIMAX(y, order=(1,0,1))
ARMAmodel = ARMAmodel.fit()
y_pred = ARMAmodel.get_forecast(len(test.index))
y_pred_df = y_pred.conf_int(alpha=0.05)
y_pred_df['Predictions'] = ARMAmodel.predict(start = y_pred_df.index[0], end = y_pred_df.index[-1])
y_pred_df.index = test.index
y_pred_out = y_pred_df["Predictions"]


import matplotlib.pyplot as plt
plt.close("all")
plt.figure(figsize=(20,10))
plt.plot(train.index, train.get('_source.Value'), color = "black", label = "Training")
plt.plot(test.index, test.get('_source.Value'), color = "red", label = "Testing")
plt.xlabel("Index")
plt.ylabel("Value")
plt.title("Train/Test/Predictions for PM10 in Toamnei")
plt.plot(y_pred_out, color='green', label = 'ARMA Predictions')
plt.legend()
plt.savefig('plots_updated/PM10_Toamnei_ARMA_Prediction.jpg', bbox_inches = 'tight')
plt.show()


import numpy as np
from sklearn.metrics import mean_squared_error

arma_rmse = np.sqrt(mean_squared_error(test["_source.Value"].values, y_pred_df["Predictions"]))
print("RMSE: ", arma_rmse)
# Out:
# C:\VALI\Programs\Miniconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\VALI\Programs\Miniconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\VALI\Programs\Miniconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# C:\VALI\Programs\Miniconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# RMSE:  36.83149305847819

# %%
pm10_toamnei = pm10[pm10.get('LocationName') == 'Toamnei']
train = pm10_toamnei[pm10_toamnei.index < dataframe_size*(3/4)]
test = pm10_toamnei[pm10_toamnei.index >= dataframe_size*(3/4)]

from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.arima.model import ARIMA
y = train['_source.Value']

ARMAmodel = ARIMA(y, order=(2,2,2))
ARMAmodel = ARMAmodel.fit()
y_pred = ARMAmodel.get_forecast(len(test.index))
y_pred_df = y_pred.conf_int(alpha=0.05)
y_pred_df['Predictions'] = ARMAmodel.predict(start = y_pred_df.index[0], end = y_pred_df.index[-1])
y_pred_df.index = test.index
y_pred_out = y_pred_df["Predictions"]


import matplotlib.pyplot as plt
plt.close("all")
plt.figure(figsize=(20,10))
plt.plot(train.index, train.get('_source.Value'), color = "black", label = "Training")
plt.plot(test.index, test.get('_source.Value'), color = "red", label = "Testing")
plt.xlabel("Index")
plt.ylabel("Value")
plt.title("Train/Test/Predictions for PM10 in Toamnei")
plt.plot(y_pred_out, color='purple', label = 'ARIMA Predictions')
plt.legend()
plt.savefig('plots_updated/PM10_Toamnei_ARIMA_Prediction1.jpg', bbox_inches = 'tight')
plt.show()


import numpy as np
from sklearn.metrics import mean_squared_error

arima_rmse1 = np.sqrt(mean_squared_error(test["_source.Value"].values, y_pred_df["Predictions"]))
print("RMSE: ", arima_rmse1)
# Out:
# C:\VALI\Programs\Miniconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\VALI\Programs\Miniconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\VALI\Programs\Miniconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\VALI\Programs\Miniconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# C:\VALI\Programs\Miniconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# C:\VALI\Programs\Miniconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# C:\VALI\Programs\Miniconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# RMSE:  30.18033286685102

# %%
pm10_toamnei = pm10[pm10.get('LocationName') == 'Toamnei']
train = pm10_toamnei[pm10_toamnei.index < dataframe_size*(3/4)]
test = pm10_toamnei[pm10_toamnei.index >= dataframe_size*(3/4)]

from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.arima.model import ARIMA
y = train['_source.Value']

ARMAmodel = ARIMA(y, order=(2,3,2))
ARMAmodel = ARMAmodel.fit()
y_pred = ARMAmodel.get_forecast(len(test.index))
y_pred_df = y_pred.conf_int(alpha=0.05)
y_pred_df['Predictions'] = ARMAmodel.predict(start = y_pred_df.index[0], end = y_pred_df.index[-1])
y_pred_df.index = test.index
y_pred_out = y_pred_df["Predictions"]


import matplotlib.pyplot as plt
plt.close("all")
plt.figure(figsize=(20,10))
plt.plot(train.index, train.get('_source.Value'), color = "black", label = "Training")
plt.plot(test.index, test.get('_source.Value'), color = "red", label = "Testing")
plt.xlabel("Index")
plt.ylabel("Value")
plt.title("Train/Test/Predictions for PM10 in Toamnei")
plt.plot(y_pred_out, color='purple', label = 'ARIMA Predictions2')
plt.legend()
plt.savefig('plots_updated/PM10_Toamnei_ARIMA_Prediction2.jpg', bbox_inches = 'tight')
plt.show()


import numpy as np
from sklearn.metrics import mean_squared_error

arima_rmse2 = np.sqrt(mean_squared_error(test["_source.Value"].values, y_pred_df["Predictions"]))
print("RMSE: ", arima_rmse2)
# Out:
# C:\VALI\Programs\Miniconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\VALI\Programs\Miniconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\VALI\Programs\Miniconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\VALI\Programs\Miniconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# C:\VALI\Programs\Miniconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# C:\VALI\Programs\Miniconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# RMSE:  93.33652024915797

# %%
pm10_toamnei = pm10[pm10.get('LocationName') == 'Toamnei']
train = pm10_toamnei[pm10_toamnei.index < dataframe_size*(3/4)]
test = pm10_toamnei[pm10_toamnei.index >= dataframe_size*(3/4)]

from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.arima.model import ARIMA
y = train['_source.Value']

ARMAmodel = ARIMA(y, order=(9,3,6))
ARMAmodel = ARMAmodel.fit()
y_pred = ARMAmodel.get_forecast(len(test.index))
y_pred_df = y_pred.conf_int(alpha=0.05)
y_pred_df['Predictions'] = ARMAmodel.predict(start = y_pred_df.index[0], end = y_pred_df.index[-1])
y_pred_df.index = test.index
y_pred_out = y_pred_df["Predictions"]


import matplotlib.pyplot as plt
plt.close("all")
plt.figure(figsize=(20,10))
plt.plot(train.index, train.get('_source.Value'), color = "black", label = "Training")
plt.plot(test.index, test.get('_source.Value'), color = "red", label = "Testing")
plt.xlabel("Index")
plt.ylabel("Value")
plt.title("Train/Test/Predictions for PM10 in Toamnei")
plt.plot(y_pred_out, color='purple', label = 'ARIMA Predictions3')
plt.legend()
plt.savefig('plots_updated/PM10_Toamnei_ARIMA_Prediction3.jpg', bbox_inches = 'tight')
plt.show()


import numpy as np
from sklearn.metrics import mean_squared_error

arima_rmse3 = np.sqrt(mean_squared_error(test["_source.Value"].values, y_pred_df["Predictions"]))
print("RMSE: ", arima_rmse3)
# Out:
# C:\VALI\Programs\Miniconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\VALI\Programs\Miniconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\VALI\Programs\Miniconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\VALI\Programs\Miniconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# C:\VALI\Programs\Miniconda3\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\VALI\Programs\Miniconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# C:\VALI\Programs\Miniconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# RMSE:  234.56309449158468

# %%
pm10_livada = pm10[pm10.get('LocationName') == 'Livada']
pm10_zarnesti = pm10[pm10.get('LocationName') == 'Zarnesti']
pm10_saguna = pm10[pm10.get('LocationName') == 'Saguna']

# %%
import matplotlib.pyplot as plt
plt.close("all")
plt.figure(figsize=(20,10))
plt.plot(pm10_livada.get('_source.TimeStamp'), pm10_livada.get('_source.Value'), color = "blue", label="Livada PM10 sensor")
plt.plot(pm10_zarnesti.get('_source.TimeStamp'), pm10_zarnesti.get('_source.Value'), color = "purple", label="Zarnesti PM10 sensor")
plt.plot(pm10_saguna.get('_source.TimeStamp'), pm10_saguna.get('_source.Value'), color = "red", label="Saguna PM10 sensor")
plt.xlabel("TimeStamp")
plt.ylabel("Value")
plt.title("Last 100k values for PM10")
plt.legend()
plt.savefig('plots_updated/PM10_Surprise.jpg', bbox_inches = 'tight')
plt.show()

# %%
dataframe_v2.tail(10)
# Out:
#        _source.Source _source.Sensor  _source.Value  _source.LocationLat  \
# 199990           Waqi            so2            2.1            45.649117
# 199991           Waqi            no2            6.9            45.649117
# 199992           Waqi           pm10           15.0            45.649117
# 199993           Waqi           pm10           48.0            45.659833
# 199994           Waqi            no2            8.4            45.659833
# 199995           Waqi           pm10           11.0            45.634330
# 199996           Waqi            no2            2.8            45.716700
# 199997           Waqi           pm10           36.0            45.716700
# 199998           Waqi            so2            1.1            45.716700
# 199999           Waqi            no2            5.5            45.634330
#
#         _source.LocationLong  _source.TimeStamp _source.Measurement  \
# 199990             25.604136      1642442400000               µg/m3
# 199991             25.604136      1642442400000               µg/m3
# 199992             25.604136      1642442400000               µg/m3
# 199993             25.614488      1642442400000               µg/m3
# 199994             25.614488      1642442400000               µg/m3
# 199995             25.633872      1642442400000               µg/m3
# 199996             25.633300      1642442400000               µg/m3
# 199997             25.633300      1642442400000               µg/m3
# 199998             25.633300      1642442400000               µg/m3
# 199999             25.633872      1642442400000               µg/m3
#
#          LocationId LocationName
# 199990  712532529.0       Patria
# 199991  712532529.0       Patria
# 199992  712532529.0       Patria
# 199993  712743216.0         Gara
# 199994  712743216.0         Gara
# 199995  712682018.0    Carrefour
# 199996  713500000.0    Sanpetru2
# 199997  713500000.0    Sanpetru2
# 199998  713500000.0    Sanpetru2
# 199999  712682018.0    Carrefour

# %%
dataframe_v2.to_csv('dataframe_200k_utf.csv', encoding='utf-8')
dataframe_v2.to_csv('dataframe_200k.csv')
