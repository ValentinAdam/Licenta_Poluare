# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
import pandas as pd
from sklearn import linear_model
from sklearn.linear_model import ARDRegression, LinearRegression
from sklearn.linear_model import Perceptron
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import Pipeline
import numpy as np

# %%
dataframe = pd.read_csv("csv/82000278_Toamnei_PM10_2021_12.csv")

# %%
dataframe.head()
# Out:
#          time   latitude  longitude  altitude  pm10
# 0  1638309618  45.651464  25.615426       538     9
# 1  1638309678  45.651464  25.615426       538     9
# 2  1638309738  45.651464  25.615426       538    10
# 3  1638309798  45.651464  25.615426       538     9
# 4  1638309858  45.651464  25.615426       538     9

# %%
dataframe_size = len(dataframe.index)
dataframe_size
# Out:
# 44638

# %%
import matplotlib.pyplot as plt
plt.close("all")
plt.figure(figsize=(30,15))
plt.plot(dataframe.get('time'), dataframe.get('pm10'), label="PM10 values for Toamnei in December 2021", color = "blue")
plt.xlabel("TimeStamp", fontsize=16)
plt.ylabel("Value", fontsize=16)
plt.title("PM10 values for Toamnei in December 2021", fontsize=18)
plt.legend(fontsize=16)
plt.savefig('plots_from_csv/PM10_Toamnei_2021-12.jpg', bbox_inches = 'tight')
plt.show()

# %%
X = dataframe[["time"]].values
Y = dataframe[["pm10"]].values

# %%
i=0
x=[]
y=[]
for el in X:
    x.append(i)
    y.append(Y[i][0])
    i=i+1

# %%
clf = ARDRegression(compute_score=True)#, n_iter=500, alpha_1=10, alpha_2=10, lambda_1=10, lambda_2=10)
clf.fit(X, y)
y_pred = clf.predict(X)
y_pred
# Out:
# array([26.19328823, 26.19328823, 26.19328823, ..., 26.19328823,
#        26.19328823, 26.19328823])

# %%
plt.figure(figsize=(30,15))
plt.plot(X, y, color = 'blue', label="PM10 values")
plt.plot(X, y_pred, color = 'red', label = 'ARD Regression')
plt.title('ARD regression on December 2021 in Toamnei', fontsize=18)
plt.xlabel('TimeStamp', fontsize=16)
plt.ylabel('Value', fontsize=16)
plt.legend(fontsize=16)
plt.savefig('plots_from_csv/PM10_Toamnei_2021-12_ARD.jpg', bbox_inches = 'tight')
plt.show()
