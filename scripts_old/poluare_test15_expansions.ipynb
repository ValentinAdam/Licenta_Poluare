# %%
import pandas as pd

# %%
import requests
from requests.auth import HTTPBasicAuth
auth = HTTPBasicAuth('elastic', 'AWbtmGda2Q7BI2bYpdjyF4qd')
url1 = 'https://8f9677360fc34e2eb943d737b2597c7b.us-east-1.aws.found.io:9243/brasov-dev/_search?sort=TimeStamp:desc&from=0&size=100&q=*'
url2 = 'https://8f9677360fc34e2eb943d737b2597c7b.us-east-1.aws.found.io:9243/brasov-dev/_search?sort=TimeStamp:desc&from=100&size=100&q=*'

# %%
response1 = requests.get(url=url1, auth=auth)

# %%
response2 = requests.get(url=url2, auth=auth)

# %%
print(response1)
print(response2)
# Out:
# <Response [200]>
# <Response [200]>

# %%
import json
data1 = json.loads(response1.text)
data2 = json.loads(response2.text)

# %%
data1
# Out:
# {'took': 102,
#  'timed_out': False,
#  '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 10000, 'relation': 'gte'},
#   'max_score': None,
#   'hits': [{'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'fEHs438Bwa_bL2zRg4FR',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm25',
#      'Value': 2,
#      'LocationLat': 45.589267,
#      'LocationLong': 25.46445,
#      'TimeStamp': 1648796400000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648796400000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'fUHs438Bwa_bL2zRg4FU',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm10',
#      'Value': 3,
#      'LocationLat': 45.589267,
#      'LocationLong': 25.46445,
#      'TimeStamp': 1648796400000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648796400000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'fkHs438Bwa_bL2zRg4Fi',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm1',
#      'Value': 1,
#      'LocationLat': 45.589267,
#      'LocationLong': 25.46445,
#      'TimeStamp': 1648796400000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648796400000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': '80Hs438Bwa_bL2zRiIED',
#     '_score': None,
#     '_source': {'Source': 'Waqi',
#      'Sensor': 'o3',
#      'Value': 27.5,
#      'LocationLat': 45.6491174,
#      'LocationLong': 25.6041355,
#      'TimeStamp': 1648796400000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648796400000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': '9UHs438Bwa_bL2zRiIEF',
#     '_score': None,
#     '_source': {'Source': 'Waqi',
#      'Sensor': 'pm10',
#      'Value': 15,
#      'LocationLat': 45.6491174,
#      'LocationLong': 25.6041355,
#      'TimeStamp': 1648796400000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648796400000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': '9kHs438Bwa_bL2zRiIEF',
#     '_score': None,
#     '_source': {'Source': 'Waqi',
#      'Sensor': 'so2',
#      'Value': 2.1,
#      'LocationLat': 45.6491174,
#      'LocationLong': 25.6041355,
#      'TimeStamp': 1648796400000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648796400000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': '90Hs438Bwa_bL2zRiIH5',
#     '_score': None,
#     '_source': {'Source': 'Waqi',
#      'Sensor': 'so2',
#      'Value': 1.4,
#      'LocationLat': 45.7167,
#      'LocationLong': 25.6333,
#      'TimeStamp': 1648796400000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648796400000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': '-EHs438Bwa_bL2zRiIH5',
#     '_score': None,
#     '_source': {'Source': 'Waqi',
#      'Sensor': 'no2',
#      'Value': 37.5,
#      'LocationLat': 45.6343302,
#      'LocationLong': 25.6338716,
#      'TimeStamp': 1648796400000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648796400000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': '-UHs438Bwa_bL2zRiIH7',
#     '_score': None,
#     '_source': {'Source': 'Waqi',
#      'Sensor': 'o3',
#      'Value': 35.8,
#      'LocationLat': 45.7167,
#      'LocationLong': 25.6333,
#      'TimeStamp': 1648796400000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648796400000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': '-kHs438Bwa_bL2zRiIH8',
#     '_score': None,
#     '_source': {'Source': 'Waqi',
#      'Sensor': 'pm10',
#      'Value': 9,
#      'LocationLat': 45.6343302,
#      'LocationLong': 25.6338716,
#      'TimeStamp': 1648796400000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648796400000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': '-0Hs438Bwa_bL2zRiYFR',
#     '_score': None,
#     '_source': {'Source': 'Waqi',
#      'Sensor': 'no2',
#      'Value': 2.8,
#      'LocationLat': 45.7167,
#      'LocationLong': 25.6333,
#      'TimeStamp': 1648796400000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648796400000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': '_EHs438Bwa_bL2zRiYFR',
#     '_score': None,
#     '_source': {'Source': 'Waqi',
#      'Sensor': 'pm10',
#      'Value': 13,
#      'LocationLat': 45.7167,
#      'LocationLong': 25.6333,
#      'TimeStamp': 1648796400000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648796400000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': '_UHs438Bwa_bL2zRiYFT',
#     '_score': None,
#     '_source': {'Source': 'Waqi',
#      'Sensor': 'pm10',
#      'Value': 16,
#      'LocationLat': 45.6542706,
#      'LocationLong': 25.6240614,
#      'TimeStamp': 1648796400000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648796400000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': '_kHs438Bwa_bL2zRiYFU',
#     '_score': None,
#     '_source': {'Source': 'Waqi',
#      'Sensor': 'so2',
#      'Value': 2.3,
#      'LocationLat': 45.6542706,
#      'LocationLong': 25.6240614,
#      'TimeStamp': 1648796400000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648796400000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': '_0Hs438Bwa_bL2zRiYFh',
#     '_score': None,
#     '_source': {'Source': 'Waqi',
#      'Sensor': 'pm10',
#      'Value': 16,
#      'LocationLat': 45.6598333,
#      'LocationLong': 25.6144883,
#      'TimeStamp': 1648796400000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648796400000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'AEHs438Bwa_bL2zRioId',
#     '_score': None,
#     '_source': {'Source': 'Waqi',
#      'Sensor': 'no2',
#      'Value': 21.4,
#      'LocationLat': 45.6598333,
#      'LocationLong': 25.6144883,
#      'TimeStamp': 1648796400000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648796400000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': '9EHs438Bwa_bL2zRiIED',
#     '_score': None,
#     '_source': {'Source': 'Waqi',
#      'Sensor': 'no2',
#      'Value': 19.5,
#      'LocationLat': 45.6491174,
#      'LocationLong': 25.6041355,
#      'TimeStamp': 1648796400000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648796400000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'AUHs438Bwa_bL2zRioId',
#     '_score': None,
#     '_source': {'Source': 'Waqi',
#      'Sensor': 'no2',
#      'Value': 23.2,
#      'LocationLat': 45.6542706,
#      'LocationLong': 25.6240614,
#      'TimeStamp': 1648796400000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648796400000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'cUHs438Bwa_bL2zRgoGH',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm25',
#      'Value': 1,
#      'LocationLat': 45.645914,
#      'LocationLong': 25.602642,
#      'TimeStamp': 1648796399000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648796399000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'c0Hs438Bwa_bL2zRgoHs',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm25',
#      'Value': 4,
#      'LocationLat': 45.6536,
#      'LocationLong': 25.599,
#      'TimeStamp': 1648796399000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648796399000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'gUHs438Bwa_bL2zRg4GC',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm1',
#      'Value': 0,
#      'LocationLat': 45.6536,
#      'LocationLong': 25.599,
#      'TimeStamp': 1648796399000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648796399000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'iUHs438Bwa_bL2zRg4HU',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm10',
#      'Value': 6,
#      'LocationLat': 45.6536,
#      'LocationLong': 25.599,
#      'TimeStamp': 1648796399000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648796399000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'j0Hs438Bwa_bL2zRhIEh',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm1',
#      'Value': 0,
#      'LocationLat': 45.645914,
#      'LocationLong': 25.602642,
#      'TimeStamp': 1648796399000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648796399000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'mEHs438Bwa_bL2zRhIFn',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm10',
#      'Value': 1,
#      'LocationLat': 45.645914,
#      'LocationLong': 25.602642,
#      'TimeStamp': 1648796399000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648796399000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'jkHs438Bwa_bL2zRhIEE',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm1',
#      'Value': 0,
#      'LocationLat': 45.641274,
#      'LocationLong': 25.614817,
#      'TimeStamp': 1648796397000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648796397000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': '10Hs438Bwa_bL2zRhoFF',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm10',
#      'Value': 0,
#      'LocationLat': 45.641274,
#      'LocationLong': 25.614817,
#      'TimeStamp': 1648796397000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648796397000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': '50Hs438Bwa_bL2zRhoFf',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm25',
#      'Value': 0,
#      'LocationLat': 45.641274,
#      'LocationLong': 25.614817,
#      'TimeStamp': 1648796397000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648796397000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'ikHs438Bwa_bL2zRg4Hb',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm1',
#      'Value': 0,
#      'LocationLat': 45.646976,
#      'LocationLong': 25.595224,
#      'TimeStamp': 1648796396000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648796396000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': '3EHs438Bwa_bL2zRhoFG',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm25',
#      'Value': 0,
#      'LocationLat': 45.646976,
#      'LocationLong': 25.595224,
#      'TimeStamp': 1648796396000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648796396000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'zUHs438Bwa_bL2zRhoEV',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm10',
#      'Value': 0,
#      'LocationLat': 45.646976,
#      'LocationLong': 25.595224,
#      'TimeStamp': 1648796396000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648796396000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'ukHs438Bwa_bL2zRhYG6',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'co2',
#      'Value': 501,
#      'LocationLat': 45.651464,
#      'LocationLong': 25.615426,
#      'TimeStamp': 1648796384000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648796384000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'u0Hs438Bwa_bL2zRhYG_',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'o3',
#      'Value': 20,
#      'LocationLat': 45.651464,
#      'LocationLong': 25.615426,
#      'TimeStamp': 1648796384000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648796384000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'vkHs438Bwa_bL2zRhYHH',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm10',
#      'Value': 6,
#      'LocationLat': 45.651464,
#      'LocationLong': 25.615426,
#      'TimeStamp': 1648796384000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648796384000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'wUHs438Bwa_bL2zRhYHJ',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm25',
#      'Value': 4,
#      'LocationLat': 45.651464,
#      'LocationLong': 25.615426,
#      'TimeStamp': 1648796384000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648796384000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': '40Hs438Bwa_bL2zRhoFY',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'cho2',
#      'Value': 7,
#      'LocationLat': 45.651464,
#      'LocationLong': 25.615426,
#      'TimeStamp': 1648796384000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648796384000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': '6kHs438Bwa_bL2zRhoFq',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm1',
#      'Value': 2,
#      'LocationLat': 45.651464,
#      'LocationLong': 25.615426,
#      'TimeStamp': 1648796384000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648796384000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'g0Hs438Bwa_bL2zRg4Gc',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm10',
#      'Value': 5,
#      'LocationLat': 45.55914,
#      'LocationLong': 25.324771,
#      'TimeStamp': 1648796383000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648796383000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'hkHs438Bwa_bL2zRg4Gv',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm1',
#      'Value': 2,
#      'LocationLat': 45.55914,
#      'LocationLong': 25.324771,
#      'TimeStamp': 1648796383000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648796383000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'uUHs438Bwa_bL2zRhYGP',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm25',
#      'Value': 3,
#      'LocationLat': 45.55914,
#      'LocationLong': 25.324771,
#      'TimeStamp': 1648796383000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648796383000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'b0Hs438Bwa_bL2zRgoER',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm1',
#      'Value': 3,
#      'LocationLat': 45.700748,
#      'LocationLong': 25.442761,
#      'TimeStamp': 1648796381000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648796381000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'dkHs438Bwa_bL2zRgoH4',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm10',
#      'Value': 5,
#      'LocationLat': 45.700748,
#      'LocationLong': 25.442761,
#      'TimeStamp': 1648796381000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648796381000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'ekHs438Bwa_bL2zRg4Eu',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm25',
#      'Value': 4,
#      'LocationLat': 45.700748,
#      'LocationLong': 25.442761,
#      'TimeStamp': 1648796381000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648796381000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'XUHs438Bwa_bL2zRf4FR',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm10',
#      'Value': 10,
#      'LocationLat': 45.6568,
#      'LocationLong': 25.5917,
#      'TimeStamp': 1648796374000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648
]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': '60G1438Bwa_bL2zRlYAf',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm25',
#      'Value': 4,
#      'LocationLat': 45.638767,
#      'LocationLong': 25.586021,
#      'TimeStamp': 1648792751000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648792751000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': '70G1438Bwa_bL2zRlYBQ',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm1',
#      'Value': 2,
#      'LocationLat': 45.638767,
#      'LocationLong': 25.586021,
#      'TimeStamp': 1648792751000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648792751000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'HUG1438Bwa_bL2zRl4E3',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm10',
#      'Value': 4,
#      'LocationLat': 45.638767,
#      'LocationLong': 25.586021,
#      'TimeStamp': 1648792751000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648792751000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': '8kG1438Bwa_bL2zRlYBu',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm10',
#      'Value': 6,
#      'LocationLat': 45.698269,
#      'LocationLong': 25.558889,
#      'TimeStamp': 1648792749000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648792749000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': '_0G1438Bwa_bL2zRlYDS',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm1',
#      'Value': 4,
#      'LocationLat': 45.698269,
#      'LocationLong': 25.558889,
#      'TimeStamp': 1648792749000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648792749000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'AEG1438Bwa_bL2zRlYHT',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm25',
#      'Value': 6,
#      'LocationLat': 45.698269,
#      'LocationLong': 25.558889,
#      'TimeStamp': 1648792749000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648792749000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': '4EG1438Bwa_bL2zRlIDY',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm25',
#      'Value': 7,
#      'LocationLat': 45.623958,
#      'LocationLong': 25.481535,
#      'TimeStamp': 1648792746000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648792746000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': '4UG1438Bwa_bL2zRlIDe',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm1',
#      'Value': 5,
#      'LocationLat': 45.623958,
#      'LocationLong': 25.481535,
#      'TimeStamp': 1648792746000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648792746000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'CUG1438Bwa_bL2zRloET',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm10',
#      'Value': 9,
#      'LocationLat': 45.623958,
#      'LocationLong': 25.481535,
#      'TimeStamp': 1648792746000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648792746000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'LkG1438Bwa_bL2zRmIHC',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm10',
#      'Value': 0,
#      'LocationLat': 45.665184,
#      'LocationLong': 25.558891,
#      'TimeStamp': 1648792714000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648792714000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': '90G1438Bwa_bL2zRlYCb',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm1',
#      'Value': 0,
#      'LocationLat': 45.665184,
#      'LocationLong': 25.558891,
#      'TimeStamp': 1648792714000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648792714000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'AUG1438Bwa_bL2zRlYHg',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm25',
#      'Value': 6,
#      'LocationLat': 45.665184,
#      'LocationLong': 25.558891,
#      'TimeStamp': 1648792714000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648792714000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': '_EG1438Bwa_bL2zRlYC4',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm25',
#      'Value': 7,
#      'LocationLat': 45.657861,
#      'LocationLong': 25.621916,
#      'TimeStamp': 1648792709000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648792709000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': '_kG1438Bwa_bL2zRlYDS',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm1',
#      'Value': 0,
#      'LocationLat': 45.657861,
#      'LocationLong': 25.621916,
#      'TimeStamp': 1648792709000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648792709000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'AkG1438Bwa_bL2zRlYHk',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm10',
#      'Value': 1,
#      'LocationLat': 45.657861,
#      'LocationLong': 25.621916,
#      'TimeStamp': 1648792709000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648792709000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'DEF-438Bwa_bL2zRoYCb',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm1',
#      'Value': 3,
#      'LocationLat': 45.589267,
#      'LocationLong': 25.46445,
#      'TimeStamp': 1648789200000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648789200000]},
#    {'_index': 'brasov-dev',
#     '_type': '_doc',
#     '_id': 'aEF-438Bwa_bL2zRooCb',
#     '_score': None,
#     '_source': {'Source': 'UradMonitor',
#      'Sensor': 'pm10',
#      'Value': 6,
#      'LocationLat': 45.589267,
#      'LocationLong': 25.46445,
#      'TimeStamp': 1648789200000,
#      'Measurement': 'µg/m3'},
#     'sort': [1648789200000]}]}}

# %%
from pandas import json_normalize
dataframe1 = json_normalize(data1['hits']['hits'])
dataframe2 = json_normalize(data2['hits']['hits'])

# %%
dataframe1
# Out:
#         _index _type                   _id _score             sort  \
# 0   brasov-dev  _doc  fEHs438Bwa_bL2zRg4FR   None  [1648796400000]
# 1   brasov-dev  _doc  fUHs438Bwa_bL2zRg4FU   None  [1648796400000]
# 2   brasov-dev  _doc  fkHs438Bwa_bL2zRg4Fi   None  [1648796400000]
# 3   brasov-dev  _doc  80Hs438Bwa_bL2zRiIED   None  [1648796400000]
# 4   brasov-dev  _doc  9UHs438Bwa_bL2zRiIEF   None  [1648796400000]
# ..         ...   ...                   ...    ...              ...
# 95  brasov-dev  _doc  2UHs438Bwa_bL2zRhoFF   None  [1648796315000]
# 96  brasov-dev  _doc  nEHs438Bwa_bL2zRhIGo   None  [1648796309000]
# 97  brasov-dev  _doc  nkHs438Bwa_bL2zRhIGq   None  [1648796309000]
# 98  brasov-dev  _doc  5kHs438Bwa_bL2zRhoFb   None  [1648796309000]
# 99  brasov-dev  _doc  1EG1438Bwa_bL2zRlIB9   None  [1648792800000]
#
#    _source.Source _source.Sensor  _source.Value  _source.LocationLat  \
# 0     UradMonitor           pm25            2.0            45.589267
# 1     UradMonitor           pm10            3.0            45.589267
# 2     UradMonitor            pm1            1.0            45.589267
# 3            Waqi             o3           27.5            45.649117
# 4            Waqi           pm10           15.0            45.649117
# ..            ...            ...            ...                  ...
# 95    UradMonitor           pm10            0.0            45.665184
# 96    UradMonitor           pm10            1.0            45.657861
# 97    UradMonitor           pm25            8.0            45.657861
# 98    UradMonitor            pm1            0.0            45.657861
# 99    UradMonitor            pm1            3.0            45.589267
#
#     _source.LocationLong  _source.TimeStamp _source.Measurement
# 0              25.464450      1648796400000               µg/m3
# 1              25.464450      1648796400000               µg/m3
# 2              25.464450      1648796400000               µg/m3
# 3              25.604136      1648796400000               µg/m3
# 4              25.604136      1648796400000               µg/m3
# ..                   ...                ...                 ...
# 95             25.558891      1648796315000               µg/m3
# 96             25.621916      1648796309000               µg/m3
# 97             25.621916      1648796309000               µg/m3
# 98             25.621916      1648796309000               µg/m3
# 99             25.464450      1648792800000               µg/m3
#
# [100 rows x 12 columns]

# %%
dataframe2
# Out:
#         _index _type                   _id _score             sort  \
# 0   brasov-dev  _doc  1kG1438Bwa_bL2zRlICE   None  [1648792800000]
# 1   brasov-dev  _doc  2EG1438Bwa_bL2zRlICP   None  [1648792800000]
# 2   brasov-dev  _doc  TUG1438Bwa_bL2zRnYGX   None  [1648792800000]
# 3   brasov-dev  _doc  P0G1438Bwa_bL2zRmoGX   None  [1648792800000]
# 4   brasov-dev  _doc  QEG1438Bwa_bL2zRmoGY   None  [1648792800000]
# ..         ...   ...                   ...    ...              ...
# 95  brasov-dev  _doc  _EG1438Bwa_bL2zRlYC4   None  [1648792709000]
# 96  brasov-dev  _doc  _kG1438Bwa_bL2zRlYDS   None  [1648792709000]
# 97  brasov-dev  _doc  AkG1438Bwa_bL2zRlYHk   None  [1648792709000]
# 98  brasov-dev  _doc  DEF-438Bwa_bL2zRoYCb   None  [1648789200000]
# 99  brasov-dev  _doc  aEF-438Bwa_bL2zRooCb   None  [1648789200000]
#
#    _source.Source _source.Sensor  _source.Value  _source.LocationLat  \
# 0     UradMonitor           pm25            4.0            45.589267
# 1     UradMonitor           pm10            6.0            45.589267
# 2            Waqi            no2           26.4            45.659833
# 3            Waqi             o3           31.6            45.649117
# 4            Waqi           pm10           15.0            45.649117
# ..            ...            ...            ...                  ...
# 95    UradMonitor           pm25            7.0            45.657861
# 96    UradMonitor            pm1            0.0            45.657861
# 97    UradMonitor           pm10            1.0            45.657861
# 98    UradMonitor            pm1            3.0            45.589267
# 99    UradMonitor           pm10            6.0            45.589267
#
#     _source.LocationLong  _source.TimeStamp _source.Measurement
# 0              25.464450      1648792800000               µg/m3
# 1              25.464450      1648792800000               µg/m3
# 2              25.614488      1648792800000               µg/m3
# 3              25.604136      1648792800000               µg/m3
# 4              25.604136      1648792800000               µg/m3
# ..                   ...                ...                 ...
# 95             25.621916      1648792709000               µg/m3
# 96             25.621916      1648792709000               µg/m3
# 97             25.621916      1648792709000               µg/m3
# 98             25.464450      1648789200000               µg/m3
# 99             25.464450      1648789200000               µg/m3
#
# [100 rows x 12 columns]

# %%
dataframes = [dataframe1, dataframe2]
df_concat = pd.concat(dataframes)
df_concat
# Out:
#         _index _type                   _id _score             sort  \
# 0   brasov-dev  _doc  fEHs438Bwa_bL2zRg4FR   None  [1648796400000]
# 1   brasov-dev  _doc  fUHs438Bwa_bL2zRg4FU   None  [1648796400000]
# 2   brasov-dev  _doc  fkHs438Bwa_bL2zRg4Fi   None  [1648796400000]
# 3   brasov-dev  _doc  80Hs438Bwa_bL2zRiIED   None  [1648796400000]
# 4   brasov-dev  _doc  9UHs438Bwa_bL2zRiIEF   None  [1648796400000]
# ..         ...   ...                   ...    ...              ...
# 95  brasov-dev  _doc  _EG1438Bwa_bL2zRlYC4   None  [1648792709000]
# 96  brasov-dev  _doc  _kG1438Bwa_bL2zRlYDS   None  [1648792709000]
# 97  brasov-dev  _doc  AkG1438Bwa_bL2zRlYHk   None  [1648792709000]
# 98  brasov-dev  _doc  DEF-438Bwa_bL2zRoYCb   None  [1648789200000]
# 99  brasov-dev  _doc  aEF-438Bwa_bL2zRooCb   None  [1648789200000]
#
#    _source.Source _source.Sensor  _source.Value  _source.LocationLat  \
# 0     UradMonitor           pm25            2.0            45.589267
# 1     UradMonitor           pm10            3.0            45.589267
# 2     UradMonitor            pm1            1.0            45.589267
# 3            Waqi             o3           27.5            45.649117
# 4            Waqi           pm10           15.0            45.649117
# ..            ...            ...            ...                  ...
# 95    UradMonitor           pm25            7.0            45.657861
# 96    UradMonitor            pm1            0.0            45.657861
# 97    UradMonitor           pm10            1.0            45.657861
# 98    UradMonitor            pm1            3.0            45.589267
# 99    UradMonitor           pm10            6.0            45.589267
#
#     _source.LocationLong  _source.TimeStamp _source.Measurement
# 0              25.464450      1648796400000               µg/m3
# 1              25.464450      1648796400000               µg/m3
# 2              25.464450      1648796400000               µg/m3
# 3              25.604136      1648796400000               µg/m3
# 4              25.604136      1648796400000               µg/m3
# ..                   ...                ...                 ...
# 95             25.621916      1648792709000               µg/m3
# 96             25.621916      1648792709000               µg/m3
# 97             25.621916      1648792709000               µg/m3
# 98             25.464450      1648789200000               µg/m3
# 99             25.464450      1648789200000               µg/m3
#
# [200 rows x 12 columns]

# %%
import matplotlib.pyplot as plt
hist_sensor = plt.figure(figsize = (25,10))
ax = hist_sensor.gca()

df_concat.get('_source.Sensor').value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df_concat['LocationId'] = df_concat['_source.LocationLat']*10000000 + df_concat['_source.LocationLong']*10000000
df_concat['LocationName'] = ""
df_concat.loc[df_concat['LocationId'] == 712668900.0, 'LocationName'] = 'AFI' 
df_concat.loc[df_concat['LocationId'] == 712196290.0, 'LocationName'] = 'Bartolomeu1'
df_concat.loc[df_concat['LocationId'] == 712209000.0, 'LocationName'] = 'Bartolomeu2'
df_concat.loc[df_concat['LocationId'] == 712240750.0, 'LocationName'] = 'Bartolomeu3'
df_concat.loc[df_concat['LocationId'] == 708361730.0, 'LocationName'] = 'Bucegi'
df_concat.loc[df_concat['LocationId'] == 712682018.0, 'LocationName'] = 'Carrefour'
df_concat.loc[df_concat['LocationId'] == 712307300.0, 'LocationName'] = 'Centru1'
df_concat.loc[df_concat['LocationId'] == 712422000.0, 'LocationName'] = 'Centru2'
df_concat.loc[df_concat['LocationId'] == 712485560.0, 'LocationName'] = 'Centru3'
df_concat.loc[df_concat['LocationId'] == 712532529.0, 'LocationName'] = 'Centru4'
df_concat.loc[df_concat['LocationId'] == 711435090.0, 'LocationName'] = 'Codlea1'
df_concat.loc[df_concat['LocationId'] == 711587690.0, 'LocationName'] = 'Codlea2'
df_concat.loc[df_concat['LocationId'] == 712526000.0, 'LocationName'] = 'Colina1'
df_concat.loc[df_concat['LocationId'] == 712485000.0, 'LocationName'] = 'Colina2'
df_concat.loc[df_concat['LocationId'] == 711054930.0, 'LocationName'] = 'Cristian'
df_concat.loc[df_concat['LocationId'] == 712743216.0, 'LocationName'] = 'Gara'
df_concat.loc[df_concat['LocationId'] == 713825580.0, 'LocationName'] = 'Harman1'
df_concat.loc[df_concat['LocationId'] == 714030800.0, 'LocationName'] = 'Harman2'
df_concat.loc[df_concat['LocationId'] == 712560910.0, 'LocationName'] = 'Racadau'
df_concat.loc[df_concat['LocationId'] == 710537170.0, 'LocationName'] = 'Rasnov'
df_concat.loc[df_concat['LocationId'] == 713449870.0, 'LocationName'] = 'Sanpetru1'
df_concat.loc[df_concat['LocationId'] == 713500000.0, 'LocationName'] = 'Sanpetru2'
df_concat.loc[df_concat['LocationId'] == 712475170.0, 'LocationName'] = 'Saturn'
df_concat.loc[df_concat['LocationId'] == 712500331.0, 'LocationName'] = 'Stupini1'
df_concat.loc[df_concat['LocationId'] == 712571580.0, 'LocationName'] = 'Stupini2'
df_concat.loc[df_concat['LocationId'] == 712804610.0, 'LocationName'] = 'Tractorul'
df_concat.loc[df_concat['LocationId'] == 713218270.0, 'LocationName'] = 'TriajH'
df_concat.loc[df_concat['LocationId'] == 712783320.0, 'LocationName'] = 'Vlahuta1'
df_concat.loc[df_concat['LocationId'] == 712797770.0, 'LocationName'] = 'Vlahuta2'
df_concat.head(10)
# Out:
#        _index _type                   _id _score             sort  \
# 0  brasov-dev  _doc  fEHs438Bwa_bL2zRg4FR   None  [1648796400000]
# 1  brasov-dev  _doc  fUHs438Bwa_bL2zRg4FU   None  [1648796400000]
# 2  brasov-dev  _doc  fkHs438Bwa_bL2zRg4Fi   None  [1648796400000]
# 3  brasov-dev  _doc  80Hs438Bwa_bL2zRiIED   None  [1648796400000]
# 4  brasov-dev  _doc  9UHs438Bwa_bL2zRiIEF   None  [1648796400000]
# 5  brasov-dev  _doc  9kHs438Bwa_bL2zRiIEF   None  [1648796400000]
# 6  brasov-dev  _doc  90Hs438Bwa_bL2zRiIH5   None  [1648796400000]
# 7  brasov-dev  _doc  -EHs438Bwa_bL2zRiIH5   None  [1648796400000]
# 8  brasov-dev  _doc  -UHs438Bwa_bL2zRiIH7   None  [1648796400000]
# 9  brasov-dev  _doc  -kHs438Bwa_bL2zRiIH8   None  [1648796400000]
#
#   _source.Source _source.Sensor  _source.Value  _source.LocationLat  \
# 0    UradMonitor           pm25            2.0            45.589267
# 1    UradMonitor           pm10            3.0            45.589267
# 2    UradMonitor            pm1            1.0            45.589267
# 3           Waqi             o3           27.5            45.649117
# 4           Waqi           pm10           15.0            45.649117
# 5           Waqi            so2            2.1            45.649117
# 6           Waqi            so2            1.4            45.716700
# 7           Waqi            no2           37.5            45.634330
# 8           Waqi             o3           35.8            45.716700
# 9           Waqi           pm10            9.0            45.634330
#
#    _source.LocationLong  _source.TimeStamp _source.Measurement   LocationId  \
# 0             25.464450      1648796400000               µg/m3  710537170.0
# 1             25.464450      1648796400000               µg/m3  710537170.0
# 2             25.464450      1648796400000               µg/m3  710537170.0
# 3             25.604136      1648796400000               µg/m3  712532529.0
# 4             25.604136      1648796400000               µg/m3  712532529.0
# 5             25.604136      1648796400000               µg/m3  712532529.0
# 6             25.633300      1648796400000               µg/m3  713500000.0
# 7             25.633872      1648796400000               µg/m3  712682018.0
# 8             25.633300      1648796400000               µg/m3  713500000.0
# 9             25.633872      1648796400000               µg/m3  712682018.0
#
#   LocationName
# 0       Rasnov
# 1       Rasnov
# 2       Rasnov
# 3      Centru4
# 4      Centru4
# 5      Centru4
# 6    Sanpetru2
# 7    Carrefour
# 8    Sanpetru2
# 9    Carrefour

# %%
# dataframe.groupby(['LocationName']).size().reset_index().rename(columns={0:'count'})

# %%
# hist_location = dataframe.get('LocationName').hist()
import matplotlib.pyplot as plt
hist_location = plt.figure(figsize = (25,10))
ax = hist_location.gca()
# dataframe.get('LocationName').hist(ax = ax)

df_concat.get('LocationName').value_counts().plot(kind='bar')
# dataframe.get('LocationName').value_counts(sort=False).plot.bar(rot=0)
# Out:
# <AxesSubplot:>

# %%
dataframe_v2 = df_concat[[i for i in list(df_concat.columns) if i != '_index']]
dataframe_v2 = dataframe_v2[[i for i in list(dataframe_v2.columns) if i != '_type']]
dataframe_v2 = dataframe_v2[[i for i in list(dataframe_v2.columns) if i != '_id']]
dataframe_v2 = dataframe_v2[[i for i in list(dataframe_v2.columns) if i != '_score']]
dataframe_v2 = dataframe_v2[[i for i in list(dataframe_v2.columns) if i != 'sort']]
dataframe_v2.head(7)
# dataframe_v2
# Out:
#   _source.Source _source.Sensor  _source.Value  _source.LocationLat  \
# 0    UradMonitor           pm25            2.0            45.589267
# 1    UradMonitor           pm10            3.0            45.589267
# 2    UradMonitor            pm1            1.0            45.589267
# 3           Waqi             o3           27.5            45.649117
# 4           Waqi           pm10           15.0            45.649117
# 5           Waqi            so2            2.1            45.649117
# 6           Waqi            so2            1.4            45.716700
#
#    _source.LocationLong  _source.TimeStamp _source.Measurement   LocationId  \
# 0             25.464450      1648796400000               µg/m3  710537170.0
# 1             25.464450      1648796400000               µg/m3  710537170.0
# 2             25.464450      1648796400000               µg/m3  710537170.0
# 3             25.604136      1648796400000               µg/m3  712532529.0
# 4             25.604136      1648796400000               µg/m3  712532529.0
# 5             25.604136      1648796400000               µg/m3  712532529.0
# 6             25.633300      1648796400000               µg/m3  713500000.0
#
#   LocationName
# 0       Rasnov
# 1       Rasnov
# 2       Rasnov
# 3      Centru4
# 4      Centru4
# 5      Centru4
# 6    Sanpetru2

# %%
cho2 = dataframe_v2[dataframe_v2.get('_source.Sensor') == 'cho2']
co2 = dataframe_v2[dataframe_v2.get('_source.Sensor') == 'co2']
no2 = dataframe_v2[dataframe_v2.get('_source.Sensor') == 'no2']
o3 = dataframe_v2[dataframe_v2.get('_source.Sensor') == 'o3']
pm1 = dataframe_v2[dataframe_v2.get('_source.Sensor') == 'pm1']
pm10 = dataframe_v2[dataframe_v2.get('_source.Sensor') == 'pm10']
pm25 = dataframe_v2[dataframe_v2.get('_source.Sensor') == 'pm25']
so2 = dataframe_v2[dataframe_v2.get('_source.Sensor') == 'so2']

# %%
print('Lungime dataframe: ',len(dataframe_v2))
print('Lungime dataframe cho2: ',len(cho2))
print('Lungime dataframe co2: ',len(co2))
print('Lungime dataframe no2: ',len(no2))
print('Lungime dataframe o3: ',len(o3))
print('Lungime dataframe pm1: ',len(pm1))
print('Lungime dataframe pm10: ',len(pm10))
print('Lungime dataframe pm25: ',len(pm25))
print('Lungime dataframe so2: ',len(so2))
# Out:
# Lungime dataframe:  200
# Lungime dataframe cho2:  8
# Lungime dataframe co2:  8
# Lungime dataframe no2:  10
# Lungime dataframe o3:  12
# Lungime dataframe pm1:  49
# Lungime dataframe pm10:  59
# Lungime dataframe pm25:  48
# Lungime dataframe so2:  6

# %%
import matplotlib.pyplot as plt
plt.close("all")
# fig = plt.figure(figsize=(20,10), frameon=True)
plt.figure(figsize=(20,10))
plt.plot(so2.get('_source.TimeStamp'), so2.get('_source.Value'), label="All SO2 sensors")
plt.scatter(so2.get('_source.TimeStamp'), so2.get('_source.Value'), color = "red")
plt.xlabel("TimeStamp")
plt.ylabel("Value")
plt.title("Last 10000 values for all SO2 sensors")
plt.legend()
plt.savefig('plots_updated/SO2.jpg', bbox_inches = 'tight')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.linear_model import LinearRegression

# %%
X = so2[["_source.TimeStamp"]].values
y = so2[["_source.Value"]].values

# %%
regressor = LinearRegression()
regressor.fit(X, y)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(X)

# %%
print("Slope: ", float(regressor.coef_))
print("Intercept: ", float(regressor.intercept_))
# float("{:.8f}".format(float(regressor.intercept_)))
# Out:
# Slope:  1.8518518518518525e-08
# Intercept:  -30531.333333333343

# %%
plt.figure(figsize=(20,10))
# plt.scatter(X, y, color = 'blue')
plt.plot(X,y, color = 'blue', label="All SO2 values")
plt.plot(X, regressor.predict(X), color = 'red', label="SO2 linear regression")
plt.title('Linear regression on last 10000 SO2 values')
plt.xlabel('TimeStamp')
plt.ylabel('Value')
plt.legend()
plt.savefig('plots_updated/SO2_regression.jpg', bbox_inches = 'tight')
plt.show()

# %%
so2.head(6) #Vlahuta1, Centru4, Sanpetru2
# Out:
#    _source.Source _source.Sensor  _source.Value  _source.LocationLat  \
# 5            Waqi            so2            2.1            45.649117
# 6            Waqi            so2            1.4            45.716700
# 13           Waqi            so2            2.3            45.654271
# 6            Waqi            so2            1.9            45.649117
# 7            Waqi            so2            1.4            45.716700
# 13           Waqi            so2            2.3            45.654271
#
#     _source.LocationLong  _source.TimeStamp _source.Measurement   LocationId  \
# 5              25.604136      1648796400000               µg/m3  712532529.0
# 6              25.633300      1648796400000               µg/m3  713500000.0
# 13             25.624061      1648796400000               µg/m3  712783320.0
# 6              25.604136      1648792800000               µg/m3  712532529.0
# 7              25.633300      1648792800000               µg/m3  713500000.0
# 13             25.624061      1648792800000               µg/m3  712783320.0
#
#    LocationName
# 5       Centru4
# 6     Sanpetru2
# 13     Vlahuta1
# 6       Centru4
# 7     Sanpetru2
# 13     Vlahuta1

# %%
so2_vlahuta1 = so2[so2.get('LocationName') == 'Vlahuta1']
so2_centru4 = so2[so2.get('LocationName') == 'Centru4']
so2_sanpetru2 = so2[so2.get('LocationName') == 'Sanpetru2']

# %%
import matplotlib.pyplot as plt
plt.close("all")
plt.figure(figsize=(20,10))
plt.plot(so2_vlahuta1.get('_source.TimeStamp'), so2_vlahuta1.get('_source.Value'), color = "red", label="Vlahuta1 SO2 sensor")
plt.plot(so2_centru4.get('_source.TimeStamp'), so2_centru4.get('_source.Value'), color = "blue", label="Centru4 SO2 sensor")
plt.plot(so2_sanpetru2.get('_source.TimeStamp'), so2_sanpetru2.get('_source.Value'), color = "purple", label="Sanpetru2 SO2 sensor")
plt.xlabel("TimeStamp")
plt.ylabel("Value")
plt.title("Last 10000 values for SO2")
plt.legend()
plt.savefig('plots_updated/SO2_all.jpg', bbox_inches = 'tight')
plt.show()

# %%
pm10_bartolomeu1 = pm10[pm10.get('LocationName') == 'Bartolomeu1']
pm10_bartolomeu2 = pm10[pm10.get('LocationName') == 'Bartolomeu2']
pm10_bartolomeu3 = pm10[pm10.get('LocationName') == 'Bartolomeu3']

# %%
import matplotlib.pyplot as plt
plt.close("all")
plt.figure(figsize=(20,10))
plt.plot(pm10_bartolomeu1.get('_source.TimeStamp'), pm10_bartolomeu1.get('_source.Value'), color = "red", label="Bartolomeu1 PM10 sensor")
plt.plot(pm10_bartolomeu2.get('_source.TimeStamp'), pm10_bartolomeu2.get('_source.Value'), color = "blue", label="Bartolomeu2 PM10 sensor")
plt.plot(pm10_bartolomeu3.get('_source.TimeStamp'), pm10_bartolomeu3.get('_source.Value'), color = "purple", label="Bartolomeu3 PM10 sensor")
plt.xlabel("TimeStamp")
plt.ylabel("Value")
plt.title("Last 10000 values for PM10 in Bartolomeu")
plt.legend()
plt.savefig('plots_updated/PM10_Bartolomeu.jpg', bbox_inches = 'tight')
plt.show()

# %%
pm10_bartolomeu2.head(30)
# Out:
#      _source.Source _source.Sensor  _source.Value  _source.LocationLat  \
# 37      UradMonitor           pm10           14.0            45.657148
# 149     UradMonitor           pm10           11.0            45.657148
# 256     UradMonitor           pm10           13.0            45.657148
# 356     UradMonitor           pm10           12.0            45.657148
# 454     UradMonitor           pm10           22.0            45.657148
# 575     UradMonitor           pm10           27.0            45.657148
# 677     UradMonitor           pm10           29.0            45.657148
# 782     UradMonitor           pm10           29.0            45.657148
# 884     UradMonitor           pm10           27.0            45.657148
# 975     UradMonitor           pm10           27.0            45.657148
# 1082    UradMonitor           pm10           23.0            45.657148
# 1184    UradMonitor           pm10           18.0            45.657148
# 1275    UradMonitor           pm10           16.0            45.657148
# 1375    UradMonitor           pm10           15.0            45.657148
# 1474    UradMonitor           pm10           20.0            45.657148
# 1592    UradMonitor           pm10           22.0            45.657148
# 1703    UradMonitor           pm10           20.0            45.657148
# 1841    UradMonitor           pm10           15.0            45.657148
# 1938    UradMonitor           pm10           30.0            45.657148
# 2047    UradMonitor           pm10           23.0            45.657148
# 2197    UradMonitor           pm10           19.0            45.657148
# 2302    UradMonitor           pm10           14.0            45.657148
# 2409    UradMonitor           pm10           12.0            45.657148
# 2517    UradMonitor           pm10           10.0            45.657148
# 2627    UradMonitor           pm10            7.0            45.657148
# 2729    UradMonitor           pm10            6.0            45.657148
# 2828    UradMonitor           pm10           12.0            45.657148
# 2928    UradMonitor           pm10            5.0            45.657148
# 3029    UradMonitor           pm10            9.0            45.657148
# 3123    UradMonitor           pm10           14.0            45.657148
#
#       _source.LocationLong  _source.TimeStamp _source.Measurement  \
# 37               25.563752      1648472373000               µg/m3
# 149              25.563752      1648468773000               µg/m3
# 256              25.563752      1648465173000               µg/m3
# 356              25.563752      1648461573000               µg/m3
# 454              25.563752      1648457973000               µg/m3
# 575              25.563752      1648454373000               µg/m3
# 677              25.563752      1648450774000               µg/m3
# 782              25.563752      1648447173000               µg/m3
# 884              25.563752      1648443573000               µg/m3
# 975              25.563752      1648439974000               µg/m3
# 1082             25.563752      1648436374000               µg/m3
# 1184             25.563752      1648432774000               µg/m3
# 1275             25.563752      1648429174000               µg/m3
# 1375             25.563752      1648425574000               µg/m3
# 1474             25.563752      1648421974000               µg/m3
# 1592             25.563752      1648418374000               µg/m3
# 1703             25.563752      1648414774000               µg/m3
# 1841             25.563752      1648411174000               µg/m3
# 1938             25.563752      1648407575000               µg/m3
# 2047             25.563752      1648403975000               µg/m3
# 2197             25.563752      1648400375000               µg/m3
# 2302             25.563752      1648396775000               µg/m3
# 2409             25.563752      1648393175000               µg/m3
# 2517             25.563752      1648389575000               µg/m3
# 2627             25.563752      1648385975000               µg/m3
# 2729             25.563752      1648382375000               µg/m3
# 2828             25.563752      1648378776000               µg/m3
# 2928             25.563752      1648375176000               µg/m3
# 3029             25.563752      1648371576000               µg/m3
# 3123             25.563752      1648367976000               µg/m3
#
#        LocationId LocationName
# 37    712209000.0  Bartolomeu2
# 149   712209000.0  Bartolomeu2
# 256   712209000.0  Bartolomeu2
# 356   712209000.0  Bartolomeu2
# 454   712209000.0  Bartolomeu2
# 575   712209000.0  Bartolomeu2
# 677   712209000.0  Bartolomeu2
# 782   712209000.0  Bartolomeu2
# 884   712209000.0  Bartolomeu2
# 975   712209000.0  Bartolomeu2
# 1082  712209000.0  Bartolomeu2
# 1184  712209000.0  Bartolomeu2
# 1275  712209000.0  Bartolomeu2
# 1375  712209000.0  Bartolomeu2
# 1474  712209000.0  Bartolomeu2
# 1592  712209000.0  Bartolomeu2
# 1703  712209000.0  Bartolomeu2
# 1841  712209000.0  Bartolomeu2
# 1938  712209000.0  Bartolomeu2
# 2047  712209000.0  Bartolomeu2
# 2197  712209000.0  Bartolomeu2
# 2302  712209000.0  Bartolomeu2
# 2409  712209000.0  Bartolomeu2
# 2517  712209000.0  Bartolomeu2
# 2627  712209000.0  Bartolomeu2
# 2729  712209000.0  Bartolomeu2
# 2828  712209000.0  Bartolomeu2
# 2928  712209000.0  Bartolomeu2
# 3029  712209000.0  Bartolomeu2
# 3123  712209000.0  Bartolomeu2

# %%
pm10_centru1 = pm10[pm10.get('LocationName') == 'Centru1']
pm10_centru2 = pm10[pm10.get('LocationName') == 'Centru2']
pm10_centru3 = pm10[pm10.get('LocationName') == 'Centru3']
pm10_centru4 = pm10[pm10.get('LocationName') == 'Centru4']

# %%
import matplotlib.pyplot as plt
plt.close("all")
plt.figure(figsize=(20,10))
# plt.plot(pm10_centru1.get('_source.TimeStamp'), pm10_centru1.get('_source.Value'), color = "red")
plt.plot(pm10_centru2.get('_source.TimeStamp'), pm10_centru2.get('_source.Value'), color = "blue", label="Centru2 PM10 sensor")
plt.plot(pm10_centru3.get('_source.TimeStamp'), pm10_centru3.get('_source.Value'), color = "purple", label="Centru3 PM10 sensor")
plt.plot(pm10_centru4.get('_source.TimeStamp'), pm10_centru4.get('_source.Value'), color = "red", label="Centru4 PM10 sensor")
plt.xlabel("TimeStamp")
plt.ylabel("Value")
plt.title("Last 10000 values for PM10 in Centru")
plt.legend()
plt.savefig('plots_updated/PM10_Centru.jpg', bbox_inches = 'tight')
plt.show()

# %%
pm10_carrefour = pm10[pm10.get('LocationName') == 'Carrefour']
pm10_afi = pm10[pm10.get('LocationName') == 'AFI']
pm10_gara = pm10[pm10.get('LocationName') == 'Gara']

# %%
import matplotlib.pyplot as plt
plt.close("all")
plt.figure(figsize=(20,10))
plt.plot(pm10_carrefour.get('_source.TimeStamp'), pm10_carrefour.get('_source.Value'), color = "red", label="Carrefour PM10 sensor")
plt.plot(pm10_afi.get('_source.TimeStamp'), pm10_afi.get('_source.Value'), color = "blue", label="AFI PM10 sensor")
plt.plot(pm10_gara.get('_source.TimeStamp'), pm10_gara.get('_source.Value'), color = "purple", label="Gara PM10 sensor")
plt.plot(pm10_centru4.get('_source.TimeStamp'), pm10_centru4.get('_source.Value'), color = "black", label="Centru4 PM10 sensor")
plt.xlabel("TimeStamp")
plt.ylabel("Value")
plt.title("Last 10000 values for PM10 in Carrefour-AFI-Gara-Centru4")
plt.legend()
plt.savefig('plots_updated/PM10_C-A-G-C4.jpg', bbox_inches = 'tight')
plt.show()

# %%
# pm10_afi.head(30)
pm10_gara.tail(10)
# Out:
#      _source.Source _source.Sensor  _source.Value  _source.LocationLat  \
# 8921           Waqi           pm10           25.0            45.659833
# 9026           Waqi           pm10           26.0            45.659833
# 9138           Waqi           pm10           26.0            45.659833
# 9233           Waqi           pm10           26.0            45.659833
# 9327           Waqi           pm10           26.0            45.659833
# 9423           Waqi           pm10           25.0            45.659833
# 9503           Waqi           pm10           25.0            45.659833
# 9592           Waqi           pm10           24.0            45.659833
# 9730           Waqi           pm10           24.0            45.659833
# 9935           Waqi           pm10           23.0            45.659833
#
#       _source.LocationLong  _source.TimeStamp _source.Measurement  \
# 8921             25.614488      1648166400000               µg/m3
# 9026             25.614488      1648162800000               µg/m3
# 9138             25.614488      1648159200000               µg/m3
# 9233             25.614488      1648155600000               µg/m3
# 9327             25.614488      1648152000000               µg/m3
# 9423             25.614488      1648148400000               µg/m3
# 9503             25.614488      1648144800000               µg/m3
# 9592             25.614488      1648141200000               µg/m3
# 9730             25.614488      1648137600000               µg/m3
# 9935             25.614488      1648134000000               µg/m3
#
#        LocationId LocationName
# 8921  712743216.0         Gara
# 9026  712743216.0         Gara
# 9138  712743216.0         Gara
# 9233  712743216.0         Gara
# 9327  712743216.0         Gara
# 9423  712743216.0         Gara
# 9503  712743216.0         Gara
# 9592  712743216.0         Gara
# 9730  712743216.0         Gara
# 9935  712743216.0         Gara

# %%
train = pm10_afi[pm10_afi.get('_source.TimeStamp') < 1648123156000]
test = pm10_afi[pm10_afi.get('_source.TimeStamp') >= 1648123156000]

import matplotlib.pyplot as plt
plt.close("all")
plt.figure(figsize=(20,10))
plt.plot(train.get('_source.TimeStamp'), train.get('_source.Value'), color = "black", label = "Training")
plt.plot(test.get('_source.TimeStamp'), test.get('_source.Value'), color = "red", label = "Testing")
plt.xlabel("TimeStamp")
plt.ylabel("Value")
plt.title("Train/Test split for PM10 in AFI")
plt.legend()
plt.savefig('plots_updated/PM10_AFI_Split.jpg', bbox_inches = 'tight')
plt.show()

# %%
pm10_afi = pm10[pm10.get('LocationName') == 'AFI']
train = pm10_afi[pm10_afi.index < 8000]
test = pm10_afi[pm10_afi.index >= 8000]

from statsmodels.tsa.statespace.sarimax import SARIMAX
y = train['_source.Value']

ARMAmodel = SARIMAX(y, order=(1,0,1))
ARMAmodel = ARMAmodel.fit()
y_pred = ARMAmodel.get_forecast(len(test.index))
y_pred_df = y_pred.conf_int(alpha=0.05)
y_pred_df['Predictions'] = ARMAmodel.predict(start = y_pred_df.index[0], end = y_pred_df.index[-1])
y_pred_df.index = test.index
y_pred_out = y_pred_df["Predictions"]


import matplotlib.pyplot as plt
plt.close("all")
plt.figure(figsize=(20,10))
plt.plot(train.index, train.get('_source.Value'), color = "black", label = "Training")
plt.plot(test.index, test.get('_source.Value'), color = "red", label = "Testing")
plt.xlabel("Index")
plt.ylabel("Value")
plt.title("Train/Test/Predictions for PM10 in AFI")
plt.plot(y_pred_out, color='green', label = 'ARMA Predictions')
plt.legend()
plt.savefig('plots_updated/PM10_AFI_ARMA_Prediction.jpg', bbox_inches = 'tight')
plt.show()


import numpy as np
from sklearn.metrics import mean_squared_error

arma_rmse = np.sqrt(mean_squared_error(test["_source.Value"].values, y_pred_df["Predictions"]))
print("RMSE: ", arma_rmse)
# Out:
# C:\VALI\Programs\Miniconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\VALI\Programs\Miniconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\VALI\Programs\Miniconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# C:\VALI\Programs\Miniconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# RMSE:  13.937689227210766

# %%
pm10_afi = pm10[pm10.get('LocationName') == 'AFI']
train = pm10_afi[pm10_afi.index < 8000]
test = pm10_afi[pm10_afi.index >= 8000]

from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.arima.model import ARIMA
y = train['_source.Value']

ARMAmodel = ARIMA(y, order=(2,2,2))
ARMAmodel = ARMAmodel.fit()
y_pred = ARMAmodel.get_forecast(len(test.index))
y_pred_df = y_pred.conf_int(alpha=0.05)
y_pred_df['Predictions'] = ARMAmodel.predict(start = y_pred_df.index[0], end = y_pred_df.index[-1])
y_pred_df.index = test.index
y_pred_out = y_pred_df["Predictions"]


import matplotlib.pyplot as plt
plt.close("all")
plt.figure(figsize=(20,10))
plt.plot(train.index, train.get('_source.Value'), color = "black", label = "Training")
plt.plot(test.index, test.get('_source.Value'), color = "red", label = "Testing")
plt.xlabel("Index")
plt.ylabel("Value")
plt.title("Train/Test/Predictions for PM10 in AFI")
plt.plot(y_pred_out, color='purple', label = 'ARIMA Predictions')
plt.legend()
plt.savefig('plots_updated/PM10_AFI_ARIMA_Prediction.jpg', bbox_inches = 'tight')
plt.show()


import numpy as np
from sklearn.metrics import mean_squared_error

arima_rmse = np.sqrt(mean_squared_error(test["_source.Value"].values, y_pred_df["Predictions"]))
print("RMSE: ", arima_rmse)
# Out:
# C:\VALI\Programs\Miniconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\VALI\Programs\Miniconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\VALI\Programs\Miniconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\VALI\Programs\Miniconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# C:\VALI\Programs\Miniconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# C:\VALI\Programs\Miniconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# C:\VALI\Programs\Miniconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# RMSE:  7.407728621220632

# %%
pm10_afi = pm10[pm10.get('LocationName') == 'AFI']
train = pm10_afi[pm10_afi.index < 8000]
test = pm10_afi[pm10_afi.index >= 8000]

from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.arima.model import ARIMA
y = train['_source.Value']

ARMAmodel = ARIMA(y, order=(2,3,2))
ARMAmodel = ARMAmodel.fit()
y_pred = ARMAmodel.get_forecast(len(test.index))
y_pred_df = y_pred.conf_int(alpha=0.05)
y_pred_df['Predictions'] = ARMAmodel.predict(start = y_pred_df.index[0], end = y_pred_df.index[-1])
y_pred_df.index = test.index
y_pred_out = y_pred_df["Predictions"]


import matplotlib.pyplot as plt
plt.close("all")
plt.figure(figsize=(20,10))
plt.plot(train.index, train.get('_source.Value'), color = "black", label = "Training")
plt.plot(test.index, test.get('_source.Value'), color = "red", label = "Testing")
plt.xlabel("Index")
plt.ylabel("Value")
plt.title("Train/Test/Predictions for PM10 in AFI")
plt.plot(y_pred_out, color='purple', label = 'ARIMA Predictions2')
plt.legend()
plt.savefig('plots_updated/PM10_AFI_ARIMA_Prediction2.jpg', bbox_inches = 'tight')
plt.show()


import numpy as np
from sklearn.metrics import mean_squared_error

arima_rmse2 = np.sqrt(mean_squared_error(test["_source.Value"].values, y_pred_df["Predictions"]))
print("RMSE: ", arima_rmse2)
# Out:
# C:\VALI\Programs\Miniconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\VALI\Programs\Miniconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\VALI\Programs\Miniconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\VALI\Programs\Miniconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# C:\VALI\Programs\Miniconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# RMSE:  12.355223934399707

# %%
pm10_afi = pm10[pm10.get('LocationName') == 'AFI']
train = pm10_afi[pm10_afi.index < 8000]
test = pm10_afi[pm10_afi.index >= 8000]

from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.arima.model import ARIMA
y = train['_source.Value']

ARMAmodel = ARIMA(y, order=(9,3,6))
ARMAmodel = ARMAmodel.fit()
y_pred = ARMAmodel.get_forecast(len(test.index))
y_pred_df = y_pred.conf_int(alpha=0.05)
y_pred_df['Predictions'] = ARMAmodel.predict(start = y_pred_df.index[0], end = y_pred_df.index[-1])
y_pred_df.index = test.index
y_pred_out = y_pred_df["Predictions"]


import matplotlib.pyplot as plt
plt.close("all")
plt.figure(figsize=(20,10))
plt.plot(train.index, train.get('_source.Value'), color = "black", label = "Training")
plt.plot(test.index, test.get('_source.Value'), color = "red", label = "Testing")
plt.xlabel("Index")
plt.ylabel("Value")
plt.title("Train/Test/Predictions for PM10 in AFI")
plt.plot(y_pred_out, color='purple', label = 'ARIMA Predictions3')
plt.legend()
plt.savefig('plots_updated/PM10_AFI_ARIMA_Prediction3.jpg', bbox_inches = 'tight')
plt.show()


import numpy as np
from sklearn.metrics import mean_squared_error

arima_rmse3 = np.sqrt(mean_squared_error(test["_source.Value"].values, y_pred_df["Predictions"]))
print("RMSE: ", arima_rmse3)
# Out:
# C:\VALI\Programs\Miniconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\VALI\Programs\Miniconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\VALI\Programs\Miniconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\VALI\Programs\Miniconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# C:\VALI\Programs\Miniconda3\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\VALI\Programs\Miniconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# C:\VALI\Programs\Miniconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# RMSE:  14.00422546066787
